# %% [markdown]
# ## Setup and Import

# %%
import importlib
import sys
from pathlib import Path

# Add mjosa_code root to path
mjosa_code_root = Path.cwd().parent  # Up to mjosa_code root
sys.path.insert(0, str(mjosa_code_root))

# Import from mjosa_code (NEW structure)
import utils.uhi.georef
from utils.common import config

importlib.reload(utils.uhi.georef)
from utils.uhi.georef import *

print("✅ Module reloaded!")
# Out:
# ✅ Module reloaded!

# %% [markdown]
# ## Load Data

# %%
# Load 028 transect
transect = load_transect(config.TRANSECT_028_OUTPUT)


transect.list_files()

# Select all 5 files from transect 028
cube = transect.select_files(
    [
        "rad_uhi_20241029_125028_1",
        "rad_uhi_20241029_125028_2",
        "rad_uhi_20241029_125028_3",
        "rad_uhi_20241029_125028_4",
        "rad_uhi_20241029_125028_5",
    ]
)
# cube.describe()
# Out:
# 📋 Files in output (corrected=False):
#  1. rad_uhi_20241029_125028_1  | shape=(1329, 968, 210)  | has_georef=True
#  2. rad_uhi_20241029_125028_2  | shape=(2011, 968, 210)  | has_georef=True
#  3. rad_uhi_20241029_125028_3  | shape=(2282, 968, 210)  | has_georef=True
#  4. rad_uhi_20241029_125028_4  | shape=(2457, 968, 210)  | has_georef=True
#  5. rad_uhi_20241029_125028_5  | shape=(1948, 968, 210)  | has_georef=True
# 🔄 Rebuilding grids from georef hits for selected files...
#    • rad_uhi_20241029_125028_1
#   rad_uhi_20241029_125028_1: Using GRIDDED format (T=1329, S=968)
#    • rad_uhi_20241029_125028_2
#   rad_uhi_20241029_125028_2: Using GRIDDED format (T=2011, S=968)
#    • rad_uhi_20241029_125028_3
#   rad_uhi_20241029_125028_3: Using GRIDDED format (T=2282, S=968)
#    • rad_uhi_20241029_125028_3
#   rad_uhi_20241029_125028_3: Using GRIDDED format (T=2282, S=968)
#    • rad_uhi_20241029_125028_4
#    • rad_uhi_20241029_125028_4
#   rad_uhi_20241029_125028_4: Using GRIDDED format (T=2457, S=968)
#   rad_uhi_20241029_125028_4: Using GRIDDED format (T=2457, S=968)
#    • rad_uhi_20241029_125028_5
#   rad_uhi_20241029_125028_5: Using GRIDDED format (T=1948, S=968)
#    • rad_uhi_20241029_125028_5
#   rad_uhi_20241029_125028_5: Using GRIDDED format (T=1948, S=968)
# ✅ Combined shapes: X/Y/Z (10027, 968), RGB (10027, 968)
# 🔄 Loading full hyperspectral cube...
#    • Loading rad_uhi_20241029_125028_1...
# ✅ Combined shapes: X/Y/Z (10027, 968), RGB (10027, 968)
# 🔄 Loading full hyperspectral cube...
#    • Loading rad_uhi_20241029_125028_1...
#    • Loading rad_uhi_20241029_125028_2...
#    • Loading rad_uhi_20241029_125028_2...
#    • Loading rad_uhi_20241029_125028_3...
#    • Loading rad_uhi_20241029_125028_3...
#    • Loading rad_uhi_20241029_125028_4...
#    • Loading rad_uhi_20241029_125028_4...
#    • Loading rad_uhi_20241029_125028_5...
#    • Loading rad_uhi_20241029_125028_5...
# ✅ Loaded full cube: (10027, 968, 210) (T × S × B)
# ✅ Loaded full cube: (10027, 968, 210) (T × S × B)

# %%
# cube.rename_legacy_corrections()

# %%
# Apply illumination correction
cube.apply_illumination_correction_v2()
# Out:
# 🔄 Using V2 algorithm (pandas rolling median, memory-efficient)
# ✅ Illumination correction already applied with window=500, strength=1.0
#    Loading from disk...
# 📂 Loading saved illumination correction from 5 files...
#    rad_uhi_20241029_125028_1: window=500, strength=1.0
#    rad_uhi_20241029_125028_1: window=500, strength=1.0
#    rad_uhi_20241029_125028_2: window=500, strength=1.0
#    rad_uhi_20241029_125028_2: window=500, strength=1.0
#    rad_uhi_20241029_125028_3: window=500, strength=1.0
#    rad_uhi_20241029_125028_3: window=500, strength=1.0
#    rad_uhi_20241029_125028_4: window=500, strength=1.0
#    rad_uhi_20241029_125028_4: window=500, strength=1.0
#    rad_uhi_20241029_125028_5: window=500, strength=1.0
# ✅ Loaded illumination correction from disk
#    rad_uhi_20241029_125028_5: window=500, strength=1.0
# ✅ Loaded illumination correction from disk
# array([[[0.00000000e+00, 8.00363868e-02, 3.38807702e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          9.79862548e-03, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 6.24412894e-01, 0.00000000e+00, ...,
#          2.43312144e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          4.49576187e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 1.18552887e+00, ...,
#          2.34972164e-01, 0.00000000e+00, 0.00000000e+00],
#         [9.47257459e-01, 0.00000000e+00, 0.00000000e+00, ...,
#          3.01917344e-01, 0.00000000e+00, 0.00000000e+00]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          1.15298668e+02, 1.14839525e+01, 3.45664215e-03],
#         [0.00000000e+00, 1.00000000e+00, 9.11504328e-01, ...,
#          2.32659373e-02, 2.43540382e+00, 4.57144403e+00],
#         [0.00000000e+00, 3.06572890e+00, 0.00000000e+00, ...,
#          4.02547836e+00, 1.90113354e-02, 8.68073642e-01],
#         ...,
#         [1.75438598e-02, 0.00000000e+00, 1.00000000e+00, ...,
#          6.55555439e+00, 1.33838160e-02, 2.99430227e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          1.98360729e+00, 1.40843954e+01, 2.13704319e+01],
#         [0.00000000e+00, 1.98199582e+00, 0.00000000e+00, ...,
#          1.00750742e+01, 3.09236441e-03, 1.81136024e+00]],
#
#        [[0.00000000e+00, 4.21987295e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 1.30968695e+01, 1.53628865e-03],
#         [0.00000000e+00, 1.38329611e+01, 2.54227202e-02, ...,
#          0.00000000e+00, 3.75119090e+00, 1.27472639e+00],
#         [0.00000000e+00, 7.00939274e+00, 3.00617886e+00, ...,
#          3.63057196e-01, 1.52854491e-02, 2.05932403e+00],
#         ...,
#         [0.00000000e+00, 7.80528212e+00, 0.00000000e+00, ...,
#          4.70339119e-01, 0.00000000e+00, 1.28490031e+00],
#         [0.00000000e+00, 3.92014837e+00, 1.46382201e+00, ...,
#          2.85792470e+00, 1.22151966e+01, 3.82714182e-01],
#         [0.00000000e+00, 3.72013187e+00, 0.00000000e+00, ...,
#          8.50438881e+00, 1.39315668e-02, 1.81136024e+00]],
#
#        ...,
#
#        [[5.45343924e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 7.10688114e+00, 1.16181439e-02],
#         [1.02409277e+01, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 4.66794825e+00, 7.25002098e+00],
#         [5.08758736e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 8.85338783e+00, 6.50349081e-01],
#         ...,
#         [1.40816319e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          9.19671249e+00, 1.27653405e-02, 3.60336947e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          4.49515009e+00, 5.52067833e+01, 1.35954428e+01],
#         [2.40280390e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 5.04114075e+01, 0.00000000e+00]],
#
#        [[0.00000000e+00, 6.32014573e-01, 1.74936104e+01, ...,
#          2.06427407e-02, 5.19848061e+00, 9.21770278e-03],
#         [2.65016556e+00, 3.81691527e+00, 7.62651634e+00, ...,
#          1.02630155e-02, 2.93049908e+00, 7.88408422e+00],
#         [1.87591171e+00, 0.00000000e+00, 1.35000381e+01, ...,
#          1.59122877e+01, 5.97381258e+00, 4.61305952e+00],
#         ...,
#         [1.32653058e+00, 1.39577746e+00, 7.58104801e+00, ...,
#          5.30832443e+01, 5.34362486e-03, 6.97243547e+00],
#         [0.00000000e+00, 0.00000000e+00, 9.65052032e+00, ...,
#          1.22621489e+01, 2.15611935e+01, 5.58016109e+00],
#         [2.50300431e+00, 9.10873473e-01, 8.28000069e+00, ...,
#          2.55792458e-02, 2.80586281e+01, 1.45568810e+01]],
#
#        [[0.00000000e+00, 3.57589817e+00, 7.66670418e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [6.69966877e-01, 6.63383007e+00, 5.57832003e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 1.27472639e+00],
#         [0.00000000e+00, 2.26482272e+00, 6.08022690e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 2.31925821e+00, 3.40770054e+00, ...,
#          7.37268677e+01, 0.00000000e+00, 3.90964794e+00],
#         [0.00000000e+00, 1.67911899e+00, 3.42214584e+00, ...,
#          3.71844983e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 1.17311001e+00, 3.81481481e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]], dtype=float32)

# %% [markdown]
# ## Import and Map ROIs
#
# Load ROIs from dev27 and map them to main classes.

# %%
# Import ROIs
cube.import_rois("./rois/028_new.json")
cube.list_rois()
# Out:
# 📂 Imported 14 ROIs from ./rois/028_new.json
#
# 📂 ROI Collection (14 ROIs):
# ==================================================
#  1. 'rust': 58 pixels
#      Slit range:  193 - 222
#      Track range: 1255 - 1261
#  2. 'sediment': 541 pixels
#      Slit range:   28 - 967
#      Track range: 3604 - 9735
#  3. '1_halo': 50 pixels
#      Slit range:  575 - 649
#      Track range: 5154 - 5168
#  4. '1_arms': 135 pixels
#      Slit range:  549 - 682
#      Track range: 5146 - 5178
#  5. '1_dark': 149 pixels
#      Slit range:  538 - 688
#      Track range: 5150 - 5179
#  6. '1_bomb': 148 pixels
#      Slit range:  595 - 636
#      Track range: 5156 - 5163
#  7. '2_dark': 145 pixels
#      Slit range:  150 - 280
#      Track range: 1250 - 1271
#  8. '2_halo': 96 pixels
#      Slit range:  174 - 240
#      Track range: 1253 - 1266
#  9. '3_halo': 143 pixels
#      Slit range:  721 - 786
#      Track range: 5587 - 5600
# 10. '3_dark': 130 pixels
#      Slit range:  723 - 809
#      Track range: 5583 - 5604
# 11. '3_bomb': 79 pixels
#      Slit range:  742 - 764
#      Track range: 5590 - 5597
# 12. 'dark_pits': 67 pixels
#      Slit range:  396 - 423
#      Track range: 716 - 723
# 13. '2_bomb': 14 pixels
#      Slit range:  208 - 214
#      Track range: 1257 - 1258
# 14. 'dark_pits_multiple': 107 pixels
#      Slit range:  315 - 726
#      Track range: 2342 - 6344

# %%
# Define ROI mapping to main classes
roi_mapping = {
    # Binary classification ROIs
    "sediment": "sediment",
    "rust": "rust",
    # Multi-class: dark bombs (numbered dark areas around bombs)
    "1_dark": "dark_bomb",
    "2_dark": "dark_bomb",
    "3_dark": "dark_bomb",
    # Multi-class: dark pits (separate dark pit class)
    "dark_pits": "dark_pit",
    "dark_pits_multiple": "dark_pit",  # Additional dark pit ROI (same class as dark_pits)
    # Multi-class: halos
    "1_halo": "halo",
    "2_halo": "halo",
    "3_halo": "halo",
}

# Define training ROIs for each classification mode
training_rois_binary = ["sediment", "rust"]

training_rois_multiclass = [
    "sediment",
    "rust",
    "1_dark",
    "2_dark",
    "3_dark",
    "dark_pits",
    "dark_pits_multiple",  # Additional dark pit ROI (same class as dark_pits)
    "1_halo",
    "2_halo",
    "3_halo",
]

print("📋 ROI Mapping:")
for roi, mapped in roi_mapping.items():
    if roi in cube.roi_collection:
        print(f"   {roi} → {mapped} ({len(cube.roi_collection[roi])} pixels)")

print(f"\n🎯 Binary classification ROIs: {training_rois_binary}")
print(f"🎯 Multi-class classification ROIs: {training_rois_multiclass}")
# Out:
# 📋 ROI Mapping:
#    sediment → sediment (541 pixels)
#    rust → rust (58 pixels)
#    1_dark → dark_bomb (149 pixels)
#    2_dark → dark_bomb (145 pixels)
#    3_dark → dark_bomb (130 pixels)
#    dark_pits → dark_pit (67 pixels)
#    dark_pits_multiple → dark_pit (107 pixels)
#    1_halo → halo (50 pixels)
#    2_halo → halo (96 pixels)
#    3_halo → halo (143 pixels)
#
# 🎯 Binary classification ROIs: ['sediment', 'rust']
# 🎯 Multi-class classification ROIs: ['sediment', 'rust', '1_dark', '2_dark', '3_dark', 'dark_pits', 'dark_pits_multiple', '1_halo', '2_halo', '3_halo']

# %% [markdown]
# ## Visualize ROIs on Full Transect

# %%
# %matplotlib inline

# Plot all training ROIs for multi-class
cube.plot_rgb(
    use_corrected=True,
    flip_axes=True,
    flip_horizontal=True,
    figsize=(5, 50),
    show_file_boundaries=False,
    roi_collection=training_rois_multiclass,
    roi_legend_loc="outside",
    roi_marker_size=1,
    roi_legend_markersize=50,
    roi_marker_edgewidth=0,
    roi_overlay_mode="solid",
    roi_solid_pixel_size=5,
)
# Out:
# ✨ Manual per-channel normalization applied:
#    Red:   [0.5300, 1.3500]
#    Green: [0.5800, 1.3700]
#    Blue:  [0.2000, 1.7300]
# 📊 Extent: x=[0, 968], y=[0, 10027]
# 📐 Image shape after transformations: (10027, 968, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=outside, roi_overlay_mode=solid
# 📊 Extent: x=[0, 968], y=[0, 10027]
# 📐 Image shape after transformations: (10027, 968, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=outside, roi_overlay_mode=solid

# %% [markdown]
# ## Define Crop Regions
#
# Define the 4-5 cropped regions where classification will be applied.

# %%
# Define crop regions (UPDATED coordinates from user)
crop_regions = [
    {
        "name": "Crop 1 (Bomb 2 - Rust)",
        "track": 1258,
        "slit": 250,  # UPDATED from 212
        "width": 500,  # UPDATED from 400
        "aspect_ratio": 4,  # UPDATED from 3.5
    },
    {
        "name": "Crop 2 (Bomb 3)",
        "track": 5592,
        "slit": 700,  # UPDATED from 765
        "width": 500,
        "aspect_ratio": 4,  # UPDATED from 3.5
    },
    {
        "name": "Crop 3 (Bomb 1)",
        "track": 5160,
        "slit": 613,
        "width": 500,  # UPDATED from 400
        "aspect_ratio": 4,  # UPDATED from 3.5
    },
    {
        "name": "Crop 4 (Dark pits)",
        "track": 717,
        "slit": 385,
        "width": 500,  # UPDATED from 400
        "aspect_ratio": 4,  # UPDATED from 3.5
    },
]

print(f"📍 Defined {len(crop_regions)} crop regions (UPDATED):")
for i, crop in enumerate(crop_regions, 1):
    print(
        f"   {i}. {crop['name']}: track={crop['track']}, slit={crop['slit']}, width={crop['width']}"
    )
# Out:
# 📍 Defined 4 crop regions (UPDATED):
#    1. Crop 1 (Bomb 2 - Rust): track=1258, slit=250, width=500
#    2. Crop 2 (Bomb 3): track=5592, slit=700, width=500
#    3. Crop 3 (Bomb 1): track=5160, slit=613, width=500
#    4. Crop 4 (Dark pits): track=717, slit=385, width=500

# %% [markdown]
# ## Visualize Crop Regions with ROIs

# %%
# Visualize each crop region with relevant ROIs (UPDATED settings)
for crop in crop_regions:
    print(f"\n📷 {crop['name']}")
    cube.plot_rgb(
        use_corrected=True,
        flip_axes=True,
        flip_horizontal=True,
        figsize=(30, 8.32),  # UPDATED
        crop_center_track=crop["track"],
        crop_center_slit=crop["slit"],
        crop_width=crop["width"],
        crop_aspect_ratio=crop["aspect_ratio"],
        display_aspect_ratio=4.0,  # UPDATED - Controls display stretching
        show_file_boundaries=False,
        roi_collection=training_rois_multiclass,
        roi_legend_loc="outside",
        roi_marker_size=1,  # FIXED - was 200
        roi_legend_markersize=50,
        roi_marker_edgewidth=0,
        roi_overlay_mode="solid",  # ← Enable solid mode
        roi_solid_pixel_size=1,
    )
# Out:
# 📷 Crop 1 (Bomb 2 - Rust)
# ✨ Manual per-channel normalization applied:
#    Red:   [0.5300, 1.3500]
#    Green: [0.5800, 1.3700]
#    Blue:  [0.2000, 1.7300]
# ✨ Manual per-channel normalization applied:
#    Red:   [0.5300, 1.3500]
#    Green: [0.5800, 1.3700]
#    Blue:  [0.2000, 1.7300]
# 📐 Crop center: global track 1258 → local track 1258, slit 250
#    Aspect ratio correction: 4.00:1 (track:slit)
#    Slit pixels: 500, Track pixels: 124
# 🔍 Crop applied: track [1196:1320], slit [0:500]
#    Resulting shape: (124, 500, 3)
# 📊 Extent: x=[0, 500], y=[1196, 1320]
# 📐 Image shape after transformations: (124, 500, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=outside, roi_overlay_mode=solid
# 📐 Crop center: global track 1258 → local track 1258, slit 250
#    Aspect ratio correction: 4.00:1 (track:slit)
#    Slit pixels: 500, Track pixels: 124
# 🔍 Crop applied: track [1196:1320], slit [0:500]
#    Resulting shape: (124, 500, 3)
# 📊 Extent: x=[0, 500], y=[1196, 1320]
# 📐 Image shape after transformations: (124, 500, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=outside, roi_overlay_mode=solid
# 📷 Crop 2 (Bomb 3)
# ✨ Manual per-channel normalization applied:
#    Red:   [0.5300, 1.3500]
#    Green: [0.5800, 1.3700]
#    Blue:  [0.2000, 1.7300]
# 📐 Crop center: global track 5592 → local track 5592, slit 700
#    Aspect ratio correction: 4.00:1 (track:slit)
#    Slit pixels: 500, Track pixels: 124
# 🔍 Crop applied: track [5530:5654], slit [450:950]
#    Resulting shape: (124, 500, 3)
# ✨ Manual per-channel normalization applied:
#    Red:   [0.5300, 1.3500]
#    Green: [0.5800, 1.3700]
#    Blue:  [0.2000, 1.7300]
# 📐 Crop center: global track 5592 → local track 5592, slit 700
#    Aspect ratio correction: 4.00:1 (track:slit)
#    Slit pixels: 500, Track pixels: 124
# 🔍 Crop applied: track [5530:5654], slit [450:950]
#    Resulting shape: (124, 500, 3)
# 📊 Extent: x=[450, 950], y=[5530, 5654]
# 📐 Image shape after transformations: (124, 500, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=outside, roi_overlay_mode=solid
# 📊 Extent: x=[450, 950], y=[5530, 5654]
# 📐 Image shape after transformations: (124, 500, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=outside, roi_overlay_mode=solid
# 📷 Crop 3 (Bomb 1)
# ✨ Manual per-channel normalization applied:
#    Red:   [0.5300, 1.3500]
#    Green: [0.5800, 1.3700]
#    Blue:  [0.2000, 1.7300]
# 📐 Crop center: global track 5160 → local track 5160, slit 613
#    Aspect ratio correction: 4.00:1 (track:slit)
#    Slit pixels: 500, Track pixels: 124
# 🔍 Crop applied: track [5098:5222], slit [363:863]
#    Resulting shape: (124, 500, 3)
# ✨ Manual per-channel normalization applied:
#    Red:   [0.5300, 1.3500]
#    Green: [0.5800, 1.3700]
#    Blue:  [0.2000, 1.7300]
# 📐 Crop center: global track 5160 → local track 5160, slit 613
#    Aspect ratio correction: 4.00:1 (track:slit)
#    Slit pixels: 500, Track pixels: 124
# 🔍 Crop applied: track [5098:5222], slit [363:863]
#    Resulting shape: (124, 500, 3)
# 📊 Extent: x=[363, 863], y=[5098, 5222]
# 📐 Image shape after transformations: (124, 500, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=outside, roi_overlay_mode=solid
# 📊 Extent: x=[363, 863], y=[5098, 5222]
# 📐 Image shape after transformations: (124, 500, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=outside, roi_overlay_mode=solid
# 📷 Crop 4 (Dark pits)
# ✨ Manual per-channel normalization applied:
#    Red:   [0.5300, 1.3500]
#    Green: [0.5800, 1.3700]
#    Blue:  [0.2000, 1.7300]
# 📐 Crop center: global track 717 → local track 717, slit 385
#    Aspect ratio correction: 4.00:1 (track:slit)
#    Slit pixels: 500, Track pixels: 124
# 🔍 Crop applied: track [655:779], slit [135:635]
#    Resulting shape: (124, 500, 3)
# ✨ Manual per-channel normalization applied:
#    Red:   [0.5300, 1.3500]
#    Green: [0.5800, 1.3700]
#    Blue:  [0.2000, 1.7300]
# 📐 Crop center: global track 717 → local track 717, slit 385
#    Aspect ratio correction: 4.00:1 (track:slit)
#    Slit pixels: 500, Track pixels: 124
# 🔍 Crop applied: track [655:779], slit [135:635]
#    Resulting shape: (124, 500, 3)
# 📊 Extent: x=[135, 635], y=[655, 779]
# 📐 Image shape after transformations: (124, 500, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=outside, roi_overlay_mode=solid
# 📊 Extent: x=[135, 635], y=[655, 779]
# 📐 Image shape after transformations: (124, 500, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=outside, roi_overlay_mode=solid

# %% [markdown]
# ### Step 1: Crop Wavelengths (490-680 nm)

# %%
# Apply smoothing BEFORE wavelength filter (force recompute to avoid cache issues)
cube.apply_spectral_smoothing(
    method="gaussian",
    gaussian_sigma=5.0,
)
# Out:
# 💾 Found cached smoothing (gaussian, corrected data) - loading from disk (much faster!)
# 📂 Loading saved spectral smoothing (gaussian, corrected data) from 5 files...
#    rad_uhi_20241029_125028_1: method=gaussian
#    rad_uhi_20241029_125028_1: method=gaussian
#    rad_uhi_20241029_125028_2: method=gaussian
#    rad_uhi_20241029_125028_2: method=gaussian
#    rad_uhi_20241029_125028_3: method=gaussian
#    rad_uhi_20241029_125028_3: method=gaussian
#    rad_uhi_20241029_125028_4: method=gaussian
#    rad_uhi_20241029_125028_4: method=gaussian
#    rad_uhi_20241029_125028_5: method=gaussian
# ✅ Loaded spectral smoothing from disk (saved computation time!)
#    rad_uhi_20241029_125028_5: method=gaussian
# ✅ Loaded spectral smoothing from disk (saved computation time!)
# array([[[ 0.4532221 ,  0.53937715,  0.63120246, ...,  1.329839  ,
#           1.0979766 ,  0.8896462 ],
#         [ 0.6584392 ,  0.804807  ,  0.96267426, ...,  0.45877442,
#           0.3839115 ,  0.3138889 ],
#         [ 0.12631023,  0.16660938,  0.21990718, ...,  0.77975476,
#           0.6993797 ,  0.6094591 ],
#         ...,
#         [ 0.5135691 ,  0.6470479 ,  0.79466134, ...,  0.9414678 ,
#           0.82947934,  0.7143122 ],
#         [ 0.29588312,  0.37845287,  0.48172387, ...,  1.260789  ,
#           1.1231327 ,  0.96826327],
#         [ 0.65205956,  0.653936  ,  0.68873525, ...,  0.93748766,
#           0.72272384,  0.5440005 ]],
#
#        [[ 0.69635546,  0.8777972 ,  1.0773233 , ..., 12.1487255 ,
#          11.606293  , 10.720098  ],
#         [ 1.0415434 ,  1.2013056 ,  1.3412076 , ...,  2.8468373 ,
#           3.069253  ,  3.2957566 ],
#         [ 0.98259646,  1.1279558 ,  1.2616764 , ...,  1.9515684 ,
#           1.8102084 ,  1.6635032 ],
#         ...,
#         [ 0.4940042 ,  0.58075166,  0.6652872 , ...,  2.9818072 ,
#           3.009077  ,  3.022356  ],
#         [ 0.8843509 ,  1.0820303 ,  1.2877989 , ..., 11.02537   ,
#          12.5197315 , 13.9785    ],
#         [ 0.55239177,  0.63404274,  0.71063375, ...,  6.1497216 ,
#           5.7270064 ,  5.2152524 ]],
#
#        [[ 1.6717954 ,  1.9628779 ,  2.2390647 , ...,  1.6725212 ,
#           1.5731289 ,  1.4397533 ],
#         [ 1.4539766 ,  1.5843427 ,  1.6899626 , ...,  1.6200663 ,
#           1.5955676 ,  1.5629601 ],
#         [ 1.2123526 ,  1.3676605 ,  1.5088923 , ...,  1.2356484 ,
#           1.3223437 ,  1.4170322 ],
#         ...,
#         [ 0.88839805,  0.9888602 ,  1.078051  , ...,  0.96765083,
#           0.9767955 ,  1.0000392 ],
#         [ 1.0665809 ,  1.2307037 ,  1.3867843 , ...,  1.9037118 ,
#           1.8404354 ,  1.7384284 ],
#         [ 0.62264377,  0.7517993 ,  0.8953722 , ...,  1.7842921 ,
#           1.8351344 ,  1.8694671 ]],
#
#        ...,
#
#        [[ 9.866468  , 10.346601  , 10.633709  , ...,  1.1538028 ,
#           1.071502  ,  0.971796  ],
#         [ 6.81992   ,  6.271155  ,  5.7535753 , ...,  4.280269  ,
#           4.6150737 ,  4.971911  ],
#         [ 4.339098  ,  4.292634  ,  4.279528  , ..., 29.088802  ,
#          24.519947  , 19.923908  ],
#         ...,
#         [ 3.6358786 ,  3.9738379 ,  4.282226  , ...,  3.1202602 ,
#           3.0964637 ,  3.1206434 ],
#         [ 0.43898275,  0.5756437 ,  0.73784757, ..., 10.362498  ,
#          11.383932  , 12.264098  ],
#         [ 2.2233014 ,  2.2617686 ,  2.3277419 , ...,  4.690904  ,
#           4.6602364 ,  4.4734483 ]],
#
#        [[ 4.071445  ,  4.5554132 ,  4.9274974 , ...,  1.2478791 ,
#           1.0548877 ,  0.88160765],
#         [ 3.1435952 ,  3.2011378 ,  3.2476764 , ...,  3.6806688 ,
#           4.1761966 ,  4.7057433 ],
#         [ 2.3994951 ,  2.4427843 ,  2.474661  , ..., 67.74391   ,
#          57.458054  , 47.129883  ],
#         ...,
#         [ 1.8596067 ,  1.9214776 ,  1.9725624 , ...,  7.994325  ,
#           8.292102  ,  8.447256  ],
#         [ 1.3913314 ,  1.6326178 ,  1.8831977 , ...,  5.614202  ,
#           5.9134483 ,  6.134068  ],
#         [ 2.721597  ,  2.8284976 ,  2.9921253 , ...,  7.9150534 ,
#           9.059123  , 10.144519  ]],
#
#        [[ 1.1632444 ,  1.2711568 ,  1.3466067 , ...,  3.0115519 ,
#           2.550007  ,  2.1074889 ],
#         [ 2.27673   ,  2.4201243 ,  2.505915  , ...,  2.1122565 ,
#           1.9509215 ,  1.8028626 ],
#         [ 1.3891878 ,  1.5542749 ,  1.6824137 , ..., 47.549896  ,
#          39.664803  , 31.805256  ],
#         ...,
#         [ 1.0161923 ,  1.2654303 ,  1.5573066 , ...,  9.070862  ,
#           8.895257  ,  8.569373  ],
#         [ 1.044073  ,  1.2603369 ,  1.5050569 , ...,  2.3456497 ,
#           1.9874089 ,  1.63386   ],
#         [ 0.6783395 ,  0.78284377,  0.8901554 , ...,  0.9049421 ,
#           0.7272863 ,  0.5717536 ]]], dtype=float32)

# %%
# Crop wavelengths to 490-700 nm (UPDATED)
cube.apply_wavelength_filter(wavelength_range=(490, 700))

print(f"✅ Wavelength cropping complete")
print(f"   Cropped shape: {cube.data_corrected.shape}")
print(f"   Wavelength range: {cube.wavelengths[0]:.1f} - {cube.wavelengths[-1]:.1f} nm")
# Out:
# ============================================================
# 🔪 WAVELENGTH FILTERING
# ============================================================
# 📊 Original wavelengths: 210
# 🎯 Target range: 490-700 nm
# ✂️  Filtered wavelengths: 119
# 📉 Range: 490.2 - 699.4 nm
#
# ✅ Datacube shape after filtering: (10027, 968, 119)
#    Memory: 4.30 GB
# ============================================================
# ✅ Wavelength cropping complete
#    Cropped shape: (10027, 968, 119)
#    Wavelength range: 490.2 - 699.4 nm
#
# ✅ Datacube shape after filtering: (10027, 968, 119)
#    Memory: 4.30 GB
# ============================================================
# ✅ Wavelength cropping complete
#    Cropped shape: (10027, 968, 119)
#    Wavelength range: 490.2 - 699.4 nm

# %% [markdown]
# ### Step 3: L2 Normalization (COMMENTED OUT FOR NOW)

# %%
# # Apply L2 normalization (unit-length spectra)
# cube.apply_spectral_normalization(method="l2")

# print(f"✅ L2 normalization complete")
# print(
#     f"   Value range: [{cube.data_corrected.min():.4f}, {cube.data_corrected.max():.4f}]"
# )

# %% [markdown]
# ### Visualize Preprocessed Spectra

# %%
# Plot preprocessed spectra for multi-class training ROIs
cube.plot_spectrum(
    roi_names=training_rois_multiclass,
    use_corrected=True,
    wavelength_range=(
        490,
        700,
    ),  # Filter to 490-680 nm (don't rely on apply_wavelength_filter)
    # wavelength_smoothing=1,  # No additional smoothing
    normalize_method=None,  # No additional normalization
    legend_loc="outside",
    use_inline_labels=False,
    show_std=True,
)

# %% [markdown]
# ## Classify Crop Regions (Binary)
#
# Apply classification only to the cropped regions of interest.

# %%
# Helper function to classify a single crop region
def classify_crop_region(cube, crop, confidence_threshold=0.5):
    """Classify a cropped region and return results."""
    # Calculate crop bounds
    half_width_slit = crop["width"] // 2
    half_width_track = int(crop["width"] / crop["aspect_ratio"] / 2)

    crop_track_min = max(0, crop["track"] - half_width_track)
    crop_track_max = min(cube.data_corrected.shape[0], crop["track"] + half_width_track)
    crop_slit_min = max(0, crop["slit"] - half_width_slit)
    crop_slit_max = min(cube.data_corrected.shape[1], crop["slit"] + half_width_slit)

    print(f"\n🔍 Classifying: {crop['name']}")
    print(
        f"   Crop bounds: track [{crop_track_min}:{crop_track_max}], slit [{crop_slit_min}:{crop_slit_max}]"
    )

    # Classify the segment
    classification_results = cube.classify_segment(
        segment_start=crop_track_min,
        segment_end=crop_track_max - 1,
        use_corrected=True,
        confidence_threshold=confidence_threshold,
        quiet=False,
    )

    # Print pixel counts
    print(f"\n📊 Pixel counts for {crop['name']}:")
    for class_name in classification_results["class_names"]:
        count = np.sum(classification_results["classification_map"] == class_name)
        percentage = 100.0 * count / classification_results["classification_map"].size
        print(f"   {class_name}: {count} pixels ({percentage:.1f}%)")

    return classification_results, crop_track_min, crop_track_max

# %% [markdown]
# ---
#
# # PART 2: Multi-Class Classification (Sediment vs Rust vs Dark vs Halo)
#
# ---

# %% [markdown]
# ## Create Mapped Training ROIs
#
# Map ROIs to main classes for multi-class training.

# %%
# Create new ROI collection with mapped class names
def create_mapped_roi_collection(cube, roi_list, roi_mapping):
    """Create ROI collection with mapped class names."""
    mapped_rois = {}

    for roi_name in roi_list:
        if roi_name in cube.roi_collection:
            mapped_name = roi_mapping.get(roi_name, roi_name)

            # Add pixels to mapped class (merge if class already exists)
            if mapped_name not in mapped_rois:
                mapped_rois[mapped_name] = []
            mapped_rois[mapped_name].extend(cube.roi_collection[roi_name])

    # Remove duplicates
    for class_name in mapped_rois:
        mapped_rois[class_name] = list(set(mapped_rois[class_name]))

    return mapped_rois


# Create mapped ROI collection
mapped_training_rois = create_mapped_roi_collection(
    cube, training_rois_multiclass, roi_mapping
)

print("📋 Mapped training ROIs for multi-class:")
for class_name, pixels in mapped_training_rois.items():
    print(f"   {class_name}: {len(pixels)} pixels")

# Store mapped ROIs temporarily for training
cube._original_roi_collection = cube.roi_collection.copy()  # Backup original ROIs
cube.roi_collection = mapped_training_rois  # Replace with mapped ROIs
# Out:
# 📋 Mapped training ROIs for multi-class:
#    sediment: 541 pixels
#    rust: 58 pixels
#    dark_bomb: 424 pixels
#    dark_pit: 174 pixels
#    halo: 289 pixels

# %% [markdown]
# ## Train SVM (Multi-Class: Sediment vs Rust vs Dark vs Halo)

# %%
# Train SVM with spatial cross-validation - MULTI-CLASS MODE
# BUG FIX: Use None for segment_start/end to include ALL data (not exclude)
cv_results_multiclass = cube.train_svm_with_cv(
    training_rois=list(mapped_training_rois.keys()),  # Use mapped class names
    segment_start=None,  # None = use all data
    segment_end=None,  # None = use all data
    wavelength_range=None,  # Already preprocessed
    cv_folds=5,
    use_corrected=True,
    svm_kernel="rbf",
    optimize_params=True,
    add_brightness_feature=False,
    use_intensity_only=False,
    quiet=False,
    closing_radius=50,  # INCREASED from 5 to 50 - forces connections between scattered pixels
)

# Print summary
print(f"\n" + "=" * 60)
print(f"📊 MULTI-CLASS CLASSIFICATION CROSS-VALIDATION SUMMARY")
print(f"=" * 60)
print(
    f"Accuracy:  {cv_results_multiclass['cv_mean_metrics']['accuracy_mean']:.3f} ± {cv_results_multiclass['cv_mean_metrics']['accuracy_std']:.3f}"
)
print(
    f"Precision: {cv_results_multiclass['cv_mean_metrics']['precision_mean']:.3f} ± {cv_results_multiclass['cv_mean_metrics']['precision_std']:.3f}"
)
print(
    f"Recall:    {cv_results_multiclass['cv_mean_metrics']['recall_mean']:.3f} ± {cv_results_multiclass['cv_mean_metrics']['recall_std']:.3f}"
)
print(
    f"F1 Score:  {cv_results_multiclass['cv_mean_metrics']['f1_mean']:.3f} ± {cv_results_multiclass['cv_mean_metrics']['f1_std']:.3f}"
)

print(f"\n🎯 Best hyperparameters:")
print(f"  C = {cv_results_multiclass['best_params']['C']}")
print(f"  gamma = {cv_results_multiclass['best_params']['gamma']}")

print(f"\n📍 Training pixels used:")
for class_name, count in cv_results_multiclass["training_pixels_per_class"].items():
    print(f"  {class_name}: {count} pixels")
# Out:
# ============================================================
# 🤖 SVM TRAINING WITH CROSS-VALIDATION
# ============================================================
# 💡 MODE: Standard spectral classification
#
# �📦 Datacube shape: (10027, 968, 119)
# 📏 Using data: corrected
# 🎯 Segment range: NONE (using ALL pixels from ROIs)
# 📍 Training ROIs: ['sediment', 'rust', 'dark_bomb', 'dark_pit', 'halo']
#
# 🔍 Filtering ROI pixels...
#    sediment: 541 pixels
#    rust: 58 pixels
#    dark_bomb: 424 pixels
#    dark_pit: 174 pixels
#    halo: 289 pixels
#
# ✅ Training data: 1486 pixels, 119 features
#    Features: 119 wavelengths
#    Kept (outside segment): 1486
#    Rejected (inside segment): 0
#
# 🔬 Creating spatial groups for CV...
#    Settings: closing_radius=50, min_group_size=20
#    Sediment grid: 100(slit) × 200(track) px, min=10
#    sediment: 541 pixels → 6 groups via connected_components
#       sed#01: 111 pixels
#       sed#02: 21 pixels
#       sed#03: 30 pixels
#       sed#04: 202 pixels
#       sed#05: 144 pixels
#       sed#06: 33 pixels
#    sediment: 541 pixels → 6 groups via connected_components
#       sed#01: 111 pixels
#       sed#02: 21 pixels
#       sed#03: 30 pixels
#       sed#04: 202 pixels
#       sed#05: 144 pixels
#       sed#06: 33 pixels
#    rust: 58 pixels → 1 groups via connected_components
#       rust_grp1: 58 pixels
#    rust: 58 pixels → 1 groups via connected_components
#       rust_grp1: 58 pixels
#    dark_bomb: 424 pixels → 3 groups via connected_components
#       bomb#1: 145 pixels
#       bomb#2: 149 pixels
#       bomb#3: 130 pixels
#    dark_bomb: 424 pixels → 3 groups via connected_components
#       bomb#1: 145 pixels
#       bomb#2: 149 pixels
#       bomb#3: 130 pixels
#    dark_pit: 174 pixels → 3 groups via connected_components
#       dark#A: 67 pixels
#       dark#B: 21 pixels
#       dark#C: 86 pixels
#    dark_pit: 174 pixels → 3 groups via connected_components
#       dark#A: 67 pixels
#       dark#B: 21 pixels
#       dark#C: 86 pixels
#    halo: 289 pixels → 3 groups via connected_components
#       halo_grp1: 96 pixels
#       halo_grp2: 50 pixels
#       halo_grp3: 143 pixels
#
# 📊 Final training data:
#    Classes: ['dark_bomb', 'dark_pit', 'halo', 'rust', 'sediment']
#    Total pixels: 1486
#    Unique spatial groups: 16
#    Group names: ['bomb#1', 'bomb#2', 'bomb#3', 'dark#A', 'dark#B', 'dark#C', 'halo_grp1', 'halo_grp2', 'halo_grp3', 'rust_grp1', 'sed#01', 'sed#02', 'sed#03', 'sed#04', 'sed#05', 'sed#06']
#
# 🔄 Performing 5-fold GROUPED cross-validation...
#
#    📊 Groups per class:
#       dark_bomb: 3 groups
#       dark_pit: 3 groups
#       halo: 3 groups
#       rust: 1 groups
#       sediment: 6 groups
#    🎯 Minority class: rust (1 groups)
#    🔄 Using Leave-One-Rust-Out strategy
#    ⚠️  Reducing folds: 5 → 1 (limited by rust)
#
#    ⚠️  Fold 1/1: SKIPPED (empty training set)
#
# 📊 Cross-Validation Results (mean ± std):
#    Accuracy:  nan ± nan
#    Precision: nan ± nan
#    Recall:    nan ± nan
#    F1 Score:  nan ± nan
#
# 🏋️  Training final SVM on all 1486 training pixels...
#
# ⚖️  Using balanced class weights (automatic)
#    halo: 289 pixels → 3 groups via connected_components
#       halo_grp1: 96 pixels
#       halo_grp2: 50 pixels
#       halo_grp3: 143 pixels
#
# 📊 Final training data:
#    Classes: ['dark_bomb', 'dark_pit', 'halo', 'rust', 'sediment']
#    Total pixels: 1486
#    Unique spatial groups: 16
#    Group names: ['bomb#1', 'bomb#2', 'bomb#3', 'dark#A', 'dark#B', 'dark#C', 'halo_grp1', 'halo_grp2', 'halo_grp3', 'rust_grp1', 'sed#01', 'sed#02', 'sed#03', 'sed#04', 'sed#05', 'sed#06']
#
# 🔄 Performing 5-fold GROUPED cross-validation...
#
#    📊 Groups per class:
#       dark_bomb: 3 groups
#       dark_pit: 3 groups
#       halo: 3 groups
#       rust: 1 groups
#       sediment: 6 groups
#    🎯 Minority class: rust (1 groups)
#    🔄 Using Leave-One-Rust-Out strategy
#    ⚠️  Reducing folds: 5 → 1 (limited by rust)
#
#    ⚠️  Fold 1/1: SKIPPED (empty training set)
#
# 📊 Cross-Validation Results (mean ± std):
#    Accuracy:  nan ± nan
#    Precision: nan ± nan
#    Recall:    nan ± nan
#    F1 Score:  nan ± nan
#
# 🏋️  Training final SVM on all 1486 training pixels...
#
# ⚖️  Using balanced class weights (automatic)
# c:\conda_envs\my_env\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\conda_envs\my_env\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\conda_envs\my_env\lib\site-packages\numpy\core\_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\conda_envs\my_env\lib\site-packages\numpy\core\_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# c:\conda_envs\my_env\lib\site-packages\numpy\core\_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#    Best parameters: C=10, gamma=0.1
#    ✅ Training complete in 8.52 seconds
#
# ✅ SVM training with cross-validation complete!
# ============================================================
#
# ============================================================
# 📊 MULTI-CLASS CLASSIFICATION CROSS-VALIDATION SUMMARY
# ============================================================
# Accuracy:  nan ± nan
# Precision: nan ± nan
# Recall:    nan ± nan
# F1 Score:  nan ± nan
#
# 🎯 Best hyperparameters:
#   C = 10
#   gamma = 0.1
#
# 📍 Training pixels used:
#   sediment: 541 pixels
#   rust: 58 pixels
#   dark_bomb: 424 pixels
#   dark_pit: 174 pixels
#   halo: 289 pixels

# %% [markdown]
# ## Additional CV Metrics (from Cross-Validation)
#
# Compute Cohen's Kappa and visualize confusion matrix from CV results.

# %%
# # Compute average confusion matrix from CV folds
# import numpy as np
# from sklearn.metrics import cohen_kappa_score

# # Get confusion matrices from all CV folds
# cv_confusion_matrices = cv_results_multiclass["cv_results"]["confusion_matrices"]

# # Average confusion matrices across folds
# avg_confusion_matrix = np.mean(cv_confusion_matrices, axis=0).astype(int)

# # Get class names
# class_names = list(mapped_training_rois.keys())

# print(f"\n" + "=" * 60)
# print(f"📊 ADDITIONAL CV METRICS (from Cross-Validation)")
# print(f"=" * 60)

# # Compute Cohen's Kappa from averaged confusion matrix
# # Reconstruct y_true and y_pred from confusion matrix
# y_true_cv = []
# y_pred_cv = []
# for i, true_class in enumerate(class_names):
#     for j, pred_class in enumerate(class_names):
#         count = avg_confusion_matrix[i, j]
#         y_true_cv.extend([i] * count)
#         y_pred_cv.extend([j] * count)

# y_true_cv = np.array(y_true_cv)
# y_pred_cv = np.array(y_pred_cv)

# # Cohen's Kappa
# kappa_cv = cohen_kappa_score(y_true_cv, y_pred_cv)
# print(f"Cohen's Kappa (κ): {kappa_cv:.3f}")

# # Interpretation
# if kappa_cv > 0.8:
#     interpretation = "Strong agreement"
# elif kappa_cv > 0.6:
#     interpretation = "Substantial agreement"
# elif kappa_cv > 0.4:
#     interpretation = "Moderate agreement"
# elif kappa_cv > 0.2:
#     interpretation = "Fair agreement"
# else:
#     interpretation = "Slight agreement"
# print(f"   Interpretation: {interpretation}")
# print(f"   (κ > 0.8: Strong, 0.6-0.8: Substantial, 0.4-0.6: Moderate)")

# # Macro F1 (already computed)
# macro_f1_mean = cv_results_multiclass["cv_mean_metrics"]["f1_mean"]
# macro_f1_std = cv_results_multiclass["cv_mean_metrics"]["f1_std"]
# print(f"\nMacro F1: {macro_f1_mean:.3f} ± {macro_f1_std:.3f}")
# print(f"   (Average F1 across all {len(class_names)} classes)")

# print("=" * 60)

# %%
# # Plot confusion matrix (averaged across CV folds)
# import matplotlib.pyplot as plt

# fig, ax = plt.subplots(figsize=(10, 8))

# # Plot confusion matrix as heatmap
# im = ax.imshow(avg_confusion_matrix, cmap="Greens", aspect="auto")

# # Add colorbar
# cbar = plt.colorbar(im, ax=ax)
# cbar.set_label("Pixel Count (averaged across CV folds)", fontsize=12)

# # Set ticks and labelsz
# ax.set_xticks(np.arange(len(class_names)))
# ax.set_yticks(np.arange(len(class_names)))
# ax.set_xticklabels(class_names)
# ax.set_yticklabels(class_names)

# # Rotate x-axis labels
# plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# # Add text annotations
# for i in range(len(class_names)):
#     for j in range(len(class_names)):
#         text = ax.text(
#             j,
#             i,
#             f"{avg_confusion_matrix[i, j]}",
#             ha="center",
#             va="center",
#             color="black",
#             fontsize=12,
#         )

# ax.set_xlabel("Predicted Class", fontsize=12)
# ax.set_ylabel("True Class", fontsize=12)
# ax.set_title(
#     "Confusion Matrix - Multi-Class SVM (Averaged Across CV Folds)",
#     fontsize=14,
#     fontweight="bold",
# )
# plt.tight_layout()
# plt.show()

# # Print normalized confusion matrix (percentages)
# cm_normalized = (
#     avg_confusion_matrix.astype("float")
#     / avg_confusion_matrix.sum(axis=1)[:, np.newaxis]
#     * 100
# )

# print(f"\n📊 Confusion Matrix (Normalized by True Class - Row %):")
# print(f"{'':20s}", end="")
# for pred_class in class_names:
#     print(f"{pred_class:>20s}", end="")
# print()
# print("-" * (20 + 20 * len(class_names)))

# for i, true_class in enumerate(class_names):
#     print(f"{true_class:20s}", end="")
#     for j in range(len(class_names)):
#         print(f"{cm_normalized[i, j]:19.1f}%", end="")
#     print()

# %%
# Plot spatial groups for multi-class
if (
    "spatial_groups_roi_collection" in cv_results_multiclass
    and cv_results_multiclass["spatial_groups_roi_collection"]
):
    print("\n📊 Spatial Groups Created for Multi-Class Classification:")
    for group_name, pixels in sorted(
        cv_results_multiclass["spatial_groups_roi_collection"].items()
    ):
        print(f"   {group_name}: {len(pixels)} pixels")

    cube.plot_georef(
        use_corrected=True,
        figsize=(40, 10),
        roi_collection=cv_results_multiclass["spatial_groups_roi_collection"],
        roi_marker_size=3,
        roi_legend_loc="outside",
        roi_marker_edgewidth=0,
        roi_legend_markersize=40,
        roi_solid_pixel_size=11,
        roi_overlay_mode="solid",
    )
else:
    print("⚠️ No spatial groups found in cv_results_multiclass.")
# Out:
# 📊 Spatial Groups Created for Multi-Class Classification:
#    bomb#1: 145 pixels
#    bomb#2: 149 pixels
#    bomb#3: 130 pixels
#    dark#A: 67 pixels
#    dark#B: 21 pixels
#    dark#C: 86 pixels
#    halo_grp1: 96 pixels
#    halo_grp2: 50 pixels
#    halo_grp3: 143 pixels
#    rust_grp1: 58 pixels
#    sed#01: 111 pixels
#    sed#02: 21 pixels
#    sed#03: 30 pixels
#    sed#04: 202 pixels
#    sed#05: 144 pixels
#    sed#06: 33 pixels
# 🔧 DEBUG: plot_georef called with use_wavelength_colormap=False, wavelength_colormap_target=None
# 💡 Interactive mode: Click on the plot to display coordinates
# 💡 Interactive mode: Click on the plot to display coordinates

# %%
# Restore original ROI collection
cube.roi_collection = cube._original_roi_collection
del cube._original_roi_collection

print("✅ Original ROI collection restored")
# Out:
# ✅ Original ROI collection restored

# %% [markdown]
# ## 🔍 DIAGNOSTIC: Check if 5-fold CV is Actually Possible
#
# Let's investigate whether the training data has enough spatial groups to support 5-fold cross-validation.

# %%
# Diagnostic: Check spatial group creation for 028 training data
import numpy as np
from sklearn.cluster import KMeans
from skimage.morphology import binary_closing, disk
from scipy.ndimage import label as scipy_label

print("=" * 80)
print("🔍 DIAGNOSTIC: 028 CV FEASIBILITY CHECK")
print("=" * 80)

# Get mapped training ROIs
print("\n📋 Training ROIs (5 classes):")
for class_name, pixels in mapped_training_rois.items():
    print(f"   {class_name}: {len(pixels)} pixels")

# Simulate spatial grouping (simplified version of what train_svm_with_cv does)
print("\n🧩 Simulating spatial group creation...")
print("=" * 80)

spatial_groups = {}
total_groups = 0

for class_name, pixel_list in mapped_training_rois.items():
    print(f"\n📍 Class: {class_name}")

    if len(pixel_list) == 0:
        print(f"   ⚠️  EMPTY CLASS - SKIPPED")
        spatial_groups[class_name] = []
        continue

    # Convert to array
    coords = np.array(pixel_list)  # [(track, slit), ...]

    # Apply morphological closing to connect nearby pixels
    closing_radius = 50  # Same as in your training call

    # Create binary mask
    min_track, min_slit = coords.min(axis=0)
    max_track, max_slit = coords.max(axis=0)

    # Add padding
    padding = closing_radius + 10
    mask_shape = (
        max_track - min_track + 2 * padding,
        max_slit - min_slit + 2 * padding,
    )
    mask = np.zeros(mask_shape, dtype=bool)

    # Place pixels in mask
    for track, slit in coords:
        mask[track - min_track + padding, slit - min_slit + padding] = True

    # Apply closing
    if closing_radius > 0:
        closed_mask = binary_closing(mask, disk(closing_radius))
    else:
        closed_mask = mask

    # Label connected components
    labeled, num_features = scipy_label(closed_mask)

    # Map original pixels to groups
    groups_for_class = []
    for track, slit in coords:
        label_val = labeled[track - min_track + padding, slit - min_slit + padding]
        if label_val > 0:
            groups_for_class.append(f"{class_name}_group_{label_val}")

    # Count unique groups
    unique_groups = sorted(set(groups_for_class))
    spatial_groups[class_name] = unique_groups
    total_groups += len(unique_groups)

    print(f"   Total pixels: {len(pixel_list)}")
    print(f"   Spatial groups created: {len(unique_groups)}")
    print(f"   Group names: {unique_groups}")

    # Check if enough for CV
    if len(unique_groups) < 5:
        print(
            f"   ⚠️  WARNING: Only {len(unique_groups)} groups - NOT ENOUGH FOR 5-FOLD CV!"
        )
    else:
        print(f"   ✅ Sufficient groups for 5-fold CV")

# Summary
print("\n" + "=" * 80)
print("📊 SUMMARY:")
print("=" * 80)
print(f"Total spatial groups across all classes: {total_groups}")
print(f"\nPer-class group counts:")
for class_name, groups in spatial_groups.items():
    print(f"   {class_name}: {len(groups)} groups")

print("\n🎯 5-FOLD CV FEASIBILITY:")
min_groups = min(len(groups) for groups in spatial_groups.values() if len(groups) > 0)
print(f"   Minimum groups in any class: {min_groups}")

if min_groups >= 5:
    print(f"   ✅ 5-FOLD CV IS FEASIBLE")
    print(f"      Each fold can have at least 1 group per class")
elif min_groups >= 3:
    print(f"   ⚠️  5-FOLD CV WILL LIKELY FAIL")
    print(f"      Some folds will be missing classes (validation error will be thrown)")
    print(f"      Recommendation: Use cv_folds={min_groups} instead")
elif min_groups >= 2:
    print(f"   ⚠️  ONLY 2-FOLD CV IS POSSIBLE")
    print(f"      Recommendation: Use cv_folds=2")
else:
    print(f"   ❌ CROSS-VALIDATION NOT POSSIBLE")
    print(f"      At least one class has only 1 spatial group")
    print(f"      Cannot split without data leakage")

print("\n" + "=" * 80)
# Out:
# ================================================================================
# 🔍 DIAGNOSTIC: 028 CV FEASIBILITY CHECK
# ================================================================================
#
# 📋 Training ROIs (5 classes):
#    sediment: 541 pixels
#    rust: 58 pixels
#    dark_bomb: 424 pixels
#    dark_pit: 174 pixels
#    halo: 289 pixels
#
# 🧩 Simulating spatial group creation...
# ================================================================================
#
# 📍 Class: sediment
#    Total pixels: 541
#    Spatial groups created: 207
#    Group names: ['sediment_group_1', 'sediment_group_10', 'sediment_group_101', 'sediment_group_102', 'sediment_group_103', 'sediment_group_105', 'sediment_group_106', 'sediment_group_107', 'sediment_group_108', 'sediment_group_109', 'sediment_group_11', 'sediment_group_112', 'sediment_group_113', 'sediment_group_114', 'sediment_group_115', 'sediment_group_116', 'sediment_group_119', 'sediment_group_12', 'sediment_group_121', 'sediment_group_122', 'sediment_group_123', 'sediment_group_127', 'sediment_group_134', 'sediment_group_135', 'sediment_group_136', 'sediment_group_138', 'sediment_group_139', 'sediment_group_14', 'sediment_group_140', 'sediment_group_141', 'sediment_group_142', 'sediment_group_143', 'sediment_group_144', 'sediment_group_145', 'sediment_group_146', 'sediment_group_147', 'sediment_group_148', 'sediment_group_149', 'sediment_group_15', 'sediment_group_150', 'sediment_group_151', 'sediment_group_153', 'sediment_group_154', 'sediment_group_155', 'sediment_group_156', 'sediment_group_157', 'sediment_group_158', 'sediment_group_159', 'sediment_group_16', 'sediment_group_161', 'sediment_group_167', 'sediment_group_168', 'sediment_group_169', 'sediment_group_17', 'sediment_group_170', 'sediment_group_171', 'sediment_group_173', 'sediment_group_174', 'sediment_group_175', 'sediment_group_178', 'sediment_group_179', 'sediment_group_180', 'sediment_group_181', 'sediment_group_182', 'sediment_group_184', 'sediment_group_186', 'sediment_group_187', 'sediment_group_188', 'sediment_group_189', 'sediment_group_190', 'sediment_group_191', 'sediment_group_192', 'sediment_group_193', 'sediment_group_194', 'sediment_group_195', 'sediment_group_197', 'sediment_group_198', 'sediment_group_199', 'sediment_group_2', 'sediment_group_20', 'sediment_group_200', 'sediment_group_201', 'sediment_group_202', 'sediment_group_206', 'sediment_group_207', 'sediment_group_208', 'sediment_group_209', 'sediment_group_21', 'sediment_group_210', 'sediment_group_211', 'sediment_group_212', 'sediment_group_213', 'sediment_group_214', 'sediment_group_215', 'sediment_group_216', 'sediment_group_217', 'sediment_group_218', 'sediment_group_219', 'sediment_group_220', 'sediment_group_221', 'sediment_group_222', 'sediment_group_223', 'sediment_group_224', 'sediment_group_225', 'sediment_group_226', 'sediment_group_227', 'sediment_group_228', 'sediment_group_229', 'sediment_group_23', 'sediment_group_230', 'sediment_group_232', 'sediment_group_233', 'sediment_group_234', 'sediment_group_235', 'sediment_group_239', 'sediment_group_24', 'sediment_group_240', 'sediment_group_241', 'sediment_group_242', 'sediment_group_243', 'sediment_group_245', 'sediment_group_247', 'sediment_group_248', 'sediment_group_249', 'sediment_group_25', 'sediment_group_251', 'sediment_group_252', 'sediment_group_253', 'sediment_group_254', 'sediment_group_255', 'sediment_group_258', 'sediment_group_259', 'sediment_group_26', 'sediment_group_261', 'sediment_group_265', 'sediment_group_267', 'sediment_group_268', 'sediment_group_269', 'sediment_group_270', 'sediment_group_272', 'sediment_group_273', 'sediment_group_274', 'sediment_group_275', 'sediment_group_276', 'sediment_group_277', 'sediment_group_278', 'sediment_group_279', 'sediment_group_28', 'sediment_group_29', 'sediment_group_3', 'sediment_group_30', 'sediment_group_31', 'sediment_group_33', 'sediment_group_34', 'sediment_group_35', 'sediment_group_36', 'sediment_group_37', 'sediment_group_38', 'sediment_group_39', 'sediment_group_4', 'sediment_group_40', 'sediment_group_41', 'sediment_group_42', 'sediment_group_43', 'sediment_group_44', 'sediment_group_45', 'sediment_group_46', 'sediment_group_49', 'sediment_group_5', 'sediment_group_50', 'sediment_group_51', 'sediment_group_52', 'sediment_group_53', 'sediment_group_54', 'sediment_group_55', 'sediment_group_57', 'sediment_group_58', 'sediment_group_59', 'sediment_group_6', 'sediment_group_60', 'sediment_group_61', 'sediment_group_62', 'sediment_group_63', 'sediment_grou ...
#    ✅ Sufficient groups for 5-fold CV
#
# 📍 Class: rust
#    Total pixels: 541
#    Spatial groups created: 207
#    Group names: ['sediment_group_1', 'sediment_group_10', 'sediment_group_101', 'sediment_group_102', 'sediment_group_103', 'sediment_group_105', 'sediment_group_106', 'sediment_group_107', 'sediment_group_108', 'sediment_group_109', 'sediment_group_11', 'sediment_group_112', 'sediment_group_113', 'sediment_group_114', 'sediment_group_115', 'sediment_group_116', 'sediment_group_119', 'sediment_group_12', 'sediment_group_121', 'sediment_group_122', 'sediment_group_123', 'sediment_group_127', 'sediment_group_134', 'sediment_group_135', 'sediment_group_136', 'sediment_group_138', 'sediment_group_139', 'sediment_group_14', 'sediment_group_140', 'sediment_group_141', 'sediment_group_142', 'sediment_group_143', 'sediment_group_144', 'sediment_group_145', 'sediment_group_146', 'sediment_group_147', 'sediment_group_148', 'sediment_group_149', 'sediment_group_15', 'sediment_group_150', 'sediment_group_151', 'sediment_group_153', 'sediment_group_154', 'sediment_group_155', 'sediment_group_156', 'sediment_group_157', 'sediment_group_158', 'sediment_group_159', 'sediment_group_16', 'sediment_group_161', 'sediment_group_167', 'sediment_group_168', 'sediment_group_169', 'sediment_group_17', 'sediment_group_170', 'sediment_group_171', 'sediment_group_173', 'sediment_group_174', 'sediment_group_175', 'sediment_group_178', 'sediment_group_179', 'sediment_group_180', 'sediment_group_181', 'sediment_group_182', 'sediment_group_184', 'sediment_group_186', 'sediment_group_187', 'sediment_group_188', 'sediment_group_189', 'sediment_group_190', 'sediment_group_191', 'sediment_group_192', 'sediment_group_193', 'sediment_group_194', 'sediment_group_195', 'sediment_group_197', 'sediment_group_198', 'sediment_group_199', 'sediment_group_2', 'sediment_group_20', 'sediment_group_200', 'sediment_group_201', 'sediment_group_202', 'sediment_group_206', 'sediment_group_207', 'sediment_group_208', 'sediment_group_209', 'sediment_group_21', 'sediment_group_210', 'sediment_group_211', 'sediment_group_212', 'sediment_group_213', 'sediment_group_214', 'sediment_group_215', 'sediment_group_216', 'sediment_group_217', 'sediment_group_218', 'sediment_group_219', 'sediment_group_220', 'sediment_group_221', 'sediment_group_222', 'sediment_group_223', 'sediment_group_224', 'sediment_group_225', 'sediment_group_226', 'sediment_group_227', 'sediment_group_228', 'sediment_group_229', 'sediment_group_23', 'sediment_group_230', 'sediment_group_232', 'sediment_group_233', 'sediment_group_234', 'sediment_group_235', 'sediment_group_239', 'sediment_group_24', 'sediment_group_240', 'sediment_group_241', 'sediment_group_242', 'sediment_group_243', 'sediment_group_245', 'sediment_group_247', 'sediment_group_248', 'sediment_group_249', 'sediment_group_25', 'sediment_group_251', 'sediment_group_252', 'sediment_group_253', 'sediment_group_254', 'sediment_group_255', 'sediment_group_258', 'sediment_group_259', 'sediment_group_26', 'sediment_group_261', 'sediment_group_265', 'sediment_group_267', 'sediment_group_268', 'sediment_group_269', 'sediment_group_270', 'sediment_group_272', 'sediment_group_273', 'sediment_group_274', 'sediment_group_275', 'sediment_group_276', 'sediment_group_277', 'sediment_group_278', 'sediment_group_279', 'sediment_group_28', 'sediment_group_29', 'sediment_group_3', 'sediment_group_30', 'sediment_group_31', 'sediment_group_33', 'sediment_group_34', 'sediment_group_35', 'sediment_group_36', 'sediment_group_37', 'sediment_group_38', 'sediment_group_39', 'sediment_group_4', 'sediment_group_40', 'sediment_group_41', 'sediment_group_42', 'sediment_group_43', 'sediment_group_44', 'sediment_group_45', 'sediment_group_46', 'sediment_group_49', 'sediment_group_5', 'sediment_group_50', 'sediment_group_51', 'sediment_group_52', 'sediment_group_53', 'sediment_group_54', 'sediment_group_55', 'sediment_group_57', 'sediment_group_58', 'sediment_group_59', 'sediment_group_6', 'sediment_group_60', 'sediment_group_61', 'sediment_group_62', 'sediment_group_63', 'sediment_grou ...
#    ✅ Sufficient groups for 5-fold CV
#
# 📍 Class: rust
#    Total pixels: 58
#    Spatial groups created: 1
#    Group names: ['rust_group_1']
#    ⚠️  WARNING: Only 1 groups - NOT ENOUGH FOR 5-FOLD CV!
#
# 📍 Class: dark_bomb
#    Total pixels: 58
#    Spatial groups created: 1
#    Group names: ['rust_group_1']
#    ⚠️  WARNING: Only 1 groups - NOT ENOUGH FOR 5-FOLD CV!
#
# 📍 Class: dark_bomb
#    Total pixels: 424
#    Spatial groups created: 3
#    Group names: ['dark_bomb_group_1', 'dark_bomb_group_2', 'dark_bomb_group_3']
#    ⚠️  WARNING: Only 3 groups - NOT ENOUGH FOR 5-FOLD CV!
#
# 📍 Class: dark_pit
#    Total pixels: 424
#    Spatial groups created: 3
#    Group names: ['dark_bomb_group_1', 'dark_bomb_group_2', 'dark_bomb_group_3']
#    ⚠️  WARNING: Only 3 groups - NOT ENOUGH FOR 5-FOLD CV!
#
# 📍 Class: dark_pit
#    Total pixels: 174
#    Spatial groups created: 8
#    Group names: ['dark_pit_group_1', 'dark_pit_group_2', 'dark_pit_group_3', 'dark_pit_group_4', 'dark_pit_group_5', 'dark_pit_group_6', 'dark_pit_group_7', 'dark_pit_group_8']
#    ✅ Sufficient groups for 5-fold CV
#
# 📍 Class: halo
#    Total pixels: 174
#    Spatial groups created: 8
#    Group names: ['dark_pit_group_1', 'dark_pit_group_2', 'dark_pit_group_3', 'dark_pit_group_4', 'dark_pit_group_5', 'dark_pit_group_6', 'dark_pit_group_7', 'dark_pit_group_8']
#    ✅ Sufficient groups for 5-fold CV
#
# 📍 Class: halo
#    Total pixels: 289
#    Spatial groups created: 3
#    Group names: ['halo_group_1', 'halo_group_2', 'halo_group_3']
#    ⚠️  WARNING: Only 3 groups - NOT ENOUGH FOR 5-FOLD CV!
#
# ================================================================================
# 📊 SUMMARY:
# ================================================================================
# Total spatial groups across all classes: 222
#
# Per-class group counts:
#    sediment: 207 groups
#    rust: 1 groups
#    dark_bomb: 3 groups
#    dark_pit: 8 groups
#    halo: 3 groups
#
# 🎯 5-FOLD CV FEASIBILITY:
#    Minimum groups in any class: 1
#    ❌ CROSS-VALIDATION NOT POSSIBLE
#       At least one class has only 1 spatial group
#       Cannot split without data leakage
#
# ================================================================================
#    Total pixels: 289
#    Spatial groups created: 3
#    Group names: ['halo_group_1', 'halo_group_2', 'halo_group_3']
#    ⚠️  WARNING: Only 3 groups - NOT ENOUGH FOR 5-FOLD CV!
#
# ================================================================================
# 📊 SUMMARY:
# ================================================================================
# Total spatial groups across all classes: 222
#
# Per-class group counts:
#    sediment: 207 groups
#    rust: 1 groups
#    dark_bomb: 3 groups
#    dark_pit: 8 groups
#    halo: 3 groups
#
# 🎯 5-FOLD CV FEASIBILITY:
#    Minimum groups in any class: 1
#    ❌ CROSS-VALIDATION NOT POSSIBLE
#       At least one class has only 1 spatial group
#       Cannot split without data leakage
#
# ================================================================================

# %%
# Additional diagnostic: Check if cv_results_multiclass exists and what it contains
print("\n" + "=" * 80)
print("🔍 CHECKING ACTUAL CV RESULTS FROM TRAINING")
print("=" * 80)

if "cv_results_multiclass" in locals():
    print("\n✅ cv_results_multiclass exists!")

    print(f"\n📋 Available keys:")
    for key in cv_results_multiclass.keys():
        print(f"   • {key}")

    if "cv_mean_metrics" in cv_results_multiclass:
        print(f"\n📊 CV Mean Metrics:")
        for metric, value in cv_results_multiclass["cv_mean_metrics"].items():
            print(f"   {metric}: {value:.4f}")

    if "cv_results" in cv_results_multiclass:
        cv_res = cv_results_multiclass["cv_results"]
        if "accuracy" in cv_res:
            print(f"\n📈 Individual Fold Results:")
            print(f"   Accuracy per fold: {cv_res['accuracy']}")
            print(f"   Number of folds completed: {len(cv_res['accuracy'])}")

            if len(cv_res["accuracy"]) < 5:
                print(
                    f"\n   ⚠️  WARNING: Expected 5 folds but only {len(cv_res['accuracy'])} completed!"
                )
                print(f"   This suggests some folds were skipped or failed.")

    if "training_pixels_per_class" in cv_results_multiclass:
        print(f"\n🎯 Training pixels per class:")
        for cls, count in cv_results_multiclass["training_pixels_per_class"].items():
            print(f"   {cls}: {count} pixels")

    # Check for spatial groups
    if "spatial_groups_roi_collection" in cv_results_multiclass:
        groups_roi = cv_results_multiclass["spatial_groups_roi_collection"]
        print(f"\n🧩 Spatial groups created: {len(groups_roi)} total")

        # Count groups per class
        class_group_counts = {}
        for group_name in groups_roi.keys():
            class_prefix = "_".join(group_name.split("_")[:-2])  # Extract class name
            if class_prefix not in class_group_counts:
                class_group_counts[class_prefix] = 0
            class_group_counts[class_prefix] += 1

        print(f"   Groups per class:")
        for cls, count in class_group_counts.items():
            print(f"      {cls}: {count} groups")

else:
    print("\n❌ cv_results_multiclass NOT FOUND")
    print("   You need to run the training cell first!")
    print("   Cell: 'Train SVM with spatial cross-validation - MULTI-CLASS MODE'")

print("\n" + "=" * 80)
# Out:
# ================================================================================
# 🔍 CHECKING ACTUAL CV RESULTS FROM TRAINING
# ================================================================================
#
# ✅ cv_results_multiclass exists!
#
# 📋 Available keys:
#    • model
#    • label_encoder
#    • class_names
#    • cv_results
#    • cv_mean_metrics
#    • best_params
#    • training_pixels_per_class
#    • filtered_training_rois
#    • spatial_groups_roi_collection
#    • filtered_pixels_outside
#    • filtered_pixels_inside
#    • training_time
#
# 📊 CV Mean Metrics:
#    accuracy_mean: nan
#    accuracy_std: nan
#    precision_mean: nan
#    precision_std: nan
#    recall_mean: nan
#    recall_std: nan
#    f1_mean: nan
#    f1_std: nan
#
# 📈 Individual Fold Results:
#    Accuracy per fold: []
#    Number of folds completed: 0
#
#    ⚠️  WARNING: Expected 5 folds but only 0 completed!
#    This suggests some folds were skipped or failed.
#
# 🎯 Training pixels per class:
#    sediment: 541 pixels
#    rust: 58 pixels
#    dark_bomb: 424 pixels
#    dark_pit: 174 pixels
#    halo: 289 pixels
#
# 🧩 Spatial groups created: 16 total
#    Groups per class:
#       : 16 groups
#
# ================================================================================

# %% [markdown]
# ## Classify Crop Regions (Multi-Class)

# %%
# Classify all crop regions (multi-class mode)
multiclass_crop_results = []

for crop in crop_regions:
    results, track_min, track_max = classify_crop_region(
        cube, crop, confidence_threshold=0
    )
    multiclass_crop_results.append(
        {
            "crop": crop,
            "results": results,
            "track_min": track_min,
            "track_max": track_max,
        }
    )
# Out:
# 🔍 Classifying: Crop 1 (Bomb 2 - Rust)
#    Crop bounds: track [1196:1320], slit [0:500]
# ============================================================
# 🎯 SEGMENT CLASSIFICATION (no filtering, no validation)
# ============================================================
# 🎲 Confidence threshold: 0.00
#    (Pixels with max_prob < 0.00 → classified_unknown)
# ============================================================
# ============================================================
# 🎯 SEGMENT CLASSIFICATION WITH VALIDATION
# ============================================================
#
# 📊 Using wavelength subset: 119 wavelengths
#
# 📦 Datacube shape: (10027, 968, 119)
# 📏 Using data: corrected
# 🎯 Segment range: tracks 1196 to 1319
#
# 🔪 Extracting segment...
#    Segment shape: (124, 968, 119)
#
# 🤖 Classifying 120032 pixels...
#
# 📊 Using wavelength subset: 119 wavelengths
#
# 📦 Datacube shape: (10027, 968, 119)
# 📏 Using data: corrected
# 🎯 Segment range: tracks 1196 to 1319
#
# 🔪 Extracting segment...
#    Segment shape: (124, 968, 119)
#
# 🤖 Classifying 120032 pixels...
#    Classifying: 100%|█████████████████████████████████| 120032/120032 [00:19<00:00, 6240.50pixels/s]
# 🎲 Confidence Thresholding:
#    Threshold: 0.00
#    Unknown pixels: 0 (0.0%)
#    Confidence range: [0.331, 1.000]
#    ✅ Classification complete in 19.33 seconds
#
# 📊 Classification distribution (before filtering):
#    dark_bomb: 4485 pixels (3.7%)
#    dark_pit: 21148 pixels (17.6%)
#    halo: 14643 pixels (12.2%)
#    rust: 139 pixels (0.1%)
#    sediment: 79617 pixels (66.3%)
#
# ✅ Classification and validation complete!
# ============================================================
#
# 📊 Pixel counts for Crop 1 (Bomb 2 - Rust):
#    dark_bomb: 4485 pixels (3.7%)
#    dark_pit: 21148 pixels (17.6%)
#    halo: 14643 pixels (12.2%)
#    rust: 139 pixels (0.1%)
#    sediment: 79617 pixels (66.3%)
#
# 🔍 Classifying: Crop 2 (Bomb 3)
#    Crop bounds: track [5530:5654], slit [450:950]
# ============================================================
# 🎯 SEGMENT CLASSIFICATION (no filtering, no validation)
# ============================================================
# 🎲 Confidence threshold: 0.00
#    (Pixels with max_prob < 0.00 → classified_unknown)
# ============================================================
# ============================================================
# 🎯 SEGMENT CLASSIFICATION WITH VALIDATION
# ============================================================
#    dark_bomb: 4485 pixels (3.7%)
#    dark_pit: 21148 pixels (17.6%)
#    halo: 14643 pixels (12.2%)
#    rust: 139 pixels (0.1%)
#    sediment: 79617 pixels (66.3%)
#
# 🔍 Classifying: Crop 2 (Bomb 3)
#    Crop bounds: track [5530:5654], slit [450:950]
# ============================================================
# 🎯 SEGMENT CLASSIFICATION (no filtering, no validation)
# ============================================================
# 🎲 Confidence threshold: 0.00
#    (Pixels with max_prob < 0.00 → classified_unknown)
# ============================================================
# ============================================================
# 🎯 SEGMENT CLASSIFICATION WITH VALIDATION
# ============================================================
#
# 📊 Using wavelength subset: 119 wavelengths
#
# 📦 Datacube shape: (10027, 968, 119)
# 📏 Using data: corrected
# 🎯 Segment range: tracks 5530 to 5653
#
# 🔪 Extracting segment...
#    Segment shape: (124, 968, 119)
#
# 🤖 Classifying 120032 pixels...
#
# 📊 Using wavelength subset: 119 wavelengths
#
# 📦 Datacube shape: (10027, 968, 119)
# 📏 Using data: corrected
# 🎯 Segment range: tracks 5530 to 5653
#
# 🔪 Extracting segment...
#    Segment shape: (124, 968, 119)
#
# 🤖 Classifying 120032 pixels...
#    Classifying: 100%|█████████████████████████████████| 120032/120032 [00:19<00:00, 6006.59pixels/s]
# 🎲 Confidence Thresholding:
#    Threshold: 0.00
#    Unknown pixels: 0 (0.0%)
#    Confidence range: [0.332, 1.000]
#    ✅ Classification complete in 20.05 seconds
#
# 📊 Classification distribution (before filtering):
#    dark_bomb: 894 pixels (0.7%)
#    dark_pit: 11518 pixels (9.6%)
#    halo: 5621 pixels (4.7%)
#    rust: 25 pixels (0.0%)
#    sediment: 101974 pixels (85.0%)
#
# ✅ Classification and validation complete!
# ============================================================
#
# 📊 Pixel counts for Crop 2 (Bomb 3):
#    dark_bomb: 894 pixels (0.7%)
#    dark_pit: 11518 pixels (9.6%)
#    halo: 5621 pixels (4.7%)
#    rust: 25 pixels (0.0%)
#    sediment: 101974 pixels (85.0%)
#
# 🔍 Classifying: Crop 3 (Bomb 1)
#    Crop bounds: track [5098:5222], slit [363:863]
# ============================================================
# 🎯 SEGMENT CLASSIFICATION (no filtering, no validation)
# ============================================================
# 🎲 Confidence threshold: 0.00
#    (Pixels with max_prob < 0.00 → classified_unknown)
# ============================================================
# ============================================================
# 🎯 SEGMENT CLASSIFICATION WITH VALIDATION
# ============================================================
#
# 📊 Pixel counts for Crop 2 (Bomb 3):
#    dark_bomb: 894 pixels (0.7%)
#    dark_pit: 11518 pixels (9.6%)
#    halo: 5621 pixels (4.7%)
#    rust: 25 pixels (0.0%)
#    sediment: 101974 pixels (85.0%)
#
# 🔍 Classifying: Crop 3 (Bomb 1)
#    Crop bounds: track [5098:5222], slit [363:863]
# ============================================================
# 🎯 SEGMENT CLASSIFICATION (no filtering, no validation)
# ============================================================
# 🎲 Confidence threshold: 0.00
#    (Pixels with max_prob < 0.00 → classified_unknown)
# ============================================================
# ============================================================
# 🎯 SEGMENT CLASSIFICATION WITH VALIDATION
# ============================================================
#
# 📊 Using wavelength subset: 119 wavelengths
#
# 📦 Datacube shape: (10027, 968, 119)
# 📏 Using data: corrected
# 🎯 Segment range: tracks 5098 to 5221
#
# 🔪 Extracting segment...
#    Segment shape: (124, 968, 119)
#
# 🤖 Classifying 120032 pixels...
#
# 📊 Using wavelength subset: 119 wavelengths
#
# 📦 Datacube shape: (10027, 968, 119)
# 📏 Using data: corrected
# 🎯 Segment range: tracks 5098 to 5221
#
# 🔪 Extracting segment...
#    Segment shape: (124, 968, 119)
#
# 🤖 Classifying 120032 pixels...
#    Classifying: 100%|████████████████████████████████| 120032/120032 [00:10<00:00, 11960.13pixels/s]
# 🎲 Confidence Thresholding:
#    Threshold: 0.00
#    Unknown pixels: 0 (0.0%)
#    Confidence range: [0.330, 1.000]
#    ✅ Classification complete in 10.08 seconds
#
# 📊 Classification distribution (before filtering):
#    dark_bomb: 2811 pixels (2.3%)
#    dark_pit: 16222 pixels (13.5%)
#    halo: 13867 pixels (11.6%)
#    rust: 3 pixels (0.0%)
#    sediment: 87129 pixels (72.6%)
#
# ✅ Classification and validation complete!
# ============================================================
#
# 📊 Pixel counts for Crop 3 (Bomb 1):
#    dark_bomb: 2811 pixels (2.3%)
#    dark_pit: 16222 pixels (13.5%)
#    halo: 13867 pixels (11.6%)
#    rust: 3 pixels (0.0%)
#    sediment: 87129 pixels (72.6%)
#
# 🔍 Classifying: Crop 4 (Dark pits)
#    Crop bounds: track [655:779], slit [135:635]
# ============================================================
# 🎯 SEGMENT CLASSIFICATION (no filtering, no validation)
# ============================================================
# 🎲 Confidence threshold: 0.00
#    (Pixels with max_prob < 0.00 → classified_unknown)
# ============================================================
# ============================================================
# 🎯 SEGMENT CLASSIFICATION WITH VALIDATION
# ============================================================
#    dark_bomb: 2811 pixels (2.3%)
#    dark_pit: 16222 pixels (13.5%)
#    halo: 13867 pixels (11.6%)
#    rust: 3 pixels (0.0%)
#    sediment: 87129 pixels (72.6%)
#
# 🔍 Classifying: Crop 4 (Dark pits)
#    Crop bounds: track [655:779], slit [135:635]
# ============================================================
# 🎯 SEGMENT CLASSIFICATION (no filtering, no validation)
# ============================================================
# 🎲 Confidence threshold: 0.00
#    (Pixels with max_prob < 0.00 → classified_unknown)
# ============================================================
# ============================================================
# 🎯 SEGMENT CLASSIFICATION WITH VALIDATION
# ============================================================
#
# 📊 Using wavelength subset: 119 wavelengths
#
# 📦 Datacube shape: (10027, 968, 119)
# 📏 Using data: corrected
# 🎯 Segment range: tracks 655 to 778
#
# 🔪 Extracting segment...
#    Segment shape: (124, 968, 119)
#
# 🤖 Classifying 120032 pixels...
#
# 📊 Using wavelength subset: 119 wavelengths
#
# 📦 Datacube shape: (10027, 968, 119)
# 📏 Using data: corrected
# 🎯 Segment range: tracks 655 to 778
#
# 🔪 Extracting segment...
#    Segment shape: (124, 968, 119)
#
# 🤖 Classifying 120032 pixels...
#    Classifying: 100%|████████████████████████████████| 120032/120032 [00:09<00:00, 12898.26pixels/s]
# 🎲 Confidence Thresholding:
#    Threshold: 0.00
#    Unknown pixels: 0 (0.0%)
#    Confidence range: [0.335, 1.000]
#    ✅ Classification complete in 9.35 seconds
#
# 📊 Classification distribution (before filtering):
#    dark_bomb: 90 pixels (0.1%)
#    dark_pit: 4034 pixels (3.4%)
#    halo: 1630 pixels (1.4%)
#    rust: 4 pixels (0.0%)
#    sediment: 114274 pixels (95.2%)
#
# ✅ Classification and validation complete!
# ============================================================
#
# 📊 Pixel counts for Crop 4 (Dark pits):
#    dark_bomb: 90 pixels (0.1%)
#    dark_pit: 4034 pixels (3.4%)
#    halo: 1630 pixels (1.4%)
#    rust: 4 pixels (0.0%)
#    sediment: 114274 pixels (95.2%)
#    dark_bomb: 90 pixels (0.1%)
#    dark_pit: 4034 pixels (3.4%)
#    halo: 1630 pixels (1.4%)
#    rust: 4 pixels (0.0%)
#    sediment: 114274 pixels (95.2%)

# %%
# Convert multi-class classification results to ROI format and plot with plot_rgb
print(
    "📊 Plotting multi-class classification results with plot_rgb (includes uncertain class)..."
)

# Define class name mapping for display
class_display_names = {
    "dark_bomb": "dark area near bomb",
    "dark_pit": "isolated dark area",
    "halo": "halo",
    "rust": "rust",
    "sediment": "sediment",
}

# Define custom color map using hardcoded colors
roi_color_map = {
    "dark area near bomb": "#000000",  # COLOR_DARK - black
    "isolated dark area": "#3F3F3F",  # COLOR_DARK_SEDIMENT - medium-dark gray
    "halo": "#e5e57f",  # COLOR_HALO - yellow-ish
    "rust": "#b12222",  # COLOR_SEDIMENT - saddle brown
    "sediment": "#8b4513",  # COLOR_SEDIMENT - saddle brown
}

# For each crop, convert classification_map to ROI collection
for crop_result in multiclass_crop_results:
    crop = crop_result["crop"]
    results = crop_result["results"]
    track_min = crop_result["track_min"]

    # Create ROI collection from classification map WITH RENAMED CLASSES
    classification_rois = {}
    for class_name in results["class_names"]:
        mask = results["classification_map"] == class_name
        rows, cols = np.where(mask)
        # Convert to global coordinates (add track_min offset)
        pixels = [(col, row + track_min) for row, col in zip(rows, cols)]

        if len(pixels) > 0:
            # Apply class name mapping
            display_name = class_display_names.get(class_name, class_name)
            classification_rois[display_name] = pixels

    print(f"\n📍 {crop['name']}")
    print(f"   ROIs created: {list(classification_rois.keys())}")
    print(f"   Pixel counts:")
    for display_name in sorted(classification_rois.keys()):
        print(f"      {display_name}: {len(classification_rois[display_name])} pixels")

    # Plot with plot_rgb showing the classified region
    cube.plot_rgb(
        use_corrected=True,
        flip_axes=True,
        flip_horizontal=True,
        figsize=(30, 8.32),
        crop_center_track=crop["track"],
        crop_center_slit=crop["slit"],
        crop_width=crop["width"],
        crop_aspect_ratio=crop["aspect_ratio"],
        display_aspect_ratio=4.0,
        show_file_boundaries=False,
        roi_collection=classification_rois,
        roi_color_map=roi_color_map,  # ← Use custom hardcoded colors
        roi_legend_loc="outside",
        roi_overlay_mode="solid",  # ← Enable solid mode
        roi_solid_pixel_size=1,
        roi_marker_size=1,
        roi_legend_markersize=50,
        roi_marker_edgewidth=0,
        roi_show_numbers=False,
        roi_legend_show_counts=False,  # Don't show pixel counts in legend labels
    )
# Out:
# 📊 Plotting multi-class classification results with plot_rgb (includes uncertain class)...
#
# 📍 Crop 1 (Bomb 2 - Rust)
#    ROIs created: ['dark area near bomb', 'isolated dark area', 'halo', 'rust', 'sediment']
#    Pixel counts:
#       dark area near bomb: 4485 pixels
#       halo: 14643 pixels
#       isolated dark area: 21148 pixels
#       rust: 139 pixels
#       sediment: 79617 pixels
# ✨ Manual per-channel normalization applied:
#    Red:   [0.5300, 1.3500]
#    Green: [0.5800, 1.3700]
#    Blue:  [0.2000, 1.7300]
# ✨ Manual per-channel normalization applied:
#    Red:   [0.5300, 1.3500]
#    Green: [0.5800, 1.3700]
#    Blue:  [0.2000, 1.7300]
# 📐 Crop center: global track 1258 → local track 1258, slit 250
#    Aspect ratio correction: 4.00:1 (track:slit)
#    Slit pixels: 500, Track pixels: 124
# 🔍 Crop applied: track [1196:1320], slit [0:500]
#    Resulting shape: (124, 500, 3)
# 📊 Extent: x=[0, 500], y=[1196, 1320]
# 📐 Image shape after transformations: (124, 500, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=outside, roi_overlay_mode=solid
# 📐 Crop center: global track 1258 → local track 1258, slit 250
#    Aspect ratio correction: 4.00:1 (track:slit)
#    Slit pixels: 500, Track pixels: 124
# 🔍 Crop applied: track [1196:1320], slit [0:500]
#    Resulting shape: (124, 500, 3)
# 📊 Extent: x=[0, 500], y=[1196, 1320]
# 📐 Image shape after transformations: (124, 500, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=outside, roi_overlay_mode=solid
# 📍 Crop 2 (Bomb 3)
#    ROIs created: ['dark area near bomb', 'isolated dark area', 'halo', 'rust', 'sediment']
#    Pixel counts:
#       dark area near bomb: 894 pixels
#       halo: 5621 pixels
#       isolated dark area: 11518 pixels
#       rust: 25 pixels
#       sediment: 101974 pixels
# ✨ Manual per-channel normalization applied:
#    Red:   [0.5300, 1.3500]
#    Green: [0.5800, 1.3700]
#    Blue:  [0.2000, 1.7300]
# ✨ Manual per-channel normalization applied:
#    Red:   [0.5300, 1.3500]
#    Green: [0.5800, 1.3700]
#    Blue:  [0.2000, 1.7300]
# 📐 Crop center: global track 5592 → local track 5592, slit 700
#    Aspect ratio correction: 4.00:1 (track:slit)
#    Slit pixels: 500, Track pixels: 124
# 🔍 Crop applied: track [5530:5654], slit [450:950]
#    Resulting shape: (124, 500, 3)
# 📊 Extent: x=[450, 950], y=[5530, 5654]
# 📐 Image shape after transformations: (124, 500, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=outside, roi_overlay_mode=solid
# 📐 Crop center: global track 5592 → local track 5592, slit 700
#    Aspect ratio correction: 4.00:1 (track:slit)
#    Slit pixels: 500, Track pixels: 124
# 🔍 Crop applied: track [5530:5654], slit [450:950]
#    Resulting shape: (124, 500, 3)
# 📊 Extent: x=[450, 950], y=[5530, 5654]
# 📐 Image shape after transformations: (124, 500, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=outside, roi_overlay_mode=solid
# 📍 Crop 3 (Bomb 1)
#    ROIs created: ['dark area near bomb', 'isolated dark area', 'halo', 'rust', 'sediment']
#    Pixel counts:
#       dark area near bomb: 2811 pixels
#       halo: 13867 pixels
#       isolated dark area: 16222 pixels
#       rust: 3 pixels
#       sediment: 87129 pixels
# ✨ Manual per-channel normalization applied:
#    Red:   [0.5300, 1.3500]
#    Green: [0.5800, 1.3700]
#    Blue:  [0.2000, 1.7300]
# ✨ Manual per-channel normalization applied:
#    Red:   [0.5300, 1.3500]
#    Green: [0.5800, 1.3700]
#    Blue:  [0.2000, 1.7300]
# 📐 Crop center: global track 5160 → local track 5160, slit 613
#    Aspect ratio correction: 4.00:1 (track:slit)
#    Slit pixels: 500, Track pixels: 124
# 🔍 Crop applied: track [5098:5222], slit [363:863]
#    Resulting shape: (124, 500, 3)
# 📊 Extent: x=[363, 863], y=[5098, 5222]
# 📐 Image shape after transformations: (124, 500, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=outside, roi_overlay_mode=solid
# 📐 Crop center: global track 5160 → local track 5160, slit 613
#    Aspect ratio correction: 4.00:1 (track:slit)
#    Slit pixels: 500, Track pixels: 124
# 🔍 Crop applied: track [5098:5222], slit [363:863]
#    Resulting shape: (124, 500, 3)
# 📊 Extent: x=[363, 863], y=[5098, 5222]
# 📐 Image shape after transformations: (124, 500, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=outside, roi_overlay_mode=solid
# 📍 Crop 4 (Dark pits)
#    ROIs created: ['dark area near bomb', 'isolated dark area', 'halo', 'rust', 'sediment']
#    Pixel counts:
#       dark area near bomb: 90 pixels
#       halo: 1630 pixels
#       isolated dark area: 4034 pixels
#       rust: 4 pixels
#       sediment: 114274 pixels
# ✨ Manual per-channel normalization applied:
#    Red:   [0.5300, 1.3500]
#    Green: [0.5800, 1.3700]
#    Blue:  [0.2000, 1.7300]
# ✨ Manual per-channel normalization applied:
#    Red:   [0.5300, 1.3500]
#    Green: [0.5800, 1.3700]
#    Blue:  [0.2000, 1.7300]
# 📐 Crop center: global track 717 → local track 717, slit 385
#    Aspect ratio correction: 4.00:1 (track:slit)
#    Slit pixels: 500, Track pixels: 124
# 🔍 Crop applied: track [655:779], slit [135:635]
#    Resulting shape: (124, 500, 3)
# 📊 Extent: x=[135, 635], y=[655, 779]
# 📐 Image shape after transformations: (124, 500, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=outside, roi_overlay_mode=solid
# 📐 Crop center: global track 717 → local track 717, slit 385
#    Aspect ratio correction: 4.00:1 (track:slit)
#    Slit pixels: 500, Track pixels: 124
# 🔍 Crop applied: track [655:779], slit [135:635]
#    Resulting shape: (124, 500, 3)
# 📊 Extent: x=[135, 635], y=[655, 779]
# 📐 Image shape after transformations: (124, 500, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=outside, roi_overlay_mode=solid

# %% [markdown]
# ### 🎨 Proper Classification Visualization
#
# **Previous approach was WRONG:** Using ROI markers creates artificial symbols stacked on top of RGB image.
#
# **Correct approach:** Create a true classified image where each pixel has the color of its class - like any normal image!

# %%
def plot_classification_as_image(
    cube,
    crop,
    classification_map,
    class_names,
    figsize=(30, 8.32),
    flip_axes=True,
    flip_horizontal=True,
):
    """
    Plot classification results as a proper classified image (not ROI markers).
    Each pixel gets the color of its class - like a normal image.
    """
    import matplotlib.pyplot as plt
    import matplotlib.patches as mpatches
    import numpy as np

    # Define colors for each class
    class_colors = {
        "sediment": [0.6, 0.4, 0.2],  # Brown (same as 057)
        "rust": [0.8, 0.2, 0.1],  # Red-orange (rust halo)
        "dark_bomb": [0.1, 0.1, 0.1],  # Super black
        "dark_pit": [0.25, 0.25, 0.25],  # Slightly lighter gray than dark_bomb
        "halo": [0.9, 0.9, 0.5],  # Yellow
        "uncertain": [0.5, 0.0, 0.5],  # Purple (changed from gray)
        # For 057 compatibility (3-class model):
        "dark": [0.1, 0.1, 0.1],  # Same as dark_bomb (super black)
        "bombs": [0.12, 0.56, 0.93],  # Dodger blue (#1E90FF converted to RGB)
        "classified_bombs": [0.12, 0.56, 0.93],  # Same blue
        "training_bombs": [0.12, 0.56, 0.93],  # Same blue
        "filtered_bombs": [0.12, 0.56, 0.93],  # Same blue
    }

    # Create RGB image from classification map
    height, width = classification_map.shape
    rgb_image = np.zeros((height, width, 3))

    for class_name in class_names:
        mask = classification_map == class_name
        color = class_colors.get(class_name, [0.5, 0.5, 0.5])  # Default gray
        rgb_image[mask] = color

    # Apply flipping to match plot_rgb behavior
    # Step 1: Transpose to match plot_rgb's initial .T.copy()
    rgb_image = rgb_image.transpose(1, 0, 2)  # (slits, tracks, 3)

    # Step 2: Apply flip_axes (like plot_rgb does)
    if flip_axes:
        rgb_image = rgb_image.transpose(1, 0, 2)  # Back to (tracks, slits, 3)

    # Step 3: Apply flip_horizontal (like plot_rgb does)
    if flip_horizontal:
        rgb_image = np.flip(rgb_image, axis=1)  # Flip along axis 1

    # Calculate extent in global coordinates
    half_width_slit = crop["width"] // 2
    half_width_track = int(crop["width"] / crop["aspect_ratio"] / 2)

    slit_min = crop["slit"] - half_width_slit
    slit_max = crop["slit"] + half_width_slit
    track_min = crop["track"] - half_width_track
    track_max = crop["track"] + half_width_track

    if flip_axes:
        # When axes flipped: x=slit, y=track (matches plot_rgb)
        extent = [slit_min, slit_max, track_min, track_max]
        xlabel, ylabel = "Slit Pixel Index", "Track Index"
    else:
        # Normal: x=track, y=slit
        extent = [track_min, track_max, slit_min, slit_max]
        xlabel, ylabel = "Track Index", "Slit Pixel Index"

    # Create figure
    fig, ax = plt.subplots(figsize=figsize)

    # Display the classified image
    im = ax.imshow(
        rgb_image,
        extent=extent,
        origin="lower",
        aspect=crop.get("display_aspect_ratio", 4.0),
        interpolation="nearest",
    )

    ax.set_xlabel(xlabel, fontsize=12)
    ax.set_ylabel(ylabel, fontsize=12)
    ax.set_title(f"Classification: {crop['name']}", fontsize=14, fontweight="bold")

    # Create legend with class colors
    legend_patches = []
    for class_name in class_names:
        count = np.sum(classification_map == class_name)
        color = class_colors.get(class_name, [0.5, 0.5, 0.5])
        label = f"{class_name} ({count} px)"
        legend_patches.append(mpatches.Patch(color=color, label=label))

    ax.legend(
        handles=legend_patches,
        loc="center left",
        bbox_to_anchor=(1, 0.5),
        frameon=True,
        fontsize=11,
    )

    plt.tight_layout()
    plt.show()

    return fig, ax


# Plot multi-class classification results as proper images
print("📊 Plotting multi-class classification as IMAGES (not ROI markers)...")

for crop_result in multiclass_crop_results:
    crop = crop_result["crop"]
    results = crop_result["results"]

    print(f"\n📍 {crop['name']}")
    print(f"   Classes: {results['class_names']}")

    # CRITICAL FIX: Crop the classification_map to the slit range!
    # classify_segment only crops track dimension, not slit dimension
    half_width_slit = crop["width"] // 2
    crop_slit_min = max(0, crop["slit"] - half_width_slit)
    crop_slit_max = min(
        results["classification_map"].shape[1], crop["slit"] + half_width_slit
    )

    # Crop the classification map to the slit range
    cropped_classification_map = results["classification_map"][
        :, crop_slit_min:crop_slit_max
    ]

    print(f"   Original shape: {results['classification_map'].shape}")
    print(
        f"   Cropped to slit [{crop_slit_min}:{crop_slit_max}]: {cropped_classification_map.shape}"
    )
    print(f"   Pixel counts:")
    for class_name in results["class_names"]:
        count = np.sum(cropped_classification_map == class_name)
        percentage = 100.0 * count / cropped_classification_map.size
        print(f"      {class_name}: {count} pixels ({percentage:.1f}%)")

    # Plot as proper classified image with CROPPED data
    plot_classification_as_image(
        cube,
        crop,
        cropped_classification_map,  # Use CROPPED classification map!
        results["class_names"],
        figsize=(30, 7.18),
        flip_axes=True,
        flip_horizontal=True,
    )
# Out:
# 📊 Plotting multi-class classification as IMAGES (not ROI markers)...
#
# 📍 Crop 1 (Bomb 2 - Rust)
#    Classes: ['dark_bomb', 'dark_pit', 'halo', 'rust', 'sediment']
#    Original shape: (124, 968)
#    Cropped to slit [0:500]: (124, 500)
#    Pixel counts:
#       dark_bomb: 4441 pixels (7.2%)
#       dark_pit: 9186 pixels (14.8%)
#       halo: 11928 pixels (19.2%)
#       rust: 139 pixels (0.2%)
#       sediment: 36306 pixels (58.6%)
# 📍 Crop 2 (Bomb 3)
#    Classes: ['dark_bomb', 'dark_pit', 'halo', 'rust', 'sediment']
#    Original shape: (124, 968)
#    Cropped to slit [450:950]: (124, 500)
#    Pixel counts:
#       dark_bomb: 872 pixels (1.4%)
#       dark_pit: 4750 pixels (7.7%)
#       halo: 3830 pixels (6.2%)
#       rust: 0 pixels (0.0%)
#       sediment: 52548 pixels (84.8%)
# 📍 Crop 3 (Bomb 1)
#    Classes: ['dark_bomb', 'dark_pit', 'halo', 'rust', 'sediment']
#    Original shape: (124, 968)
#    Cropped to slit [363:863]: (124, 500)
#    Pixel counts:
#       dark_bomb: 2803 pixels (4.5%)
#       dark_pit: 9833 pixels (15.9%)
#       halo: 12175 pixels (19.6%)
#       rust: 3 pixels (0.0%)
#       sediment: 37186 pixels (60.0%)
# 📍 Crop 4 (Dark pits)
#    Classes: ['dark_bomb', 'dark_pit', 'halo', 'rust', 'sediment']
#    Original shape: (124, 968)
#    Cropped to slit [135:635]: (124, 500)
#    Pixel counts:
#       dark_bomb: 2 pixels (0.0%)
#       dark_pit: 2092 pixels (3.4%)
#       halo: 484 pixels (0.8%)
#       rust: 0 pixels (0.0%)
#       sediment: 59422 pixels (95.8%)

# %%
# Test: Compare plot_rgb vs plot_classification_as_image
print("Testing zoom/extent comparison...")

# Use the first crop region for testing
test_crop = crop_regions[0]
test_results = multiclass_crop_results[0]["results"]

print(f"\nTest crop parameters:")
print(f"  Track: {test_crop['track']}, Slit: {test_crop['slit']}")
print(f"  Width: {test_crop['width']}, Aspect ratio: {test_crop['aspect_ratio']}")

# CRITICAL: Crop the classification_map to match the slit range!
# classify_segment only crops track dimension, not slit dimension
half_width_slit = test_crop["width"] // 2
crop_slit_min = max(0, test_crop["slit"] - half_width_slit)
crop_slit_max = min(
    test_results["classification_map"].shape[1], test_crop["slit"] + half_width_slit
)

# Crop the classification map to the slit range
cropped_classification_map = test_results["classification_map"][
    :, crop_slit_min:crop_slit_max
]

print(f"\n🔍 DEBUG: Classification map shapes:")
print(f"   Original: {test_results['classification_map'].shape}")
print(
    f"   Cropped to slit [{crop_slit_min}:{crop_slit_max}]: {cropped_classification_map.shape}"
)

# 1. Reference: plot_rgb with same parameters
print("\n1. Plotting with plot_rgb (reference)...")
cube.plot_rgb(
    use_corrected=True,
    flip_axes=True,
    flip_horizontal=True,
    crop_center_track=test_crop["track"],
    crop_center_slit=test_crop["slit"],
    crop_width=test_crop["width"],
    crop_aspect_ratio=test_crop["aspect_ratio"],
    display_aspect_ratio=4.0,
    figsize=(30, 8.32),
)

# 2. Custom: plot_classification_as_image with same parameters
print("\n2. Plotting with plot_classification_as_image (custom)...")
plot_classification_as_image(
    cube,
    test_crop,
    cropped_classification_map,  # Use CROPPED classification map!
    test_results["class_names"],
    figsize=(30, 8.32),
    flip_axes=True,
    flip_horizontal=True,
)

print("\n✓ Both plots generated. Check if they have the same zoom level and extent!")
# Out:
# Testing zoom/extent comparison...
#
# Test crop parameters:
#   Track: 1258, Slit: 250
#   Width: 500, Aspect ratio: 4
#
# 🔍 DEBUG: Classification map shapes:
#    Original: (124, 968)
#    Cropped to slit [0:500]: (124, 500)
#
# 1. Plotting with plot_rgb (reference)...
# ✨ Manual per-channel normalization applied:
#    Red:   [0.5300, 1.3500]
#    Green: [0.5800, 1.3700]
#    Blue:  [0.2000, 1.7300]
# 📐 Crop center: global track 1258 → local track 1258, slit 250
#    Aspect ratio correction: 4.00:1 (track:slit)
#    Slit pixels: 500, Track pixels: 124
# 🔍 Crop applied: track [1196:1320], slit [0:500]
#    Resulting shape: (124, 500, 3)
# 📊 Extent: x=[0, 500], y=[1196, 1320]
# 📐 Image shape after transformations: (124, 500, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=best, roi_overlay_mode=markers
# 🐛 DEBUG: Creating legend (should NOT happen in solid mode!)
# ✨ Manual per-channel normalization applied:
#    Red:   [0.5300, 1.3500]
#    Green: [0.5800, 1.3700]
#    Blue:  [0.2000, 1.7300]
# 📐 Crop center: global track 1258 → local track 1258, slit 250
#    Aspect ratio correction: 4.00:1 (track:slit)
#    Slit pixels: 500, Track pixels: 124
# 🔍 Crop applied: track [1196:1320], slit [0:500]
#    Resulting shape: (124, 500, 3)
# 📊 Extent: x=[0, 500], y=[1196, 1320]
# 📐 Image shape after transformations: (124, 500, 3)
# 🐛 DEBUG legend: has_overlays=True, roi_legend_loc=best, roi_overlay_mode=markers
# 🐛 DEBUG: Creating legend (should NOT happen in solid mode!)
# e:\mjosa_complete\gref4hsi\mjosa_code\utils\uhi\georef.py:8430: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   legend = plt.legend(
# 2. Plotting with plot_classification_as_image (custom)...
# ✓ Both plots generated. Check if they have the same zoom level and extent!

# %% [markdown]
# ---
#
# ## 💾 SAVE CLASSIFICATION RESULTS (Run this once!)
#
# Save the classification results so you can test plotting in dev31 without rerunning the pipeline.

# %%
import pickle
import os

# Create saved_data directory if it doesn't exist
os.makedirs("./saved_data", exist_ok=True)

# Save classification results
save_data = {
    "multiclass_crop_results": multiclass_crop_results,
    "crop_regions": crop_regions,
}

save_file = "./saved_data/classification_results_028.pkl"
with open(save_file, "wb") as f:
    pickle.dump(save_data, f)

print(f"✅ Classification results saved to {save_file}")
print(f"   {len(multiclass_crop_results)} crop results")
print(f"\n📝 Now you can use dev31 for quick plotting tests!")
# Out:
# ✅ Classification results saved to ./saved_data/classification_results_028.pkl
#    4 crop results
#
# 📝 Now you can use dev31 for quick plotting tests!

# %% [markdown]
# ## 💾 SAVE SVM MODEL (for dev32)
#
# Save the trained SVM model so it can be applied to other transects (e.g., 057 in dev32).

# %%
# Debug: Check available keys in cv_results_multiclass
print("🔍 Debug: Available keys in cv_results_multiclass:")
print(cv_results_multiclass.keys())
print(
    "\nThis will help us see if it's 'trained_model', 'best_model', or something else."
)
# Out:
# 🔍 Debug: Available keys in cv_results_multiclass:
# dict_keys(['model', 'label_encoder', 'class_names', 'cv_results', 'cv_mean_metrics', 'best_params', 'training_pixels_per_class', 'filtered_training_rois', 'spatial_groups_roi_collection', 'filtered_pixels_outside', 'filtered_pixels_inside', 'training_time'])
#
# This will help us see if it's 'trained_model', 'best_model', or something else.

# %%
import pickle
import os

# Create saved_data directory if it doesn't exist
os.makedirs("./saved_data", exist_ok=True)

# Prepare model data for saving
model_save_data = {
    "model": cv_results_multiclass["model"],  # FIXED: correct key is "model"
    "label_encoder": cv_results_multiclass[
        "label_encoder"
    ],  # ADDED: needed for classification
    "class_names": list(mapped_training_rois.keys()),  # Class names
    "best_params": cv_results_multiclass["best_params"],  # C and gamma
    "cv_metrics": cv_results_multiclass["cv_mean_metrics"],  # Performance metrics
    "preprocessing": {
        "smoothing_method": "gaussian",
        "smoothing_sigma": 5.0,
        "wavelength_range": (490, 700),  # nm
        "normalization": None,  # No L2 normalization
    },
    "training_info": {
        "transect": "028",
        "num_training_pixels": cv_results_multiclass["training_pixels_per_class"],
        "roi_mapping": roi_mapping,
    },
}

# Save the model
model_file = "./saved_data/svm_model_028_multiclass.pkl"
with open(model_file, "wb") as f:
    pickle.dump(model_save_data, f)

print(f"✅ SVM model saved to {model_file}")
print(f"\n📊 Model Info:")
print(f"   Classes: {model_save_data['class_names']}")
print(f"   Best C: {model_save_data['best_params']['C']}")
print(f"   Best gamma: {model_save_data['best_params']['gamma']}")
print(f"   Accuracy: {model_save_data['cv_metrics']['accuracy_mean']:.3f}")
print(f"\n📝 Now you can use this model in dev32 to classify transect 057!")
# Out:
# ✅ SVM model saved to ./saved_data/svm_model_028_multiclass.pkl
#
# 📊 Model Info:
#    Classes: ['sediment', 'rust', 'dark_bomb', 'dark_pit', 'halo']
#    Best C: 10
#    Best gamma: 0.1
#    Accuracy: nan
#
# 📝 Now you can use this model in dev32 to classify transect 057!

# %% [markdown]
# ---
#
# ## 📊 COMPREHENSIVE CLASSIFICATION ANALYSIS
#
# Generate detailed metrics, visualizations, and statistics for the classification results.

# %%
# Import the comprehensive analysis function
from utils.uhi.classification_analysis import analyze_classification_results

# For notebook 9, we have crop-based classification results
# We need to combine all crop results or analyze the most representative one
print("=" * 80)
print("📊 CLASSIFICATION ANALYSIS: 028 TRANSECT (5-CLASS MODEL)")
print("=" * 80)
print(f"Model: SVM trained on transect 028")
print(
    f"Classes: {list(mapped_training_rois.keys()) if 'mapped_training_rois' in globals() else 'N/A'}"
)
print(f"Application: Same transect (028) with 4 crop regions")
print("=" * 80)

# Try to find classification results from crop classifications
if "multiclass_crop_results" in globals() and len(multiclass_crop_results) > 0:
    # Analyze each crop region separately
    for i, crop_result in enumerate(multiclass_crop_results, 1):
        crop_name = crop_result["crop"]["name"]
        print(f"\n{'='*80}")
        print(f"CROP REGION {i}/4: {crop_name}")
        print(f"{'='*80}")

        cls_map = crop_result["results"]["classification_map"]
        class_names_var = crop_result["results"]["class_names"]

        metrics = analyze_classification_results(
            classification_map=cls_map,
            filtered_map=None,  # No filtering for crop regions
            class_names=class_names_var,
            track_start=0,
            figsize=(14, 6),
            show_plots=True,
            save_csv=f"./saved_data/classification_summary_028_crop_{i}.csv",
        )

        print(f"\n📝 CROP {i} SUMMARY:")
        print(f"   Total pixels: {metrics['total_pixels']:,}")
        for cn in class_names_var:
            count = metrics["counts_before"].get(cn, 0)
            pct = 100.0 * count / metrics["total_pixels"]
            print(f"   • {cn}: {count:,} pixels ({pct:.2f}%)")
        print("=" * 80)

    print("\n" + "=" * 80)
    print("📝 OVERALL NARRATIVE SUMMARY")
    print("=" * 80)
    print(f"This is the 028 model applied to 4 crop regions on its own transect.")
    print(
        f"The model distinguishes 5 classes: sediment, rust, dark_bomb, dark_pit, halo."
    )
    print(
        f"Each crop region shows different class distributions based on local seafloor features."
    )
    print("=" * 80)
else:
    print("❌ ERROR: multiclass_crop_results not found!")
    print("   Please run the crop classification cells first.")
# Out:
# ================================================================================
# 📊 CLASSIFICATION ANALYSIS: 028 TRANSECT (5-CLASS MODEL)
# ================================================================================
# Model: SVM trained on transect 028
# Classes: ['sediment', 'rust', 'dark_bomb', 'dark_pit', 'halo']
# Application: Same transect (028) with 4 crop regions
# ================================================================================
#
# ================================================================================
# CROP REGION 1/4: Crop 1 (Bomb 2 - Rust)
# ================================================================================
#
# ================================================================================
# CLASSIFICATION ANALYSIS SUMMARY
# ================================================================================
# Total pixels in map: 120,032
# Unknown / unclassified (before): 0 pixels (0.00%)
#
# Per-class counts (before filtering):
#   dark_bomb: 4,485 pixels (3.74%)
#   dark_pit: 21,148 pixels (17.62%)
#   halo: 14,643 pixels (12.20%)
#   rust: 139 pixels (0.12%)
#   sediment: 79,617 pixels (66.33%)
#
# Cluster statistics (connected components):
#   dark_bomb: 37 clusters, largest=4372 px, smallest=1 px, mean=121.2 px
#   dark_pit: 1149 clusters, largest=14024 px, smallest=1 px, mean=18.4 px
#   halo: 2500 clusters, largest=9492 px, smallest=1 px, mean=5.9 px
#   rust: 3 clusters, largest=137 px, smallest=1 px, mean=46.3 px
#   sediment: 529 clusters, largest=77584 px, smallest=1 px, mean=150.5 px
#
# 💾 Saved CSV summary to: ./saved_data/classification_summary_028_crop_1.csv
# ================================================================================
# ✅ Analysis complete. Returned metrics dictionary.
# ================================================================================
#
# 📝 CROP 1 SUMMARY:
#    Total pixels: 120,032
#    • dark_bomb: 4,485 pixels (3.74%)
#    • dark_pit: 21,148 pixels (17.62%)
#    • halo: 14,643 pixels (12.20%)
#    • rust: 139 pixels (0.12%)
#    • sediment: 79,617 pixels (66.33%)
# ================================================================================
#
# ================================================================================
# CROP REGION 2/4: Crop 2 (Bomb 3)
# ================================================================================
#
# ================================================================================
# CLASSIFICATION ANALYSIS SUMMARY
# ================================================================================
# Total pixels in map: 120,032
# Unknown / unclassified (before): 0 pixels (0.00%)
#
# Per-class counts (before filtering):
#   dark_bomb: 894 pixels (0.74%)
#   dark_pit: 11,518 pixels (9.60%)
#   halo: 5,621 pixels (4.68%)
#   rust: 25 pixels (0.02%)
#   sediment: 101,974 pixels (84.96%)
#
# Cluster statistics (connected components):
#   dark_bomb: 19 clusters, largest=732 px, smallest=1 px, mean=47.1 px
#   dark_pit: 1205 clusters, largest=1693 px, smallest=1 px, mean=9.6 px
#   halo: 1758 clusters, largest=2120 px, smallest=1 px, mean=3.2 px
#   rust: 2 clusters, largest=23 px, smallest=2 px, mean=12.5 px
#   sediment: 287 clusters, largest=101315 px, smallest=1 px, mean=355.3 px
#
# 💾 Saved CSV summary to: ./saved_data/classification_summary_028_crop_2.csv
# ================================================================================
# ✅ Analysis complete. Returned metrics dictionary.
# ================================================================================
#
# 📝 CROP 2 SUMMARY:
#    Total pixels: 120,032
#    • dark_bomb: 894 pixels (0.74%)
#    • dark_pit: 11,518 pixels (9.60%)
#    • halo: 5,621 pixels (4.68%)
#    • rust: 25 pixels (0.02%)
#    • sediment: 101,974 pixels (84.96%)
# ================================================================================
#
# ================================================================================
# CROP REGION 3/4: Crop 3 (Bomb 1)
# ================================================================================
#
# ================================================================================
# CLASSIFICATION ANALYSIS SUMMARY
# ================================================================================
# Total pixels in map: 120,032
# Unknown / unclassified (before): 0 pixels (0.00%)
#
# Per-class counts (before filtering):
#   dark_bomb: 2,811 pixels (2.34%)
#   dark_pit: 16,222 pixels (13.51%)
#   halo: 13,867 pixels (11.55%)
#   rust: 3 pixels (0.00%)
#   sediment: 87,129 pixels (72.59%)
#
# Cluster statistics (connected components):
#   dark_bomb: 27 clusters, largest=2735 px, smallest=1 px, mean=104.1 px
#   dark_pit: 1169 clusters, largest=2207 px, smallest=1 px, mean=13.9 px
#   halo: 2165 clusters, largest=9584 px, smallest=1 px, mean=6.4 px
#   rust: 3 clusters, largest=1 px, smallest=1 px, mean=1.0 px
#   sediment: 442 clusters, largest=56083 px, smallest=1 px, mean=197.1 px
#
# 💾 Saved CSV summary to: ./saved_data/classification_summary_028_crop_3.csv
# ================================================================================
# ✅ Analysis complete. Returned metrics dictionary.
# ================================================================================
#
# 📝 CROP 3 SUMMARY:
#    Total pixels: 120,032
#    • dark_bomb: 2,811 pixels (2.34%)
#    • dark_pit: 16,222 pixels (13.51%)
#    • halo: 13,867 pixels (11.55%)
#    • rust: 3 pixels (0.00%)
#    • sediment: 87,129 pixels (72.59%)
# ================================================================================
#
# ================================================================================
# CROP REGION 4/4: Crop 4 (Dark pits)
# ================================================================================
#
# ================================================================================
# CLASSIFICATION ANALYSIS SUMMARY
# ================================================================================
# Total pixels in map: 120,032
# Unknown / unclassified (before): 0 pixels (0.00%)
#
# Per-class counts (before filtering):
#   dark_bomb: 90 pixels (0.07%)
#   dark_pit: 4,034 pixels (3.36%)
#   halo: 1,630 pixels (1.36%)
#   rust: 4 pixels (0.00%)
#   sediment: 114,274 pixels (95.20%)
#
# Cluster statistics (connected components):
#   dark_bomb: 6 clusters, largest=85 px, smallest=1 px, mean=15.0 px
#   dark_pit: 479 clusters, largest=1575 px, smallest=1 px, mean=8.4 px
#   halo: 761 clusters, largest=97 px, smallest=1 px, mean=2.1 px
#   rust: 1 clusters, largest=4 px, smallest=4 px, mean=4.0 px
#   sediment: 65 clusters, largest=114125 px, smallest=1 px, mean=1758.1 px
#
# 💾 Saved CSV summary to: ./saved_data/classification_summary_028_crop_4.csv
# ================================================================================
# ✅ Analysis complete. Returned metrics dictionary.
# ================================================================================
#
# 📝 CROP 4 SUMMARY:
#    Total pixels: 120,032
#    • dark_bomb: 90 pixels (0.07%)
#    • dark_pit: 4,034 pixels (3.36%)
#    • halo: 1,630 pixels (1.36%)
#    • rust: 4 pixels (0.00%)
#    • sediment: 114,274 pixels (95.20%)
# ================================================================================
#
# ================================================================================
# 📝 OVERALL NARRATIVE SUMMARY
# ================================================================================
# This is the 028 model applied to 4 crop regions on its own transect.
# The model distinguishes 5 classes: sediment, rust, dark_bomb, dark_pit, halo.
# Each crop region shows different class distributions based on local seafloor features.
# ================================================================================

# %%
here
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 here
#
# NameError: name 'here' is not defined

# %% [markdown]
# ---
#
# ## 💾 EXPORT COVERAGE STATISTICS
#
# Save classification coverage percentages for each crop region to CSV for cross-notebook comparison.

# %%
# Export coverage statistics for notebook 9 (028 on 028 crops)
import pandas as pd
import os

# Create coverage_stats directory if it doesn't exist
os.makedirs("./coverage_stats", exist_ok=True)

if "multiclass_crop_results" in globals() and len(multiclass_crop_results) > 0:
    # Calculate coverage percentages for each crop region
    all_coverage_data = []

    for i, crop_result in enumerate(multiclass_crop_results):
        crop = crop_result["crop"]
        results = crop_result["results"]
        total_pixels = results["classification_map"].size

        # Calculate crop region bounds for naming
        crop_name = crop["name"]

        for class_name in results["class_names"]:
            count = np.sum(results["classification_map"] == class_name)
            percentage = 100.0 * count / total_pixels
            all_coverage_data.append(
                {
                    "notebook": "9_svm_028",
                    "model": "028_on_028",
                    "region": crop_name,
                    "class": class_name,
                    "pixels": count,
                    "percentage": percentage,
                }
            )

    # Save to CSV
    df_coverage = pd.DataFrame(all_coverage_data)
    output_file = "./coverage_stats/028_on_028_coverage.csv"
    df_coverage.to_csv(output_file, index=False)

    print("✅ Coverage statistics exported!")
    print(f"   File: {output_file}")
    print(f"\n📊 Coverage Summary by Region:")

    # Print summary table grouped by region
    for region in df_coverage["region"].unique():
        print(f"\n{region}:")
        region_data = df_coverage[df_coverage["region"] == region]
        for _, row in region_data.iterrows():
            print(f"  {row['class']:15s}: {row['percentage']:6.2f}%")
else:
    print("❌ ERROR: multiclass_crop_results not found!")
    print("   Run the crop classification cells first.")
