# %%
from functions import *

# %% [markdown]
# show what the augmentation does for a single segment. Only augmented data is plotted

# %%
# Usage example:
augment_all_segments(
    base_root=r"E:\mjosa\29\training_data_new\fundation\only_1_segment\file",
    out_root=r"E:\mjosa\29\training_data_new\fundation\only_1_segment\augmented",
    max_workers=6,
)

plot_all_npz_segments(
    r"E:\mjosa\29\training_data_new\fundation\only_1_segment\augmented"
)
# Out:
# 🛠️ Augmenting 1 files with 6 workers...
# 100%|██████████| 1/1 [00:00<00:00,  2.56it/s]
# ✅ Done in 0.39 seconds

# %% [markdown]
# use to augment the actual data

# %%
# Usage example:
augment_all_segments(
    base_root=r"E:\mjosa\29\training_data_new\fundation\reflectance",
    out_root=r"E:\mjosa\29\training_data_new\fundation\augmented",
)
# Out:
# 🛠️ Augmenting 410 files with 4 workers...
# 100%|██████████| 410/410 [01:52<00:00,  3.65it/s]
# ✅ Done in 112.39 seconds
