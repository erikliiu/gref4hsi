# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt

sys.path.append(os.path.abspath("../"))
from utils.gref_pipeline.georef import *

sys.path.append(os.path.abspath("../../"))
from gref_pipeline import config

# %%
# Load 028 transect
transect = load_transect(r"E:\mjosa_new_oct_2025\use_gref4hsi\028\output")
transect.list_files()

# Select 028_5 for NDI analysis
cube = transect.select_files(
    [
        "rad_uhi_20241029_125028_1",
        "rad_uhi_20241029_125028_2",
        "rad_uhi_20241029_125028_3",
        "rad_uhi_20241029_125028_4",
        "rad_uhi_20241029_125028_5",
    ]
)
cube.describe()
# Out:
# 📋 Files in output (corrected=False):
#  1. rad_uhi_20241029_125028_1  | shape=(1329, 968, 210)  | has_georef=True
#  2. rad_uhi_20241029_125028_2  | shape=(2011, 968, 210)  | has_georef=True
#  3. rad_uhi_20241029_125028_3  | shape=(2282, 968, 210)  | has_georef=True
#  4. rad_uhi_20241029_125028_4  | shape=(2457, 968, 210)  | has_georef=True
#  5. rad_uhi_20241029_125028_5  | shape=(1948, 968, 210)  | has_georef=True
# 🔄 Rebuilding grids from georef hits for selected files...
#    • rad_uhi_20241029_125028_1
#   rad_uhi_20241029_125028_1: Using GRIDDED format (T=1329, S=968)
#    • rad_uhi_20241029_125028_2
#   rad_uhi_20241029_125028_2: Using GRIDDED format (T=2011, S=968)
#    • rad_uhi_20241029_125028_3
#   rad_uhi_20241029_125028_3: Using GRIDDED format (T=2282, S=968)
#    • rad_uhi_20241029_125028_4
#   rad_uhi_20241029_125028_4: Using GRIDDED format (T=2457, S=968)
#    • rad_uhi_20241029_125028_5
#   rad_uhi_20241029_125028_5: Using GRIDDED format (T=1948, S=968)
# ✅ Combined shapes: X/Y/Z (10027, 968), RGB (10027, 968)
# 🔄 Loading full hyperspectral cube...
#    • Loading rad_uhi_20241029_125028_1...
#    • Loading rad_uhi_20241029_125028_2...
#    • Loading rad_uhi_20241029_125028_3...
#    • Loading rad_uhi_20241029_125028_4...
#    • Loading rad_uhi_20241029_125028_5...
# ✅ Loaded full cube: (10027, 968, 210) (T × S × B)
#
# === Combined_output ===
# Tracks × Slits: 10027 × 968
# RGB coverage: R/G/B finite ratios 0.99/0.99/0.99
#
# 📋 File boundaries:
#   rad_uhi_20241029_125028_1: tracks 0–1328 (1329)
#   rad_uhi_20241029_125028_2: tracks 1329–3339 (2011)
#   rad_uhi_20241029_125028_3: tracks 3340–5621 (2282)
#   rad_uhi_20241029_125028_4: tracks 5622–8078 (2457)
#   rad_uhi_20241029_125028_5: tracks 8079–10026 (1948)

# %%
cube.apply_illumination_correction_v2()
# Out:
# 🔄 Using V2 algorithm (pandas rolling median, memory-efficient)
# ✅ Illumination correction already applied with window=500, strength=1.0
#    Loading from disk...
# 📂 Loading saved illumination correction from 5 files...
#    rad_uhi_20241029_125028_1: window=500, strength=1.0
#    rad_uhi_20241029_125028_2: window=500, strength=1.0
#    rad_uhi_20241029_125028_3: window=500, strength=1.0
#    rad_uhi_20241029_125028_4: window=500, strength=1.0
#    rad_uhi_20241029_125028_5: window=500, strength=1.0
# ✅ Loaded illumination correction from disk
# array([[[0.00000000e+00, 8.00363868e-02, 3.38807702e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          9.79862548e-03, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 6.24412894e-01, 0.00000000e+00, ...,
#          2.43312144e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          4.49576187e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 1.18552887e+00, ...,
#          2.34972164e-01, 0.00000000e+00, 0.00000000e+00],
#         [9.47257459e-01, 0.00000000e+00, 0.00000000e+00, ...,
#          3.01917344e-01, 0.00000000e+00, 0.00000000e+00]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          1.15298668e+02, 1.14839525e+01, 3.45664215e-03],
#         [0.00000000e+00, 1.00000000e+00, 9.11504328e-01, ...,
#          2.32659373e-02, 2.43540382e+00, 4.57144403e+00],
#         [0.00000000e+00, 3.06572890e+00, 0.00000000e+00, ...,
#          4.02547836e+00, 1.90113354e-02, 8.68073642e-01],
#         ...,
#         [1.75438598e-02, 0.00000000e+00, 1.00000000e+00, ...,
#          6.55555439e+00, 1.33838160e-02, 2.99430227e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          1.98360729e+00, 1.40843954e+01, 2.13704319e+01],
#         [0.00000000e+00, 1.98199582e+00, 0.00000000e+00, ...,
#          1.00750742e+01, 3.09236441e-03, 1.81136024e+00]],
#
#        [[0.00000000e+00, 4.21987295e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 1.30968695e+01, 1.53628865e-03],
#         [0.00000000e+00, 1.38329611e+01, 2.54227202e-02, ...,
#          0.00000000e+00, 3.75119090e+00, 1.27472639e+00],
#         [0.00000000e+00, 7.00939274e+00, 3.00617886e+00, ...,
#          3.63057196e-01, 1.52854491e-02, 2.05932403e+00],
#         ...,
#         [0.00000000e+00, 7.80528212e+00, 0.00000000e+00, ...,
#          4.70339119e-01, 0.00000000e+00, 1.28490031e+00],
#         [0.00000000e+00, 3.92014837e+00, 1.46382201e+00, ...,
#          2.85792470e+00, 1.22151966e+01, 3.82714182e-01],
#         [0.00000000e+00, 3.72013187e+00, 0.00000000e+00, ...,
#          8.50438881e+00, 1.39315668e-02, 1.81136024e+00]],
#
#        ...,
#
#        [[5.45343924e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 7.10688114e+00, 1.16181439e-02],
#         [1.02409277e+01, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 4.66794825e+00, 7.25002098e+00],
#         [5.08758736e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 8.85338783e+00, 6.50349081e-01],
#         ...,
#         [1.40816319e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          9.19671249e+00, 1.27653405e-02, 3.60336947e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          4.49515009e+00, 5.52067833e+01, 1.35954428e+01],
#         [2.40280390e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 5.04114075e+01, 0.00000000e+00]],
#
#        [[0.00000000e+00, 6.32014573e-01, 1.74936104e+01, ...,
#          2.06427407e-02, 5.19848061e+00, 9.21770278e-03],
#         [2.65016556e+00, 3.81691527e+00, 7.62651634e+00, ...,
#          1.02630155e-02, 2.93049908e+00, 7.88408422e+00],
#         [1.87591171e+00, 0.00000000e+00, 1.35000381e+01, ...,
#          1.59122877e+01, 5.97381258e+00, 4.61305952e+00],
#         ...,
#         [1.32653058e+00, 1.39577746e+00, 7.58104801e+00, ...,
#          5.30832443e+01, 5.34362486e-03, 6.97243547e+00],
#         [0.00000000e+00, 0.00000000e+00, 9.65052032e+00, ...,
#          1.22621489e+01, 2.15611935e+01, 5.58016109e+00],
#         [2.50300431e+00, 9.10873473e-01, 8.28000069e+00, ...,
#          2.55792458e-02, 2.80586281e+01, 1.45568810e+01]],
#
#        [[0.00000000e+00, 3.57589817e+00, 7.66670418e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [6.69966877e-01, 6.63383007e+00, 5.57832003e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 1.27472639e+00],
#         [0.00000000e+00, 2.26482272e+00, 6.08022690e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 2.31925821e+00, 3.40770054e+00, ...,
#          7.37268677e+01, 0.00000000e+00, 3.90964794e+00],
#         [0.00000000e+00, 1.67911899e+00, 3.42214584e+00, ...,
#          3.71844983e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 1.17311001e+00, 3.81481481e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]], dtype=float32)

# %%
cube.plot_georef()
cube.plot_georef(use_corrected=True)

# %% [markdown]
# # create rois

# %%
cube.import_rois("./ROIs/028_new.json")
cube.list_rois()
# Out:
# 📂 Imported 13 ROIs from ./ROIs/028_new.json
#
# 📂 ROI Collection (13 ROIs):
# ==================================================
#  1. 'rust': 58 pixels
#      Slit range:  193 - 222
#      Track range: 1255 - 1261
#  2. 'sediment': 541 pixels
#      Slit range:   28 - 967
#      Track range: 3604 - 9735
#  3. '1_halo': 50 pixels
#      Slit range:  575 - 649
#      Track range: 5154 - 5168
#  4. '1_arms': 135 pixels
#      Slit range:  549 - 682
#      Track range: 5146 - 5178
#  5. '1_dark': 149 pixels
#      Slit range:  538 - 688
#      Track range: 5150 - 5179
#  6. '1_bomb': 148 pixels
#      Slit range:  595 - 636
#      Track range: 5156 - 5163
#  7. '2_dark': 145 pixels
#      Slit range:  150 - 280
#      Track range: 1250 - 1271
#  8. '2_halo': 96 pixels
#      Slit range:  174 - 240
#      Track range: 1253 - 1266
#  9. '3_halo': 143 pixels
#      Slit range:  721 - 786
#      Track range: 5587 - 5600
# 10. '3_dark': 130 pixels
#      Slit range:  723 - 809
#      Track range: 5583 - 5604
# 11. '3_bomb': 79 pixels
#      Slit range:  742 - 764
#      Track range: 5590 - 5597
# 12. 'dark_pits': 67 pixels
#      Slit range:  396 - 423
#      Track range: 716 - 723
# 13. '2_bomb': 14 pixels
#      Slit range:  208 - 214
#      Track range: 1257 - 1258

# %%
# roi_028 = [
#     "rust",
#     "sediment",
#     "dark_pit",
#     "halo",
#     "dark_pit_with_bomb",
#     "halo_real",
#     # "",
# ]

# %%
stop

# %%
# %matplotlib qt

# %%
cube.plot_interactive_rgb(
    roi_name="rust", use_corrected=True, marker_size=10, figsize=(90, 8)
)

# %%
cube.plot_interactive_rgb(roi_name="sediment", use_corrected=True, marker_size=2)

# %%
cube.plot_interactive_rgb(roi_name="1_halo", use_corrected=True, marker_size=1)

# %%
cube.plot_interactive_rgb(roi_name="1_arms", use_corrected=True, marker_size=1)

# %%
cube.plot_interactive_rgb(roi_name="1_dark", use_corrected=True, marker_size=1)

# %%
cube.plot_interactive_rgb(roi_name="1_bomb", use_corrected=True, marker_size=1)

# %%
cube.plot_interactive_rgb(roi_name="2_dark", use_corrected=True, marker_size=1)

# %%
cube.plot_interactive_rgb(roi_name="2_halo", use_corrected=True, marker_size=1)

# %%
cube.plot_interactive_rgb(roi_name="2_bomb", use_corrected=True, marker_size=1)

# %%
cube.plot_interactive_rgb(roi_name="3_halo", use_corrected=True, marker_size=1)

# %%
cube.plot_interactive_rgb(roi_name="3_dark", use_corrected=True, marker_size=1)

# %%
cube.plot_interactive_rgb(roi_name="3_bomb", use_corrected=True, marker_size=1)

# %%
cube.plot_interactive_rgb(roi_name="dark_pits", use_corrected=True, marker_size=1)

# %%
cube.plot_interactive_rgb(
    roi_name="dark_pits_multiple", use_corrected=True, marker_size=1
)
# Out:
# ✨ Creating new ROI 'dark_pits_multiple'
# []
# c:\conda_envs\my_env\lib\site-packages\ipykernel\eventloops.py:145: UserWarning: Glyph 128433 (\N{THREE BUTTON MOUSE}) missing from font(s) DejaVu Sans.
#   el.exec() if hasattr(el, "exec") else el.exec_()
# ✅ Added pixel: (slit=824, track=2218) - Total: 1
# ❌ Removed nearest pixel: (slit=824, track=2218) [distance: 2.8 pixels] - Total: 0
# ✅ Added pixel: (slit=556, track=2758) - Total: 1
# ✅ Added pixel: (slit=557, track=2758) - Total: 2
# ✅ Added pixel: (slit=558, track=2758) - Total: 3
# ✅ Added pixel: (slit=559, track=2758) - Total: 4
# ✅ Added pixel: (slit=561, track=2758) - Total: 5
# ✅ Added pixel: (slit=565, track=2758) - Total: 6
# ✅ Added pixel: (slit=568, track=2757) - Total: 7
# ✅ Added pixel: (slit=566, track=2756) - Total: 8
# ✅ Added pixel: (slit=561, track=2756) - Total: 9
# ✅ Added pixel: (slit=557, track=2757) - Total: 10
# 📌 Pixel already selected: (slit=556, track=2758)
# ✅ Added pixel: (slit=556, track=2759) - Total: 11
# ✅ Added pixel: (slit=563, track=2759) - Total: 12
# ✅ Added pixel: (slit=568, track=2759) - Total: 13
# ✅ Added pixel: (slit=569, track=2758) - Total: 14
# 📌 Pixel already selected: (slit=568, track=2757)
# 📌 Pixel already selected: (slit=561, track=2758)
# 📌 Pixel already selected: (slit=561, track=2758)
# ✅ Added pixel: (slit=324, track=2343) - Total: 15
# 📌 Pixel already selected: (slit=324, track=2343)
# ✅ Added pixel: (slit=319, track=2342) - Total: 16
# ✅ Added pixel: (slit=317, track=2342) - Total: 17
# ✅ Added pixel: (slit=316, track=2342) - Total: 18
# ✅ Added pixel: (slit=315, track=2343) - Total: 19
# ✅ Added pixel: (slit=315, track=2344) - Total: 20
# ✅ Added pixel: (slit=320, track=2344) - Total: 21
# ✅ Added pixel: (slit=324, track=2344) - Total: 22
# ✅ Added pixel: (slit=326, track=2344) - Total: 23
# ✅ Added pixel: (slit=326, track=2343) - Total: 24
# ✅ Added pixel: (slit=320, track=2342) - Total: 25
# 📌 Pixel already selected: (slit=317, track=2342)
# ✅ Added pixel: (slit=317, track=2344) - Total: 26
# ✅ Added pixel: (slit=322, track=2345) - Total: 27
# ✅ Added pixel: (slit=326, track=2346) - Total: 28
# ✅ Added pixel: (slit=328, track=2345) - Total: 29
# ✅ Added pixel: (slit=329, track=2344) - Total: 30
# ✅ Added pixel: (slit=327, track=2343) - Total: 31
# 📌 Pixel already selected: (slit=319, track=2342)
# ✅ Added pixel: (slit=319, track=2344) - Total: 32
# 📌 Pixel already selected: (slit=322, track=2345)
# ✅ Added pixel: (slit=326, track=2345) - Total: 33
# ✅ Added pixel: (slit=328, track=2344) - Total: 34
# ✅ Added pixel: (slit=327, track=2344) - Total: 35
# ✅ Added pixel: (slit=715, track=2974) - Total: 36
# 📌 Pixel already selected: (slit=715, track=2974)
# ✅ Added pixel: (slit=716, track=2973) - Total: 37
# ✅ Added pixel: (slit=714, track=2973) - Total: 38
# ✅ Added pixel: (slit=713, track=2973) - Total: 39
# ✅ Added pixel: (slit=713, track=2974) - Total: 40
# ✅ Added pixel: (slit=715, track=2975) - Total: 41
# ✅ Added pixel: (slit=720, track=2975) - Total: 42
# ✅ Added pixel: (slit=720, track=2974) - Total: 43
# ✅ Added pixel: (slit=721, track=2974) - Total: 44
# ✅ Added pixel: (slit=718, track=2973) - Total: 45
# 📌 Pixel already selected: (slit=716, track=2973)
# ✅ Added pixel: (slit=714, track=2974) - Total: 46
# 📌 Pixel already selected: (slit=714, track=2974)
# 📌 Pixel already selected: (slit=715, track=2975)
# ✅ Added pixel: (slit=719, track=2975) - Total: 47
# ✅ Added pixel: (slit=721, track=2975) - Total: 48
# 📌 Pixel already selected: (slit=721, track=2974)
# ✅ Added pixel: (slit=721, track=2973) - Total: 49
# ✅ Added pixel: (slit=720, track=2973) - Total: 50
# ✅ Added pixel: (slit=717, track=2973) - Total: 51
# ✅ Added pixel: (slit=716, track=2975) - Total: 52
# ✅ Added pixel: (slit=720, track=2976) - Total: 53
# ✅ Added pixel: (slit=726, track=2975) - Total: 54
# ✅ Added pixel: (slit=726, track=2974) - Total: 55
# ✅ Added pixel: (slit=724, track=2973) - Total: 56
# ✅ Added pixel: (slit=720, track=2972) - Total: 57
# 📌 Pixel already selected: (slit=717, track=2973)
# ✅ Added pixel: (slit=716, track=2974) - Total: 58
# 📌 Pixel already selected: (slit=720, track=2975)
# ✅ Added pixel: (slit=724, track=2975) - Total: 59
# ✅ Added pixel: (slit=724, track=2974) - Total: 60
# 📌 Pixel already selected: (slit=720, track=2973)
# ✅ Added pixel: (slit=928, track=4964) - Total: 61
# ❌ Removed nearest pixel: (slit=928, track=4964) [distance: 8.1 pixels] - Total: 60
# ⚠️ No pixel within 10 pixels of click: (slit=925, track=4965)
# ✅ Added pixel: (slit=471, track=5955) - Total: 61
# ✅ Added pixel: (slit=472, track=5955) - Total: 62
# ✅ Added pixel: (slit=476, track=5956) - Total: 63
# ✅ Added pixel: (slit=476, track=5957) - Total: 64
# 📌 Pixel already selected: (slit=476, track=5957)
# ✅ Added pixel: (slit=472, track=5957) - Total: 65
# ✅ Added pixel: (slit=471, track=5956) - Total: 66
# 📌 Pixel already selected: (slit=476, track=5956)
# ✅ Added pixel: (slit=479, track=5957) - Total: 67
# 📌 Pixel already selected: (slit=479, track=5957)
# ✅ Added pixel: (slit=475, track=5958) - Total: 68
# ✅ Added pixel: (slit=472, track=5958) - Total: 69
# 📌 Pixel already selected: (slit=472, track=5957)
# ✅ Added pixel: (slit=474, track=5957) - Total: 70
# ✅ Added pixel: (slit=475, track=5957) - Total: 71
# ✅ Added pixel: (slit=508, track=5498) - Total: 72
# 📌 Pixel already selected: (slit=508, track=5498)
# ✅ Added pixel: (slit=507, track=5498) - Total: 73
# ✅ Added pixel: (slit=504, track=5498) - Total: 74
# ✅ Added pixel: (slit=503, track=5498) - Total: 75
# ✅ Added pixel: (slit=503, track=5499) - Total: 76
# ✅ Added pixel: (slit=506, track=5499) - Total: 77
# ✅ Added pixel: (slit=510, track=5499) - Total: 78
# ✅ Added pixel: (slit=511, track=5498) - Total: 79
# ✅ Added pixel: (slit=510, track=5497) - Total: 80
# ✅ Added pixel: (slit=506, track=5497) - Total: 81
# 📌 Pixel already selected: (slit=504, track=5498)
# ✅ Added pixel: (slit=502, track=5499) - Total: 82
# ✅ Added pixel: (slit=501, track=5500) - Total: 83
# ✅ Added pixel: (slit=505, track=5501) - Total: 84
# ✅ Added pixel: (slit=510, track=5500) - Total: 85
# ✅ Added pixel: (slit=512, track=5499) - Total: 86
# 📌 Pixel already selected: (slit=507, track=5498)
# ✅ Added pixel: (slit=502, track=5498) - Total: 87
# ✅ Added pixel: (slit=501, track=5501) - Total: 88
# 📌 Pixel already selected: (slit=505, track=5501)
# 📌 Pixel already selected: (slit=510, track=5499)
# 📌 Pixel already selected: (slit=510, track=5499)
# ✅ Added pixel: (slit=504, track=5499) - Total: 89
# 📌 Pixel already selected: (slit=502, track=5499)
# ✅ Added pixel: (slit=524, track=6342) - Total: 90
# 📌 Pixel already selected: (slit=524, track=6342)
# 📌 Pixel already selected: (slit=524, track=6342)
# ✅ Added pixel: (slit=519, track=6341) - Total: 91
# ✅ Added pixel: (slit=518, track=6342) - Total: 92
# ✅ Added pixel: (slit=518, track=6344) - Total: 93
# ✅ Added pixel: (slit=522, track=6344) - Total: 94
# 📌 Pixel already selected: (slit=522, track=6344)
# 📌 Pixel already selected: (slit=524, track=6342)
# ✅ Added pixel: (slit=525, track=6342) - Total: 95
# ✅ Added pixel: (slit=521, track=6340) - Total: 96
# ✅ Added pixel: (slit=520, track=6341) - Total: 97
# ✅ Added pixel: (slit=522, track=6343) - Total: 98
# ✅ Added pixel: (slit=526, track=6342) - Total: 99
# ✅ Added pixel: (slit=527, track=6341) - Total: 100
# ✅ Added pixel: (slit=524, track=6341) - Total: 101
# 📌 Pixel already selected: (slit=520, track=6341)
# ✅ Added pixel: (slit=521, track=6342) - Total: 102
# 📌 Pixel already selected: (slit=526, track=6342)
# ✅ Added pixel: (slit=529, track=6342) - Total: 103
# 📌 Pixel already selected: (slit=527, track=6341)
# ✅ Added pixel: (slit=523, track=6341) - Total: 104
# ✅ Added pixel: (slit=526, track=6344) - Total: 105
# ✅ Added pixel: (slit=530, track=6343) - Total: 106
# ✅ Added pixel: (slit=530, track=6341) - Total: 107
# 📌 Pixel already selected: (slit=524, track=6341)
# 💾 Saved ROI 'dark_pits_multiple' with 107 pixels

# %% [markdown]
# # ROI operations

# %%
stop

# %%
# List all ROIs
cube.list_rois()

# %%
cube.export_rois("./ROIs/028_new.json")
# Out:
# 💾 Exported 14 ROIs to ./ROIs/028_new.json

# %%
# Delete specific ROI
cube.delete_roi("1_halo")

# %%
# # cube.import_rois("./ROIs/057_5_SVM.json")
# cube.import_rois("./ROIs/057_5_combined.json")

# %%
cube.rename_roi(old_roi_name="", new_roi_name="training_dark")

# %% [markdown]
# # check rois

# %%
# %matplotlib inline
cube.plot_georef(
    # apply_alignment_shift=True,
    use_corrected=False,
    # track_start=config.UHI_TRACK_RANGE_5[0],
    # track_end=config.UHI_TRACK_RANGE_5[1],
    figsize=(50, 20),
    roi_collection="all",
    roi_marker_size=2,
    roi_legend_loc="outside",
    roi_marker_edgewidth=0,
    roi_legend_markersize=40,
)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
roi_028 = [
    # "rust",
    "sediment",
    # "dark_pit",
    # "halo",
    # "dark_pit_with_bomb",
    # "halo_real",
    # "",
]

# %%
# %matplotlib qt
# %matplotlib inline

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    # interpolate_wavelengths=[35, 104, 157],
    legend_loc="outside",
    use_inline_labels=False,
    figsize=(20, 10),
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    # interpolate_wavelengths=[35, 104, 157],
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
# cube.plot_spectrum(
#     use_corrected=True,
#     wavelength_range=(490, 700),
#     # wavelength_smoothing=10,
#     # interpolate_wavelengths=[35, 104, 157],
#     legend_loc="outside",
#     use_inline_labels=False,
#     figsize=(20, 10),
# )

# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    roi_names="all",
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=3,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
    # normalize_method="l2",
    # derivative_order=1,
)

# %%
cube.plot_spectrum(
    roi_names="all",
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=3,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
    normalize_method="l2",
    # derivative_order=1,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(430, 750),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    track_index=300,
    slit_index=50,
    # roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    track_index=300,
    slit_index=50,
    # roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
    smooth_before_filter=True,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    # wavelength_range=(450, 700),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    # wavelength_range=(450, 700),
    wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=20,
    # interpolate_wavelengths=[35, 104, 157],
    legend_loc="outside",
    use_inline_labels=False,
    normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=30,
    smoothing_method="savgol",
    savgol_polyorder=3,
    # interpolate_wavelengths=[35, 104, 157],
    legend_loc="outside",
    use_inline_labels=False,
    normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=50,
    smoothing_method="savgol",
    savgol_polyorder=4,
    # interpolate_wavelengths=[35, 104, 157],
    legend_loc="outside",
    use_inline_labels=False,
    normalize_method="l2",
    show_std=False,
    # smooth_before_filter=True,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    normalize_method="l2",
    show_std=False,
    derivative_order=1,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=30,
    legend_loc="outside",
    use_inline_labels=False,
    normalize_method="l2",
    show_std=False,
    derivative_order=2,
)

# %% [markdown]
# # TEST: Percentile Clipping
#
# Test the new `apply_percentile_clipping()` function to remove extreme spikes before smoothing.

# %%
# Helper function to visualize histograms per band
def test_plot_band_histograms(cube, sample_every_n_bands=10, figsize=(20, 12)):
    """
    Plot histograms for sampled wavelength bands to see distribution of values.
    This helps you identify which bands have extreme outliers (spikes).
    """
    n_bands = cube.data_corrected.shape[2]
    band_indices = list(range(0, n_bands, sample_every_n_bands))

    n_plots = len(band_indices)
    n_cols = 5
    n_rows = (n_plots + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_rows, n_cols, figsize=figsize)
    axes = axes.flatten()

    for idx, band_idx in enumerate(band_indices):
        if band_idx >= n_bands:
            break

        # Get all values for this band
        band_data = cube.data_corrected[:, :, band_idx].flatten()

        # Plot histogram
        axes[idx].hist(band_data, bins=50, alpha=0.7, edgecolor="black")
        axes[idx].set_title(
            f"Band {band_idx}\n{cube.wavelengths[band_idx]:.1f} nm", fontsize=10
        )
        axes[idx].set_xlabel("Intensity", fontsize=8)
        axes[idx].set_ylabel("Count", fontsize=8)
        axes[idx].grid(alpha=0.3)

        # Mark percentiles
        p5 = np.percentile(band_data, 5)
        p95 = np.percentile(band_data, 95)
        axes[idx].axvline(
            p5, color="red", linestyle="--", linewidth=1, alpha=0.7, label="5th %ile"
        )
        axes[idx].axvline(
            p95, color="red", linestyle="--", linewidth=1, alpha=0.7, label="95th %ile"
        )
        axes[idx].legend(fontsize=6)

    # Hide unused subplots
    for idx in range(len(band_indices), len(axes)):
        axes[idx].axis("off")

    plt.suptitle("Histogram per Band (sampled)", fontsize=14, fontweight="bold")
    plt.tight_layout()
    plt.show()


print("✅ test_plot_band_histograms() defined")

# %%
# Step 1: Look at histograms BEFORE clipping
print("📊 Histograms BEFORE percentile clipping:")
test_plot_band_histograms(cube, sample_every_n_bands=20)

# %%
# Step 2: Save one example spectrum BEFORE clipping (for comparison)
# Pick a pixel from the middle of the cube (safer than using ROI which might be out of bounds)
T, S, B = cube.data_corrected.shape
example_t = T // 2
example_s = S // 2
example_spectrum_before = cube.data_corrected[example_t, example_s, :].copy()
print(
    f"✅ Saved example spectrum from cube center at track={example_t}, slit={example_s}"
)

# %%
# Step 3: Apply percentile clipping
# TRY DIFFERENT VALUES: 5-95, 10-90, 2-98, etc.
cube.apply_percentile_clipping(lower_percentile=5, upper_percentile=95)

# %%
# Step 4: Look at histograms AFTER clipping
print("📊 Histograms AFTER percentile clipping:")
test_plot_band_histograms(cube, sample_every_n_bands=20)

# %%
# Step 5: Compare BEFORE vs AFTER for one example spectrum
# Use the same pixel we saved earlier
example_spectrum_after = cube.data_corrected[example_t, example_s, :]

fig, axes = plt.subplots(2, 1, figsize=(16, 10))

# Plot BEFORE    
axes[0].plot(cube.wavelengths, example_spectrum_before, linewidth=1.5, color='red', label='BEFORE clipping')
axes[0].set_title('Spectrum BEFORE Percentile Clipping', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Wavelength (nm)', fontsize=12)
axes[0].set_ylabel('Intensity', fontsize=12)
axes[0].grid(
    alpha=0.3,
    example_spectrum_before,
    color="red",
    label="",
)
axes[0].set_title("size=11)""bold")
axes[0].set_xlabel(".wavelengths[0]" 450, alpha=0.2, color='gray', label='Bad range')
axes[0].axvspan(700" cube.wav"lengths[-1], alpha=0.2, color='gray')

# Plot AFTER
axes[1].plot(cube.wavelengths, example_spectrum_after, line"idth", label="r='blue',"label='AFTER clipping')
axes[1].set_title('Spectrum AFTER Percentile Clipping', font"ize="4, fontweight='bold')
axes[1].set_xlabel('Wavelength (nm)', fontsize=12)
axes[1].set_ylabel('Intensity', fontsize=12)
axes[1].grid(
    alpha=0.3)
    example_spectrum_after,
   
    color="blue",
    label="",
)
axes[1].set_title("size=11)""bold")
axes[1].set_xlabel(".wavelengths[0]" 450, alpha=0.2, color='gray', label='Bad range')
axes[1].axvspan(700" cube.wav"lengths[-1], alpha=0.2, color='gray')

plt.tight_layout()
plt.show()"", label=""
""
print(f"\n📉 BEFORE - Value range: [{example_spectrum_before.min():.4f}, {example_spectrum_before.max():.4f}]")
print(f"📉 AFTER  - Value range: [{example_spectrum_after.min():.4f}, {example_spectrum_after.max():.4f}]")
print(f"\n✅ Notice how the spikes at <450nm and >700nm are now clipped!")

# %%
# Step 6: Now test with smoothing on the FULL spectrum (no wavelength filter yet!)
# This tests if clipping was enough to allow smoothing across bad bands
cube.plot_spectrum(
    roi_names=["sediment"],
    use_corrected=True,
    wavelength_range=None,  # FULL spectrum (no cropping)
    wavelength_smoothing=20,  # Large window
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    figsize=(20, 8),
)
print(
    "\n✅ If the edges (<450nm, >700nm) now look smooth (not spiky), clipping worked!"
)

# %% [markdown]
# # TEST: Advanced Smoothing Methods
#
# Test the new smoothing methods: Gaussian, Median, Whittaker, and Bilateral filters.

# %% [markdown]
# ## Gaussian Smoothing
#
# Test Gaussian filter with different sigma values.

# %%
# Gaussian smoothing with sigma=1.0 (light smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=1.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Gaussian smoothing with sigma=2.0 (default, moderate smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=2.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=3.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    track_index=300,
    slit_index=50,
    # roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=3.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    track_index=300,
    slit_index=50,
    # roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=3.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    # track_index=300,
    # slit_index=50,
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=3.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=3.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=5.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
    # normalize_method="l2",
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
# %matplotlib inline

cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=5.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
    normalize_method="l2",
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
# %matplotlib qt

cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=5.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
    normalize_method="l2",
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=3,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
    normalize_method="l2",
    derivative_order=1,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
# %matplotlib qt
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=5.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
    normalize_method="l2",
    derivative_order=1,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=3,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
    normalize_method="l2",
    derivative_order=2,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=5.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
    normalize_method="l2",
    derivative_order=2,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=5.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=5.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=5.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    normalize_method="l2",
)

# %% [markdown]
# ## Median Smoothing
#
# Test Median filter with different kernel sizes.

# %%
# Median smoothing with kernel_size=3 (light smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="median",
    median_kernel_size=3,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Median smoothing with kernel_size=5 (default, moderate smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="median",
    median_kernel_size=5,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Median smoothing with kernel_size=7 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="median",
    median_kernel_size=7,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %% [markdown]
# ## Whittaker Smoothing
#
# Test Whittaker smoother with different lambda values.

# %%
# Whittaker smoothing with lambda=1e3 (light smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="whittaker",
    whittaker_lambda=1e3,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Whittaker smoothing with lambda=1e3 (light smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="whittaker",
    whittaker_lambda=1e3,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    # smooth_before_filter=True,
)

# %%
# Whittaker smoothing with lambda=1e3 (light smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="whittaker",
    whittaker_lambda=1e3,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    normalize_method="l2",
    # smooth_before_filter=True,
)

# %%
# Whittaker smoothing with lambda=1e3 (light smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    # wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="whittaker",
    whittaker_lambda=1e3,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
)

# %%
# Whittaker smoothing with lambda=1e4 (default, moderate smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="whittaker",
    whittaker_lambda=1e4,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Whittaker smoothing with lambda=1e5 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="whittaker",
    whittaker_lambda=1e5,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %% [markdown]
# ## Bilateral Smoothing
#
# Test Bilateral filter with different spatial and intensity sigma values.

# %%
# Bilateral smoothing with default parameters (moderate edge preservation)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="bilateral",
    bilateral_sigma_spatial=2.0,
    bilateral_sigma_intensity=0.1,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Bilateral smoothing with larger spatial sigma (more smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="bilateral",
    bilateral_sigma_spatial=3.0,
    bilateral_sigma_intensity=0.1,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Bilateral smoothing with smaller intensity sigma (stronger edge preservation)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="bilateral",
    bilateral_sigma_spatial=2.0,
    bilateral_sigma_intensity=0.05,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Bilateral smoothing with larger intensity sigma (less edge preservation, more smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="bilateral",
    bilateral_sigma_spatial=2.0,
    bilateral_sigma_intensity=0.2,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %% [markdown]
# ## Summary of Smoothing Methods
#
# **Gaussian Smoothing** (`smoothing_method="gaussian"`):
# - Good for general noise reduction
# - `gaussian_sigma`: Larger = smoother (typical range: 1.0-3.0)
# - Smooth, continuous results
#
# **Median Smoothing** (`smoothing_method="median"`):
# - Robust to outliers and spikes
# - `median_kernel_size`: Larger = smoother (must be odd, typical: 3, 5, 7)
# - Good for preserving edges while removing noise
#
# **Whittaker Smoothing** (`smoothing_method="whittaker"`):
# - Excellent feature preservation with penalized least squares
# - `whittaker_lambda`: Larger = smoother (typical range: 1e3-1e5)
# - Best for spectral contours and subtle features
#
# **Bilateral Smoothing** (`smoothing_method="bilateral"`):
# - Edge-preserving, intensity-aware smoothing
# - `bilateral_sigma_spatial`: Controls spatial extent (typical: 2.0-3.0)
# - `bilateral_sigma_intensity`: Controls edge preservation (smaller = stronger, typical: 0.05-0.2)
# - Best for maintaining sharp transitions between features
#
# **Recommendation**: Start with Whittaker for spectral analysis (excellent feature preservation), or Gaussian for quick noise reduction.

# %% [markdown]
# ## How to use in your real workflow:
#
# Once you find good percentile values (e.g., 5-95 or 10-90), add this AFTER illumination correction:
#
# ```python
# # Your normal workflow:
# cube.apply_illumination_correction_v2()
#
# # NEW: Clip extreme spikes
# cube.apply_percentile_clipping(lower_percentile=5, upper_percentile=95)
#
# # Then continue as normal:
# cube.apply_spectral_smoothing(wavelength_smoothing=20)
# cube.apply_wavelength_filter(wavelength_range=(450, 700))
# cube.apply_spectral_normalization(method="l2")
# ```
#
# **To test different percentile values:**
# - More aggressive (removes more outliers): `lower_percentile=10, upper_percentile=90`
# - Less aggressive (keeps more data): `lower_percentile=2, upper_percentile=98`
# - Check the histograms to see which bands have the worst outliers!

# %% [markdown]
# # TEST: apply_spectral_smoothing() with Gaussian
#
# Test the new Gaussian smoothing in the pipeline function that modifies the entire datacube.

# %%
# Test: Apply Gaussian smoothing to the entire datacube
# WARNING: This modifies cube.data_corrected permanently (until you reload)
# Make a backup first if needed

# Apply Gaussian smoothing with default sigma=2.0
cube.apply_spectral_smoothing(method="gaussian", gaussian_sigma=2.0)

# %%
# After smoothing, plot the spectra to see the effect
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %% [markdown]
# **Note:** If you need to reload the cube to test different smoothing parameters:
# ```python
# # Reload the cube from scratch
# cube = transect.select_files([
#     "rad_uhi_20241029_125028_1",
#     "rad_uhi_20241029_125028_2",
#     "rad_uhi_20241029_125028_3",
#     "rad_uhi_20241029_125028_4",
#     "rad_uhi_20241029_125028_5",
# ])
# cube.apply_illumination_correction_v2()
# # Then apply different smoothing settings
# ```

# %% [markdown]
# # check wavelenghts from 057

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt

sys.path.append(os.path.abspath("../"))
from utils.gref_pipeline.georef import *

sys.path.append(os.path.abspath("../../"))
from gref_pipeline import config

# %%
# Load transect
transect = load_transect(config.OUTPUT_FOLDER)
transect.list_files()

# Select file
cube = transect.select_files(["rad_uhi_20241029_115057_5"])
cube.describe()

# %%
# Apply illumination correction
cube.apply_illumination_correction_v2()

# %%
# Import ROIs
cube.import_rois("./ROIs/057_5_combined.json")
cube.list_rois()

# %%
# Define ROI collections
training_rois = [
    "training_dark",
    "training_sediment",
    "training_bombs",
]

validation_rois = [
    "validation_dark",
    "validation_sediment",
    "validation_bombs",
]

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=training_rois,
    use_corrected=True,
    wavelength_range=(440, 750),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=training_rois,
    use_corrected=True,
    wavelength_range=(440, 700),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=training_rois,
    use_corrected=True,
    wavelength_range=(490, 700),
    # wavelength_smoothing=10,
    # smoothing_method="gaussian",
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=training_rois,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
    smooth_before_filter=True,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=validation_rois,
    use_corrected=True,
    wavelength_range=(490, 700),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=validation_rois,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
    smooth_before_filter=True,
)
