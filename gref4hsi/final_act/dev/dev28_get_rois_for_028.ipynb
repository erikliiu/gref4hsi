# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt

sys.path.append(os.path.abspath("../"))
from utils.gref_pipeline.georef import *

sys.path.append(os.path.abspath("../../"))
from gref_pipeline import config

# %%
# Load 028 transect
transect = load_transect(r"E:\mjosa_new_oct_2025\use_gref4hsi\028\output")
transect.list_files()

# Select 028_5 for NDI analysis
cube = transect.select_files(
    [
        "rad_uhi_20241029_125028_1",
        "rad_uhi_20241029_125028_2",
        "rad_uhi_20241029_125028_3",
        "rad_uhi_20241029_125028_4",
        "rad_uhi_20241029_125028_5",
    ]
)
cube.describe()
# Out:
# 📋 Files in output (corrected=False):
#  1. rad_uhi_20241029_125028_1  | shape=(1329, 968, 210)  | has_georef=True
#  2. rad_uhi_20241029_125028_2  | shape=(2011, 968, 210)  | has_georef=True
#  3. rad_uhi_20241029_125028_3  | shape=(2282, 968, 210)  | has_georef=True
#  4. rad_uhi_20241029_125028_4  | shape=(2457, 968, 210)  | has_georef=True
#  5. rad_uhi_20241029_125028_5  | shape=(1948, 968, 210)  | has_georef=True
# 🔄 Rebuilding grids from georef hits for selected files...
#    • rad_uhi_20241029_125028_1
#   rad_uhi_20241029_125028_1: Using GRIDDED format (T=1329, S=968)
#    • rad_uhi_20241029_125028_2
#   rad_uhi_20241029_125028_2: Using GRIDDED format (T=2011, S=968)
#    • rad_uhi_20241029_125028_3
#   rad_uhi_20241029_125028_3: Using GRIDDED format (T=2282, S=968)
#    • rad_uhi_20241029_125028_4
#   rad_uhi_20241029_125028_4: Using GRIDDED format (T=2457, S=968)
#    • rad_uhi_20241029_125028_5
#   rad_uhi_20241029_125028_5: Using GRIDDED format (T=1948, S=968)
# ✅ Combined shapes: X/Y/Z (10027, 968), RGB (10027, 968)
# 🔄 Loading full hyperspectral cube...
#    • Loading rad_uhi_20241029_125028_1...
#    • Loading rad_uhi_20241029_125028_2...
#    • Loading rad_uhi_20241029_125028_3...
#    • Loading rad_uhi_20241029_125028_4...
#    • Loading rad_uhi_20241029_125028_5...
# ✅ Loaded full cube: (10027, 968, 210) (T × S × B)
#
# === Combined_output ===
# Tracks × Slits: 10027 × 968
# RGB coverage: R/G/B finite ratios 0.99/0.99/0.99
#
# 📋 File boundaries:
#   rad_uhi_20241029_125028_1: tracks 0–1328 (1329)
#   rad_uhi_20241029_125028_2: tracks 1329–3339 (2011)
#   rad_uhi_20241029_125028_3: tracks 3340–5621 (2282)
#   rad_uhi_20241029_125028_4: tracks 5622–8078 (2457)
#   rad_uhi_20241029_125028_5: tracks 8079–10026 (1948)

# %%
cube.apply_illumination_correction_v2()
# Out:
# 🔄 Using V2 algorithm (pandas rolling median)
# ✅ Illumination correction already applied with window=500, strength=1.0
#    Loading from disk...
# 📂 Loading saved illumination correction from 5 files...
#    rad_uhi_20241029_125028_1: window=500, strength=1.0
#    rad_uhi_20241029_125028_2: window=500, strength=1.0
#    rad_uhi_20241029_125028_3: window=500, strength=1.0
#    rad_uhi_20241029_125028_4: window=500, strength=1.0
#    rad_uhi_20241029_125028_5: window=500, strength=1.0
# ✅ Loaded illumination correction from disk
# array([[[0.00000000e+00, 8.00363868e-02, 3.38807702e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          9.79862548e-03, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 6.24412894e-01, 0.00000000e+00, ...,
#          2.43312144e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          4.49576187e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 1.18552887e+00, ...,
#          2.34972164e-01, 0.00000000e+00, 0.00000000e+00],
#         [9.47257459e-01, 0.00000000e+00, 0.00000000e+00, ...,
#          3.01917344e-01, 0.00000000e+00, 0.00000000e+00]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          1.15298668e+02, 1.14839525e+01, 3.45664215e-03],
#         [0.00000000e+00, 1.00000000e+00, 9.11504328e-01, ...,
#          2.32659373e-02, 2.43540382e+00, 4.57144403e+00],
#         [0.00000000e+00, 3.06572890e+00, 0.00000000e+00, ...,
#          4.02547836e+00, 1.90113354e-02, 8.68073642e-01],
#         ...,
#         [1.75438598e-02, 0.00000000e+00, 1.00000000e+00, ...,
#          6.55555439e+00, 1.33838160e-02, 2.99430227e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          1.98360729e+00, 1.40843954e+01, 2.13704319e+01],
#         [0.00000000e+00, 1.98199582e+00, 0.00000000e+00, ...,
#          1.00750742e+01, 3.09236441e-03, 1.81136024e+00]],
#
#        [[0.00000000e+00, 4.21987295e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 1.30968695e+01, 1.53628865e-03],
#         [0.00000000e+00, 1.38329611e+01, 2.54227202e-02, ...,
#          0.00000000e+00, 3.75119090e+00, 1.27472639e+00],
#         [0.00000000e+00, 7.00939274e+00, 3.00617886e+00, ...,
#          3.63057196e-01, 1.52854491e-02, 2.05932403e+00],
#         ...,
#         [0.00000000e+00, 7.80528212e+00, 0.00000000e+00, ...,
#          4.70339119e-01, 0.00000000e+00, 1.28490031e+00],
#         [0.00000000e+00, 3.92014837e+00, 1.46382201e+00, ...,
#          2.85792470e+00, 1.22151966e+01, 3.82714182e-01],
#         [0.00000000e+00, 3.72013187e+00, 0.00000000e+00, ...,
#          8.50438881e+00, 1.39315668e-02, 1.81136024e+00]],
#
#        ...,
#
#        [[5.45343924e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 7.10688114e+00, 1.16181439e-02],
#         [1.02409277e+01, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 4.66794825e+00, 7.25002098e+00],
#         [5.08758736e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 8.85338783e+00, 6.50349081e-01],
#         ...,
#         [1.40816319e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          9.19671249e+00, 1.27653405e-02, 3.60336947e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          4.49515009e+00, 5.52067833e+01, 1.35954428e+01],
#         [2.40280390e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 5.04114075e+01, 0.00000000e+00]],
#
#        [[0.00000000e+00, 6.32014573e-01, 1.74936104e+01, ...,
#          2.06427407e-02, 5.19848061e+00, 9.21770278e-03],
#         [2.65016556e+00, 3.81691527e+00, 7.62651634e+00, ...,
#          1.02630155e-02, 2.93049908e+00, 7.88408422e+00],
#         [1.87591171e+00, 0.00000000e+00, 1.35000381e+01, ...,
#          1.59122877e+01, 5.97381258e+00, 4.61305952e+00],
#         ...,
#         [1.32653058e+00, 1.39577746e+00, 7.58104801e+00, ...,
#          5.30832443e+01, 5.34362486e-03, 6.97243547e+00],
#         [0.00000000e+00, 0.00000000e+00, 9.65052032e+00, ...,
#          1.22621489e+01, 2.15611935e+01, 5.58016109e+00],
#         [2.50300431e+00, 9.10873473e-01, 8.28000069e+00, ...,
#          2.55792458e-02, 2.80586281e+01, 1.45568810e+01]],
#
#        [[0.00000000e+00, 3.57589817e+00, 7.66670418e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [6.69966877e-01, 6.63383007e+00, 5.57832003e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 1.27472639e+00],
#         [0.00000000e+00, 2.26482272e+00, 6.08022690e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 2.31925821e+00, 3.40770054e+00, ...,
#          7.37268677e+01, 0.00000000e+00, 3.90964794e+00],
#         [0.00000000e+00, 1.67911899e+00, 3.42214584e+00, ...,
#          3.71844983e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 1.17311001e+00, 3.81481481e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]], dtype=float32)

# %%
cube.plot_georef()
cube.plot_georef(use_corrected=True)
# Out:
# 💡 Interactive mode: Click on the plot to display coordinates
# 💡 Interactive mode: Click on the plot to display coordinates

# %% [markdown]
# # create rois

# %%
cube.import_rois("./ROIs/028.json")
cube.list_rois()
# Out:
# 📂 Imported 6 ROIs from ./ROIs/028.json
#
# 📂 ROI Collection (6 ROIs):
# ==================================================
#  1. 'rust': 35 pixels
#      Slit range:  194 - 252
#      Track range: 1222 - 1262
#  2. 'sediment': 177 pixels
#      Slit range:   28 - 835
#      Track range: 8633 - 9735
#  3. 'dark_pit': 71 pixels
#      Slit range:  693 - 745
#      Track range: 9509 - 9523
#  4. 'dark_pit_with_bomb': 69 pixels
#      Slit range:  308 - 337
#      Track range: 9375 - 9395
#  5. 'halo': 60 pixels
#      Slit range:  328 - 469
#      Track range: 6488 - 6655
#  6. 'halo_real': 84 pixels
#      Slit range:  237 - 306
#      Track range: 9372 - 9386

# %%
roi_028 = [
    "rust",
    "sediment",
    "dark_pit",
    "halo",
    "dark_pit_with_bomb",
    "halo_real",
    # "",
]

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
# %matplotlib qt

# %%
cube.plot_interactive_rgb(
    roi_name="rust", use_corrected=True, marker_size=1, figsize=(90, 8)
)
# Out:
# 📂 Loaded 'rust' with 12 pixels
# [(209, 1261),
#  (203, 1260),
#  (206, 1261),
#  (201, 1260),
#  (212, 1261),
#  (207, 1261),
#  (197, 1258),
#  (200, 1260),
#  (200, 1256),
#  (199, 1259),
#  (200, 1259),
#  (202, 1256)]
# ✅ Added pixel: (slit=252, track=1222) - Total: 13
# ✅ Added pixel: (slit=211, track=1260) - Total: 14
# 📌 Pixel already selected: (slit=209, track=1261)
# ✅ Added pixel: (slit=207, track=1260) - Total: 15
# 📌 Pixel already selected: (slit=207, track=1261)
# ✅ Added pixel: (slit=214, track=1262) - Total: 16
# ✅ Added pixel: (slit=218, track=1261) - Total: 17
# ✅ Added pixel: (slit=221, track=1260) - Total: 18
# ✅ Added pixel: (slit=222, track=1260) - Total: 19
# ✅ Added pixel: (slit=198, track=1257) - Total: 20
# 📌 Pixel already selected: (slit=198, track=1257)
# ✅ Added pixel: (slit=196, track=1258) - Total: 21
# 📌 Pixel already selected: (slit=196, track=1258)
# 📌 Pixel already selected: (slit=196, track=1258)
# 📌 Pixel already selected: (slit=197, track=1258)
# ✅ Added pixel: (slit=197, track=1259) - Total: 22
# ✅ Added pixel: (slit=198, track=1259) - Total: 23
# 📌 Pixel already selected: (slit=198, track=1259)
# 📌 Pixel already selected: (slit=198, track=1259)
# ✅ Added pixel: (slit=194, track=1258) - Total: 24
# ✅ Added pixel: (slit=195, track=1258) - Total: 25
# 📌 Pixel already selected: (slit=196, track=1258)
# ✅ Added pixel: (slit=196, track=1257) - Total: 26
# 📌 Pixel already selected: (slit=206, track=1261)
# 📌 Pixel already selected: (slit=206, track=1261)
# 📌 Pixel already selected: (slit=209, track=1261)
# ✅ Added pixel: (slit=211, track=1261) - Total: 27
# 📌 Pixel already selected: (slit=206, track=1261)
# ✅ Added pixel: (slit=204, track=1260) - Total: 28
# 📌 Pixel already selected: (slit=203, track=1260)
# 📌 Pixel already selected: (slit=206, track=1261)
# 📌 Pixel already selected: (slit=207, track=1261)
# 📌 Pixel already selected: (slit=209, track=1261)
# ✅ Added pixel: (slit=210, track=1261) - Total: 29
# 📌 Pixel already selected: (slit=210, track=1261)
# 📌 Pixel already selected: (slit=211, track=1261)
# 📌 Pixel already selected: (slit=209, track=1261)
# 📌 Pixel already selected: (slit=211, track=1260)
# 📌 Pixel already selected: (slit=211, track=1260)
# 📌 Pixel already selected: (slit=211, track=1260)
# ✅ Added pixel: (slit=210, track=1260) - Total: 30
# 📌 Pixel already selected: (slit=210, track=1260)
# ✅ Added pixel: (slit=209, track=1260) - Total: 31
# ✅ Added pixel: (slit=208, track=1260) - Total: 32
# 📌 Pixel already selected: (slit=207, track=1260)
# ✅ Added pixel: (slit=212, track=1260) - Total: 33
# ✅ Added pixel: (slit=209, track=1259) - Total: 34
# ✅ Added pixel: (slit=208, track=1259) - Total: 35
# ❌ Removed nearest pixel: (slit=212, track=1260) [distance: 1.0 pixels] - Total: 34
# ❌ Removed pixel: (slit=209, track=1259) - Total: 33
# ❌ Removed nearest pixel: (slit=208, track=1259) [distance: 1.4 pixels] - Total: 32
# ✅ Added pixel: (slit=217, track=1261) - Total: 33
# ✅ Added pixel: (slit=216, track=1260) - Total: 34
# ✅ Added pixel: (slit=220, track=1260) - Total: 35
# 💾 Saved ROI 'rust' with 35 pixels

# %%
cube.plot_interactive_rgb(roi_name="sediment", use_corrected=True, marker_size=2)
# Out:
# ✨ Creating new ROI 'sediment'
# []
# ✅ Added pixel: (slit=332, track=9301) - Total: 1
# ✅ Added pixel: (slit=228, track=9274) - Total: 2
# ✅ Added pixel: (slit=586, track=9324) - Total: 3
# ✅ Added pixel: (slit=620, track=9278) - Total: 4
# ✅ Added pixel: (slit=690, track=9274) - Total: 5
# ✅ Added pixel: (slit=712, track=9278) - Total: 6
# ✅ Added pixel: (slit=778, track=9285) - Total: 7
# ✅ Added pixel: (slit=820, track=9276) - Total: 8
# ✅ Added pixel: (slit=832, track=9270) - Total: 9
# ✅ Added pixel: (slit=706, track=9326) - Total: 10
# ✅ Added pixel: (slit=695, track=9337) - Total: 11
# ✅ Added pixel: (slit=660, track=9379) - Total: 12
# ✅ Added pixel: (slit=640, track=9419) - Total: 13
# ✅ Added pixel: (slit=623, track=9440) - Total: 14
# ✅ Added pixel: (slit=591, track=9457) - Total: 15
# ✅ Added pixel: (slit=553, track=9460) - Total: 16
# ✅ Added pixel: (slit=517, track=9457) - Total: 17
# ✅ Added pixel: (slit=495, track=9457) - Total: 18
# ✅ Added pixel: (slit=694, track=9564) - Total: 19
# ✅ Added pixel: (slit=625, track=9564) - Total: 20
# ✅ Added pixel: (slit=549, track=9569) - Total: 21
# ✅ Added pixel: (slit=450, track=9544) - Total: 22
# ✅ Added pixel: (slit=405, track=9533) - Total: 23
# ✅ Added pixel: (slit=383, track=9545) - Total: 24
# ✅ Added pixel: (slit=349, track=9559) - Total: 25
# ✅ Added pixel: (slit=309, track=9584) - Total: 26
# ✅ Added pixel: (slit=274, track=9614) - Total: 27
# ✅ Added pixel: (slit=232, track=9633) - Total: 28
# ✅ Added pixel: (slit=191, track=9634) - Total: 29
# ✅ Added pixel: (slit=161, track=9591) - Total: 30
# ✅ Added pixel: (slit=151, track=9539) - Total: 31
# ✅ Added pixel: (slit=107, track=9549) - Total: 32
# ✅ Added pixel: (slit=79, track=9528) - Total: 33
# ✅ Added pixel: (slit=54, track=9499) - Total: 34
# ✅ Added pixel: (slit=37, track=9435) - Total: 35
# ✅ Added pixel: (slit=69, track=9401) - Total: 36
# ✅ Added pixel: (slit=101, track=9380) - Total: 37
# ✅ Added pixel: (slit=74, track=9343) - Total: 38
# ✅ Added pixel: (slit=82, track=9321) - Total: 39
# ✅ Added pixel: (slit=96, track=9285) - Total: 40
# ✅ Added pixel: (slit=122, track=9270) - Total: 41
# ✅ Added pixel: (slit=122, track=9268) - Total: 42
# ✅ Added pixel: (slit=154, track=9268) - Total: 43
# ✅ Added pixel: (slit=201, track=9268) - Total: 44
# ✅ Added pixel: (slit=269, track=9279) - Total: 45
# ✅ Added pixel: (slit=307, track=9296) - Total: 46
# ✅ Added pixel: (slit=339, track=9287) - Total: 47
# ✅ Added pixel: (slit=354, track=9273) - Total: 48
# ✅ Added pixel: (slit=354, track=9256) - Total: 49
# ✅ Added pixel: (slit=428, track=9214) - Total: 50
# ✅ Added pixel: (slit=487, track=9214) - Total: 51
# ✅ Added pixel: (slit=546, track=9232) - Total: 52
# ✅ Added pixel: (slit=591, track=9259) - Total: 53
# ✅ Added pixel: (slit=559, track=9309) - Total: 54
# ✅ Added pixel: (slit=472, track=9320) - Total: 55
# ✅ Added pixel: (slit=425, track=9312) - Total: 56
# ✅ Added pixel: (slit=541, track=9735) - Total: 57
# ✅ Added pixel: (slit=569, track=9734) - Total: 58
# ✅ Added pixel: (slit=655, track=9726) - Total: 59
# ✅ Added pixel: (slit=732, track=9725) - Total: 60
# ✅ Added pixel: (slit=766, track=9703) - Total: 61
# ✅ Added pixel: (slit=764, track=9695) - Total: 62
# ✅ Added pixel: (slit=719, track=9686) - Total: 63
# ✅ Added pixel: (slit=664, track=9725) - Total: 64
# ✅ Added pixel: (slit=578, track=9731) - Total: 65
# ✅ Added pixel: (slit=519, track=9734) - Total: 66
# ✅ Added pixel: (slit=502, track=9591) - Total: 67
# ✅ Added pixel: (slit=455, track=9591) - Total: 68
# ✅ Added pixel: (slit=395, track=9628) - Total: 69
# ✅ Added pixel: (slit=354, track=9637) - Total: 70
# ✅ Added pixel: (slit=322, track=9623) - Total: 71
# ✅ Added pixel: (slit=260, track=9651) - Total: 72
# ✅ Added pixel: (slit=222, track=9647) - Total: 73
# ✅ Added pixel: (slit=193, track=9573) - Total: 74
# ✅ Added pixel: (slit=200, track=9547) - Total: 75
# ✅ Added pixel: (slit=218, track=9533) - Total: 76
# ✅ Added pixel: (slit=232, track=9524) - Total: 77
# 📌 Pixel already selected: (slit=232, track=9524)
# ✅ Added pixel: (slit=186, track=9542) - Total: 78
# ✅ Added pixel: (slit=136, track=9544) - Total: 79
# ✅ Added pixel: (slit=82, track=9527) - Total: 80
# ✅ Added pixel: (slit=38, track=9246) - Total: 81
# ✅ Added pixel: (slit=57, track=9240) - Total: 82
# ✅ Added pixel: (slit=96, track=9236) - Total: 83
# ✅ Added pixel: (slit=127, track=9234) - Total: 84
# ✅ Added pixel: (slit=166, track=9234) - Total: 85
# ✅ Added pixel: (slit=215, track=9220) - Total: 86
# ✅ Added pixel: (slit=220, track=9218) - Total: 87
# ✅ Added pixel: (slit=254, track=9113) - Total: 88
# ✅ Added pixel: (slit=220, track=9102) - Total: 89
# ✅ Added pixel: (slit=178, track=9116) - Total: 90
# ✅ Added pixel: (slit=146, track=9128) - Total: 91
# ✅ Added pixel: (slit=109, track=9128) - Total: 92
# ✅ Added pixel: (slit=67, track=9117) - Total: 93
# ✅ Added pixel: (slit=257, track=9019) - Total: 94
# ✅ Added pixel: (slit=287, track=8979) - Total: 95
# ✅ Added pixel: (slit=324, track=8940) - Total: 96
# ✅ Added pixel: (slit=260, track=8935) - Total: 97
# ✅ Added pixel: (slit=181, track=8946) - Total: 98
# ✅ Added pixel: (slit=102, track=8941) - Total: 99
# ✅ Added pixel: (slit=457, track=9069) - Total: 100
# ✅ Added pixel: (slit=479, track=9058) - Total: 101
# ✅ Added pixel: (slit=521, track=9035) - Total: 102
# ✅ Added pixel: (slit=541, track=9049) - Total: 103
# ✅ Added pixel: (slit=546, track=9041) - Total: 104
# ✅ Added pixel: (slit=595, track=9032) - Total: 105
# ✅ Added pixel: (slit=682, track=9025) - Total: 106
# ✅ Added pixel: (slit=727, track=9035) - Total: 107
# ✅ Added pixel: (slit=756, track=9064) - Total: 108
# ✅ Added pixel: (slit=761, track=9075) - Total: 109
# ✅ Added pixel: (slit=835, track=9116) - Total: 110
# ✅ Added pixel: (slit=833, track=9114) - Total: 111
# ✅ Added pixel: (slit=768, track=9108) - Total: 112
# ✅ Added pixel: (slit=712, track=9106) - Total: 113
# ✅ Added pixel: (slit=694, track=9106) - Total: 114
# ✅ Added pixel: (slit=746, track=9106) - Total: 115
# ✅ Added pixel: (slit=790, track=9106) - Total: 116
# ✅ Added pixel: (slit=793, track=9019) - Total: 117
# ✅ Added pixel: (slit=784, track=9019) - Total: 118
# ✅ Added pixel: (slit=716, track=9011) - Total: 119
# ✅ Added pixel: (slit=672, track=9011) - Total: 120
# ✅ Added pixel: (slit=628, track=9013) - Total: 121
# ✅ Added pixel: (slit=242, track=8823) - Total: 122
# ✅ Added pixel: (slit=233, track=8789) - Total: 123
# ✅ Added pixel: (slit=225, track=8756) - Total: 124
# ✅ Added pixel: (slit=205, track=8728) - Total: 125
# ✅ Added pixel: (slit=178, track=8709) - Total: 126
# ✅ Added pixel: (slit=134, track=8680) - Total: 127
# ✅ Added pixel: (slit=109, track=8653) - Total: 128
# ✅ Added pixel: (slit=99, track=8633) - Total: 129
# ✅ Added pixel: (slit=200, track=8700) - Total: 130
# ✅ Added pixel: (slit=248, track=8751) - Total: 131
# ✅ Added pixel: (slit=262, track=8782) - Total: 132
# ✅ Added pixel: (slit=82, track=8884) - Total: 133
# ✅ Added pixel: (slit=75, track=8896) - Total: 134
# ✅ Added pixel: (slit=64, track=8905) - Total: 135
# ✅ Added pixel: (slit=28, track=8963) - Total: 136
# ✅ Added pixel: (slit=32, track=8986) - Total: 137
# ✅ Added pixel: (slit=33, track=8991) - Total: 138
# ✅ Added pixel: (slit=166, track=8933) - Total: 139
# ✅ Added pixel: (slit=164, track=8933) - Total: 140
# ✅ Added pixel: (slit=156, track=8947) - Total: 141
# 📌 Pixel already selected: (slit=156, track=8947)
# ✅ Added pixel: (slit=30, track=9111) - Total: 142
# ✅ Added pixel: (slit=38, track=9123) - Total: 143
# ✅ Added pixel: (slit=92, track=9134) - Total: 144
# ✅ Added pixel: (slit=151, track=9114) - Total: 145
# ✅ Added pixel: (slit=299, track=9237) - Total: 146
# ✅ Added pixel: (slit=243, track=9222) - Total: 147
# ✅ Added pixel: (slit=279, track=9220) - Total: 148
# ✅ Added pixel: (slit=351, track=9195) - Total: 149
# ✅ Added pixel: (slit=388, track=9181) - Total: 150
# ✅ Added pixel: (slit=428, track=9176) - Total: 151
# ✅ Added pixel: (slit=501, track=9293) - Total: 152
# ✅ Added pixel: (slit=475, track=9295) - Total: 153
# ✅ Added pixel: (slit=447, track=9295) - Total: 154
# ✅ Added pixel: (slit=516, track=9321) - Total: 155
# ✅ Added pixel: (slit=492, track=9320) - Total: 156
# ✅ Added pixel: (slit=339, track=9338) - Total: 157
# ✅ Added pixel: (slit=316, track=9332) - Total: 158
# ✅ Added pixel: (slit=287, track=9327) - Total: 159
# ✅ Added pixel: (slit=262, track=9338) - Total: 160
# ✅ Added pixel: (slit=242, track=9337) - Total: 161
# ✅ Added pixel: (slit=143, track=9558) - Total: 162
# ✅ Added pixel: (slit=143, track=9556) - Total: 163
# ✅ Added pixel: (slit=166, track=9588) - Total: 164
# ✅ Added pixel: (slit=213, track=9600) - Total: 165
# ✅ Added pixel: (slit=417, track=9608) - Total: 166
# ✅ Added pixel: (slit=422, track=9606) - Total: 167
# ✅ Added pixel: (slit=457, track=9628) - Total: 168
# ✅ Added pixel: (slit=366, track=9650) - Total: 169
# ✅ Added pixel: (slit=776, track=9670) - Total: 170
# 📌 Pixel already selected: (slit=776, track=9670)
# ✅ Added pixel: (slit=742, track=9668) - Total: 171
# ✅ Added pixel: (slit=729, track=9668) - Total: 172
# ✅ Added pixel: (slit=726, track=9668) - Total: 173
# ✅ Added pixel: (slit=759, track=9721) - Total: 174
# ✅ Added pixel: (slit=751, track=9717) - Total: 175
# ✅ Added pixel: (slit=727, track=9711) - Total: 176
# ✅ Added pixel: (slit=627, track=9729) - Total: 177
# 💾 Saved ROI 'sediment' with 177 pixels

# %%
cube.plot_interactive_rgb(roi_name="dark_pit", use_corrected=True, marker_size=2)
# Out:
# ✨ Creating new ROI 'dark_pit'
# []
# ✅ Added pixel: (slit=817, track=9736) - Total: 1
# ❌ Removed nearest pixel: (slit=817, track=9736) [distance: 1.0 pixels] - Total: 0
# ✅ Added pixel: (slit=702, track=9514) - Total: 1
# ✅ Added pixel: (slit=703, track=9514) - Total: 2
# ✅ Added pixel: (slit=710, track=9516) - Total: 3
# ✅ Added pixel: (slit=714, track=9517) - Total: 4
# ✅ Added pixel: (slit=717, track=9517) - Total: 5
# ✅ Added pixel: (slit=720, track=9518) - Total: 6
# ✅ Added pixel: (slit=722, track=9518) - Total: 7
# ✅ Added pixel: (slit=724, track=9517) - Total: 8
# ✅ Added pixel: (slit=725, track=9516) - Total: 9
# ✅ Added pixel: (slit=725, track=9515) - Total: 10
# ✅ Added pixel: (slit=717, track=9513) - Total: 11
# ✅ Added pixel: (slit=711, track=9513) - Total: 12
# ✅ Added pixel: (slit=707, track=9514) - Total: 13
# ✅ Added pixel: (slit=706, track=9516) - Total: 14
# ✅ Added pixel: (slit=708, track=9517) - Total: 15
# ✅ Added pixel: (slit=716, track=9518) - Total: 16
# ✅ Added pixel: (slit=719, track=9518) - Total: 17
# ✅ Added pixel: (slit=724, track=9518) - Total: 18
# ✅ Added pixel: (slit=726, track=9517) - Total: 19
# ✅ Added pixel: (slit=728, track=9516) - Total: 20
# ✅ Added pixel: (slit=730, track=9514) - Total: 21
# ✅ Added pixel: (slit=726, track=9513) - Total: 22
# ✅ Added pixel: (slit=722, track=9513) - Total: 23
# ✅ Added pixel: (slit=712, track=9513) - Total: 24
# ✅ Added pixel: (slit=710, track=9513) - Total: 25
# 📌 Pixel already selected: (slit=707, track=9514)
# ✅ Added pixel: (slit=707, track=9516) - Total: 26
# 📌 Pixel already selected: (slit=707, track=9516)
# ✅ Added pixel: (slit=711, track=9518) - Total: 27
# ✅ Added pixel: (slit=715, track=9519) - Total: 28
# ✅ Added pixel: (slit=717, track=9519) - Total: 29
# ✅ Added pixel: (slit=725, track=9520) - Total: 30
# ✅ Added pixel: (slit=726, track=9519) - Total: 31
# ✅ Added pixel: (slit=733, track=9519) - Total: 32
# ✅ Added pixel: (slit=734, track=9518) - Total: 33
# ✅ Added pixel: (slit=737, track=9517) - Total: 34
# ✅ Added pixel: (slit=738, track=9515) - Total: 35
# ✅ Added pixel: (slit=734, track=9513) - Total: 36
# ✅ Added pixel: (slit=723, track=9512) - Total: 37
# ✅ Added pixel: (slit=711, track=9511) - Total: 38
# ✅ Added pixel: (slit=702, track=9511) - Total: 39
# ✅ Added pixel: (slit=695, track=9515) - Total: 40
# ✅ Added pixel: (slit=695, track=9519) - Total: 41
# ✅ Added pixel: (slit=702, track=9522) - Total: 42
# ✅ Added pixel: (slit=718, track=9523) - Total: 43
# ✅ Added pixel: (slit=731, track=9522) - Total: 44
# ✅ Added pixel: (slit=740, track=9521) - Total: 45
# ✅ Added pixel: (slit=745, track=9518) - Total: 46
# ✅ Added pixel: (slit=745, track=9516) - Total: 47
# ✅ Added pixel: (slit=735, track=9511) - Total: 48
# ✅ Added pixel: (slit=717, track=9509) - Total: 49
# ✅ Added pixel: (slit=704, track=9510) - Total: 50
# ✅ Added pixel: (slit=696, track=9512) - Total: 51
# ✅ Added pixel: (slit=693, track=9517) - Total: 52
# ✅ Added pixel: (slit=707, track=9520) - Total: 53
# ✅ Added pixel: (slit=726, track=9520) - Total: 54
# ✅ Added pixel: (slit=728, track=9515) - Total: 55
# ✅ Added pixel: (slit=719, track=9513) - Total: 56
# ✅ Added pixel: (slit=703, track=9513) - Total: 57
# ✅ Added pixel: (slit=707, track=9517) - Total: 58
# ✅ Added pixel: (slit=714, track=9518) - Total: 59
# ✅ Added pixel: (slit=721, track=9516) - Total: 60
# ✅ Added pixel: (slit=717, track=9515) - Total: 61
# ✅ Added pixel: (slit=715, track=9515) - Total: 62
# ✅ Added pixel: (slit=726, track=9515) - Total: 63
# ✅ Added pixel: (slit=727, track=9516) - Total: 64
# ✅ Added pixel: (slit=720, track=9515) - Total: 65
# ✅ Added pixel: (slit=719, track=9515) - Total: 66
# 📌 Pixel already selected: (slit=719, track=9513)
# ✅ Added pixel: (slit=714, track=9511) - Total: 67
# 📌 Pixel already selected: (slit=711, track=9513)
# ✅ Added pixel: (slit=709, track=9517) - Total: 68
# ✅ Added pixel: (slit=709, track=9518) - Total: 69
# 📌 Pixel already selected: (slit=721, track=9516)
# ✅ Added pixel: (slit=721, track=9515) - Total: 70
# ✅ Added pixel: (slit=722, track=9515) - Total: 71
# 💾 Saved ROI 'dark_pit' with 71 pixels

# %%
cube.plot_interactive_rgb(
    roi_name="dark_pit_with_bomb", use_corrected=True, marker_size=2
)
# Out:
# ✨ Creating new ROI 'dark_pit_with_bomb'
# []
# ✅ Added pixel: (slit=470, track=9206) - Total: 1
# ❌ Removed nearest pixel: (slit=470, track=9206) [distance: 6.1 pixels] - Total: 0
# ⚠️ No pixel within 10 pixels of click: (slit=468, track=9207)
# ⚠️ No pixel within 10 pixels of click: (slit=468, track=9207)
# ⚠️ No pixel within 10 pixels of click: (slit=469, track=9206)
# ⚠️ No pixel within 10 pixels of click: (slit=469, track=9206)
# ✅ Added pixel: (slit=324, track=9375) - Total: 1
# ✅ Added pixel: (slit=321, track=9380) - Total: 2
# ✅ Added pixel: (slit=319, track=9381) - Total: 3
# ✅ Added pixel: (slit=316, track=9383) - Total: 4
# ✅ Added pixel: (slit=314, track=9385) - Total: 5
# ✅ Added pixel: (slit=312, track=9386) - Total: 6
# ✅ Added pixel: (slit=309, track=9388) - Total: 7
# ✅ Added pixel: (slit=308, track=9389) - Total: 8
# ✅ Added pixel: (slit=308, track=9390) - Total: 9
# ✅ Added pixel: (slit=309, track=9391) - Total: 10
# ✅ Added pixel: (slit=312, track=9393) - Total: 11
# ✅ Added pixel: (slit=314, track=9394) - Total: 12
# ✅ Added pixel: (slit=319, track=9394) - Total: 13
# ✅ Added pixel: (slit=323, track=9395) - Total: 14
# ✅ Added pixel: (slit=327, track=9394) - Total: 15
# ✅ Added pixel: (slit=329, track=9394) - Total: 16
# 📌 Pixel already selected: (slit=329, track=9394)
# 📌 Pixel already selected: (slit=329, track=9394)
# 📌 Pixel already selected: (slit=329, track=9394)
# 📌 Pixel already selected: (slit=329, track=9394)
# 📌 Pixel already selected: (slit=329, track=9394)
# 📌 Pixel already selected: (slit=329, track=9394)
# 📌 Pixel already selected: (slit=329, track=9394)
# 📌 Pixel already selected: (slit=329, track=9394)
# 📌 Pixel already selected: (slit=329, track=9394)
# 📌 Pixel already selected: (slit=329, track=9394)
# 📌 Pixel already selected: (slit=329, track=9394)
# 📌 Pixel already selected: (slit=329, track=9394)
# 📌 Pixel already selected: (slit=329, track=9394)
# ✅ Added pixel: (slit=332, track=9378) - Total: 17
# ✅ Added pixel: (slit=332, track=9377) - Total: 18
# ✅ Added pixel: (slit=333, track=9376) - Total: 19
# ✅ Added pixel: (slit=333, track=9380) - Total: 20
# 📌 Pixel already selected: (slit=333, track=9380)
# ✅ Added pixel: (slit=333, track=9381) - Total: 21
# ✅ Added pixel: (slit=330, track=9383) - Total: 22
# ✅ Added pixel: (slit=326, track=9386) - Total: 23
# ✅ Added pixel: (slit=325, track=9389) - Total: 24
# ✅ Added pixel: (slit=323, track=9392) - Total: 25
# 📌 Pixel already selected: (slit=323, track=9392)
# 📌 Pixel already selected: (slit=323, track=9392)
# ✅ Added pixel: (slit=327, track=9387) - Total: 26
# ✅ Added pixel: (slit=326, track=9384) - Total: 27
# ✅ Added pixel: (slit=326, track=9382) - Total: 28
# ✅ Added pixel: (slit=327, track=9382) - Total: 29
# 📌 Pixel already selected: (slit=326, track=9384)
# ✅ Added pixel: (slit=322, track=9388) - Total: 30
# ✅ Added pixel: (slit=318, track=9390) - Total: 31
# ✅ Added pixel: (slit=317, track=9391) - Total: 32
# ✅ Added pixel: (slit=326, track=9388) - Total: 33
# 📌 Pixel already selected: (slit=326, track=9382)
# ✅ Added pixel: (slit=326, track=9381) - Total: 34
# ✅ Added pixel: (slit=328, track=9378) - Total: 35
# 📌 Pixel already selected: (slit=328, track=9378)
# ✅ Added pixel: (slit=324, track=9381) - Total: 36
# ✅ Added pixel: (slit=313, track=9387) - Total: 37
# ✅ Added pixel: (slit=311, track=9388) - Total: 38
# ✅ Added pixel: (slit=313, track=9390) - Total: 39
# 📌 Pixel already selected: (slit=313, track=9390)
# ✅ Added pixel: (slit=326, track=9390) - Total: 40
# ✅ Added pixel: (slit=324, track=9389) - Total: 41
# ✅ Added pixel: (slit=320, track=9387) - Total: 42
# ✅ Added pixel: (slit=321, track=9382) - Total: 43
# ✅ Added pixel: (slit=318, track=9377) - Total: 44
# ✅ Added pixel: (slit=324, track=9377) - Total: 45
# ✅ Added pixel: (slit=325, track=9377) - Total: 46
# ✅ Added pixel: (slit=326, track=9378) - Total: 47
# ✅ Added pixel: (slit=327, track=9379) - Total: 48
# ✅ Added pixel: (slit=329, track=9379) - Total: 49
# ✅ Added pixel: (slit=333, track=9378) - Total: 50
# ✅ Added pixel: (slit=337, track=9384) - Total: 51
# ✅ Added pixel: (slit=335, track=9388) - Total: 52
# ✅ Added pixel: (slit=324, track=9386) - Total: 53
# ✅ Added pixel: (slit=324, track=9384) - Total: 54
# 📌 Pixel already selected: (slit=324, track=9384)
# ✅ Added pixel: (slit=324, track=9385) - Total: 55
# ✅ Added pixel: (slit=322, track=9386) - Total: 56
# 📌 Pixel already selected: (slit=322, track=9386)
# ✅ Added pixel: (slit=319, track=9387) - Total: 57
# ✅ Added pixel: (slit=317, track=9388) - Total: 58
# ✅ Added pixel: (slit=314, track=9389) - Total: 59
# ✅ Added pixel: (slit=320, track=9384) - Total: 60
# 📌 Pixel already selected: (slit=320, track=9384)
# ✅ Added pixel: (slit=320, track=9385) - Total: 61
# 📌 Pixel already selected: (slit=320, track=9385)
# ✅ Added pixel: (slit=316, track=9385) - Total: 62
# 📌 Pixel already selected: (slit=316, track=9385)
# ✅ Added pixel: (slit=316, track=9386) - Total: 63
# ✅ Added pixel: (slit=315, track=9387) - Total: 64
# ✅ Added pixel: (slit=314, track=9387) - Total: 65
# ✅ Added pixel: (slit=314, track=9388) - Total: 66
# ✅ Added pixel: (slit=313, track=9388) - Total: 67
# ✅ Added pixel: (slit=315, track=9385) - Total: 68
# 📌 Pixel already selected: (slit=316, track=9385)
# ✅ Added pixel: (slit=318, track=9384) - Total: 69
# 📌 Pixel already selected: (slit=320, track=9384)
# 📌 Pixel already selected: (slit=320, track=9384)
# 💾 Saved ROI 'dark_pit_with_bomb' with 69 pixels

# %%
cube.plot_interactive_rgb(roi_name="halo", use_corrected=True, marker_size=1)
# Out:
# ✨ Creating new ROI 'halo'
# []
# ✅ Added pixel: (slit=469, track=6488) - Total: 1
# ✅ Added pixel: (slit=336, track=6646) - Total: 2
# ✅ Added pixel: (slit=333, track=6645) - Total: 3
# ✅ Added pixel: (slit=330, track=6646) - Total: 4
# ✅ Added pixel: (slit=329, track=6647) - Total: 5
# ✅ Added pixel: (slit=329, track=6649) - Total: 6
# ✅ Added pixel: (slit=332, track=6650) - Total: 7
# ✅ Added pixel: (slit=336, track=6652) - Total: 8
# ✅ Added pixel: (slit=339, track=6653) - Total: 9
# 📌 Pixel already selected: (slit=339, track=6653)
# ✅ Added pixel: (slit=341, track=6654) - Total: 10
# ✅ Added pixel: (slit=343, track=6654) - Total: 11
# ✅ Added pixel: (slit=346, track=6654) - Total: 12
# ✅ Added pixel: (slit=350, track=6655) - Total: 13
# ✅ Added pixel: (slit=351, track=6655) - Total: 14
# ✅ Added pixel: (slit=354, track=6655) - Total: 15
# ✅ Added pixel: (slit=356, track=6655) - Total: 16
# ✅ Added pixel: (slit=358, track=6655) - Total: 17
# ✅ Added pixel: (slit=359, track=6655) - Total: 18
# ✅ Added pixel: (slit=361, track=6655) - Total: 19
# 📌 Pixel already selected: (slit=358, track=6655)
# ✅ Added pixel: (slit=355, track=6655) - Total: 20
# ✅ Added pixel: (slit=357, track=6640) - Total: 21
# 📌 Pixel already selected: (slit=357, track=6640)
# ✅ Added pixel: (slit=355, track=6641) - Total: 22
# ✅ Added pixel: (slit=352, track=6641) - Total: 23
# ✅ Added pixel: (slit=351, track=6641) - Total: 24
# ✅ Added pixel: (slit=349, track=6641) - Total: 25
# ✅ Added pixel: (slit=348, track=6641) - Total: 26
# ✅ Added pixel: (slit=346, track=6642) - Total: 27
# ✅ Added pixel: (slit=344, track=6642) - Total: 28
# ✅ Added pixel: (slit=343, track=6642) - Total: 29
# ✅ Added pixel: (slit=343, track=6643) - Total: 30
# ✅ Added pixel: (slit=341, track=6644) - Total: 31
# ✅ Added pixel: (slit=340, track=6644) - Total: 32
# ✅ Added pixel: (slit=339, track=6644) - Total: 33
# ✅ Added pixel: (slit=337, track=6645) - Total: 34
# ✅ Added pixel: (slit=336, track=6645) - Total: 35
# ✅ Added pixel: (slit=396, track=6642) - Total: 36
# ✅ Added pixel: (slit=384, track=6639) - Total: 37
# ✅ Added pixel: (slit=370, track=6639) - Total: 38
# ✅ Added pixel: (slit=363, track=6640) - Total: 39
# ✅ Added pixel: (slit=404, track=6648) - Total: 40
# ✅ Added pixel: (slit=396, track=6651) - Total: 41
# ✅ Added pixel: (slit=394, track=6652) - Total: 42
# ✅ Added pixel: (slit=390, track=6654) - Total: 43
# ✅ Added pixel: (slit=383, track=6655) - Total: 44
# ✅ Added pixel: (slit=379, track=6656) - Total: 45
# ✅ Added pixel: (slit=375, track=6656) - Total: 46
# ✅ Added pixel: (slit=371, track=6655) - Total: 47
# ✅ Added pixel: (slit=376, track=6655) - Total: 48
# ✅ Added pixel: (slit=379, track=6655) - Total: 49
# ✅ Added pixel: (slit=380, track=6655) - Total: 50
# ❌ Removed nearest pixel: (slit=379, track=6656) [distance: 1.0 pixels] - Total: 49
# ❌ Removed nearest pixel: (slit=379, track=6655) [distance: 1.4 pixels] - Total: 48
# ❌ Removed nearest pixel: (slit=375, track=6656) [distance: 1.0 pixels] - Total: 47
# ✅ Added pixel: (slit=330, track=6648) - Total: 48
# ❌ Removed nearest pixel: (slit=337, track=6645) [distance: 1.0 pixels] - Total: 47
# ❌ Removed nearest pixel: (slit=336, track=6646) [distance: 1.4 pixels] - Total: 46
# ✅ Added pixel: (slit=338, track=6653) - Total: 47
# 📌 Pixel already selected: (slit=329, track=6649)
# ✅ Added pixel: (slit=331, track=6647) - Total: 48
# ✅ Added pixel: (slit=333, track=6646) - Total: 49
# ✅ Added pixel: (slit=332, track=6645) - Total: 50
# 📌 Pixel already selected: (slit=330, track=6646)
# 📌 Pixel already selected: (slit=330, track=6646)
# ✅ Added pixel: (slit=330, track=6647) - Total: 51
# ✅ Added pixel: (slit=328, track=6648) - Total: 52
# 📌 Pixel already selected: (slit=341, track=6654)
# 📌 Pixel already selected: (slit=341, track=6654)
# ✅ Added pixel: (slit=341, track=6653) - Total: 53
# ✅ Added pixel: (slit=340, track=6653) - Total: 54
# ✅ Added pixel: (slit=336, track=6651) - Total: 55
# ✅ Added pixel: (slit=334, track=6651) - Total: 56
# ✅ Added pixel: (slit=332, track=6648) - Total: 57
# ✅ Added pixel: (slit=330, track=6649) - Total: 58
# ✅ Added pixel: (slit=332, track=6646) - Total: 59
# 📌 Pixel already selected: (slit=336, track=6645)
# ✅ Added pixel: (slit=335, track=6645) - Total: 60
# 💾 Saved ROI 'halo' with 60 pixels

# %%
cube.plot_interactive_rgb(roi_name="halo_real", use_corrected=True, marker_size=1)
# Out:
# ✨ Creating new ROI 'halo_real'
# []
# c:\conda_envs\my_env\lib\site-packages\ipykernel\eventloops.py:145: UserWarning: Glyph 128433 (\N{THREE BUTTON MOUSE}) missing from font(s) DejaVu Sans.
#   el.exec() if hasattr(el, "exec") else el.exec_()
# ✅ Added pixel: (slit=337, track=9304) - Total: 1
# ❌ Removed nearest pixel: (slit=337, track=9304) [distance: 2.2 pixels] - Total: 0
# ✅ Added pixel: (slit=291, track=9384) - Total: 1
# ✅ Added pixel: (slit=287, track=9385) - Total: 2
# ✅ Added pixel: (slit=283, track=9385) - Total: 3
# ✅ Added pixel: (slit=274, track=9385) - Total: 4
# ✅ Added pixel: (slit=269, track=9385) - Total: 5
# ✅ Added pixel: (slit=244, track=9372) - Total: 6
# ✅ Added pixel: (slit=244, track=9373) - Total: 7
# ✅ Added pixel: (slit=246, track=9374) - Total: 8
# ✅ Added pixel: (slit=247, track=9374) - Total: 9
# ✅ Added pixel: (slit=248, track=9374) - Total: 10
# ✅ Added pixel: (slit=248, track=9373) - Total: 11
# ✅ Added pixel: (slit=246, track=9372) - Total: 12
# ✅ Added pixel: (slit=242, track=9377) - Total: 13
# ✅ Added pixel: (slit=243, track=9376) - Total: 14
# 📌 Pixel already selected: (slit=242, track=9377)
# ✅ Added pixel: (slit=242, track=9376) - Total: 15
# 📌 Pixel already selected: (slit=243, track=9376)
# 📌 Pixel already selected: (slit=243, track=9376)
# ✅ Added pixel: (slit=245, track=9376) - Total: 16
# 📌 Pixel already selected: (slit=245, track=9376)
# 📌 Pixel already selected: (slit=242, track=9376)
# ✅ Added pixel: (slit=240, track=9377) - Total: 17
# ✅ Added pixel: (slit=239, track=9377) - Total: 18
# ✅ Added pixel: (slit=237, track=9378) - Total: 19
# ✅ Added pixel: (slit=237, track=9380) - Total: 20
# 📌 Pixel already selected: (slit=237, track=9380)
# ✅ Added pixel: (slit=237, track=9379) - Total: 21
# ✅ Added pixel: (slit=237, track=9381) - Total: 22
# ✅ Added pixel: (slit=239, track=9381) - Total: 23
# ✅ Added pixel: (slit=241, track=9382) - Total: 24
# 📌 Pixel already selected: (slit=241, track=9382)
# ✅ Added pixel: (slit=243, track=9383) - Total: 25
# ✅ Added pixel: (slit=244, track=9383) - Total: 26
# ✅ Added pixel: (slit=245, track=9383) - Total: 27
# 📌 Pixel already selected: (slit=245, track=9383)
# 📌 Pixel already selected: (slit=245, track=9383)
# 📌 Pixel already selected: (slit=245, track=9383)
# 📌 Pixel already selected: (slit=244, track=9383)
# 📌 Pixel already selected: (slit=243, track=9383)
# 📌 Pixel already selected: (slit=241, track=9382)
# 📌 Pixel already selected: (slit=241, track=9382)
# ✅ Added pixel: (slit=240, track=9382) - Total: 28
# ✅ Added pixel: (slit=244, track=9382) - Total: 29
# 📌 Pixel already selected: (slit=244, track=9383)
# ✅ Added pixel: (slit=283, track=9373) - Total: 30
# ✅ Added pixel: (slit=283, track=9372) - Total: 31
# ✅ Added pixel: (slit=288, track=9372) - Total: 32
# ✅ Added pixel: (slit=294, track=9372) - Total: 33
# ✅ Added pixel: (slit=298, track=9372) - Total: 34
# ✅ Added pixel: (slit=299, track=9373) - Total: 35
# ✅ Added pixel: (slit=291, track=9372) - Total: 36
# ✅ Added pixel: (slit=282, track=9372) - Total: 37
# ✅ Added pixel: (slit=288, track=9373) - Total: 38
# ✅ Added pixel: (slit=289, track=9373) - Total: 39
# ✅ Added pixel: (slit=291, track=9373) - Total: 40
# ✅ Added pixel: (slit=292, track=9373) - Total: 41
# ✅ Added pixel: (slit=295, track=9373) - Total: 42
# ✅ Added pixel: (slit=296, track=9373) - Total: 43
# ✅ Added pixel: (slit=301, track=9375) - Total: 44
# 📌 Pixel already selected: (slit=301, track=9375)
# ✅ Added pixel: (slit=302, track=9376) - Total: 45
# ✅ Added pixel: (slit=303, track=9376) - Total: 46
# ✅ Added pixel: (slit=303, track=9375) - Total: 47
# ✅ Added pixel: (slit=299, track=9375) - Total: 48
# ✅ Added pixel: (slit=297, track=9374) - Total: 49
# ✅ Added pixel: (slit=293, track=9373) - Total: 50
# ✅ Added pixel: (slit=282, track=9373) - Total: 51
# ✅ Added pixel: (slit=295, track=9383) - Total: 52
# ✅ Added pixel: (slit=294, track=9384) - Total: 53
# ✅ Added pixel: (slit=292, track=9385) - Total: 54
# ✅ Added pixel: (slit=279, track=9385) - Total: 55
# ✅ Added pixel: (slit=275, track=9386) - Total: 56
# ✅ Added pixel: (slit=277, track=9386) - Total: 57
# ✅ Added pixel: (slit=270, track=9386) - Total: 58
# ✅ Added pixel: (slit=248, track=9383) - Total: 59
# 📌 Pixel already selected: (slit=246, track=9374)
# ✅ Added pixel: (slit=247, track=9375) - Total: 60
# ✅ Added pixel: (slit=247, track=9372) - Total: 61
# ✅ Added pixel: (slit=246, track=9375) - Total: 62
# ✅ Added pixel: (slit=281, track=9373) - Total: 63
# 📌 Pixel already selected: (slit=289, track=9373)
# 📌 Pixel already selected: (slit=303, track=9375)
# ✅ Added pixel: (slit=298, track=9374) - Total: 64
# 📌 Pixel already selected: (slit=298, track=9374)
# ✅ Added pixel: (slit=238, track=9380) - Total: 65
# ✅ Added pixel: (slit=242, track=9382) - Total: 66
# ✅ Added pixel: (slit=246, track=9383) - Total: 67
# 📌 Pixel already selected: (slit=248, track=9383)
# ✅ Added pixel: (slit=276, track=9386) - Total: 68
# ✅ Added pixel: (slit=288, track=9384) - Total: 69
# ✅ Added pixel: (slit=292, track=9384) - Total: 70
# 📌 Pixel already selected: (slit=292, track=9384)
# ✅ Added pixel: (slit=280, track=9385) - Total: 71
# ✅ Added pixel: (slit=271, track=9386) - Total: 72
# 📌 Pixel already selected: (slit=270, track=9386)
# 📌 Pixel already selected: (slit=281, track=9373)
# ✅ Added pixel: (slit=290, track=9373) - Total: 73
# ✅ Added pixel: (slit=304, track=9379) - Total: 74
# ✅ Added pixel: (slit=305, track=9376) - Total: 75
# ✅ Added pixel: (slit=306, track=9378) - Total: 76
# ✅ Added pixel: (slit=303, track=9378) - Total: 77
# ✅ Added pixel: (slit=305, track=9378) - Total: 78
# ✅ Added pixel: (slit=304, track=9377) - Total: 79
# ✅ Added pixel: (slit=258, track=9384) - Total: 80
# ✅ Added pixel: (slit=265, track=9384) - Total: 81
# ✅ Added pixel: (slit=267, track=9385) - Total: 82
# ✅ Added pixel: (slit=265, track=9385) - Total: 83
# 📌 Pixel already selected: (slit=243, track=9383)
# ✅ Added pixel: (slit=246, track=9373) - Total: 84
# 💾 Saved ROI 'halo_real' with 84 pixels

# %% [markdown]
# # ROI operations

# %%
stop

# %%
# List all ROIs
cube.list_rois()
# Out:
# ❌ No ROIs saved yet

# %%
cube.export_rois("./ROIs/028.json")
# Out:
# 💾 Exported 6 ROIs to ./ROIs/028.json

# %%
# Delete specific ROI
cube.delete_roi("halo")
# Out:
# 🗑️  Deleted ROI 'halo' (60 pixels)

# %%
# # cube.import_rois("./ROIs/057_5_SVM.json")
# cube.import_rois("./ROIs/057_5_combined.json")
# Out:
# 📂 Imported 6 ROIs from ./ROIs/057_5_combined.json

# %%
cube.rename_roi(old_roi_name="dark_pits", new_roi_name="training_dark")
cube.rename_roi(old_roi_name="sediment", new_roi_name="training_sediment")
cube.rename_roi(old_roi_name="bombs", new_roi_name="training_bombs")

# %% [markdown]
# # check rois

# %%
# %matplotlib inline
cube.plot_georef(
    # apply_alignment_shift=True,
    use_corrected=False,
    # track_start=config.UHI_TRACK_RANGE_5[0],
    # track_end=config.UHI_TRACK_RANGE_5[1],
    figsize=(30, 10),
    roi_collection="all",
    roi_marker_size=2,
    roi_legend_loc="outside",
    roi_marker_edgewidth=0,
    roi_legend_markersize=40,
)
# Out:
# 💡 Interactive mode: Click on the plot to display coordinates

# %%
roi_028 = [
    # "rust",
    "sediment",
    # "dark_pit",
    # "halo",
    # "dark_pit_with_bomb",
    # "halo_real",
    # "",
]

# %%
# %matplotlib qt
# %matplotlib inline

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    # interpolate_wavelengths=[35, 104, 157],
    legend_loc="outside",
    use_inline_labels=False,
    figsize=(20, 10),
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    # interpolate_wavelengths=[35, 104, 157],
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(430, 750),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    track_index=300,
    slit_index=50,
    # roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    track_index=300,
    slit_index=50,
    # roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
    smooth_before_filter=True,
)
# Out:
# c:\Users\Erik Liu\OneDrive - NTNU\PhD\Courses\UHI post processing\havard_repo\from_Leo_usb\gref4hsi\gref4hsi\final_act\utils\gref_pipeline\georef.py:6835: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   label_y = plot_avg[-10:].mean()

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    # wavelength_range=(450, 700),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    # wavelength_range=(450, 700),
    wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=20,
    # interpolate_wavelengths=[35, 104, 157],
    legend_loc="outside",
    use_inline_labels=False,
    normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=30,
    smoothing_method="savgol",
    savgol_polyorder=3,
    # interpolate_wavelengths=[35, 104, 157],
    legend_loc="outside",
    use_inline_labels=False,
    normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=50,
    smoothing_method="savgol",
    savgol_polyorder=4,
    # interpolate_wavelengths=[35, 104, 157],
    legend_loc="outside",
    use_inline_labels=False,
    normalize_method="l2",
    show_std=False,
    # smooth_before_filter=True,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    normalize_method="l2",
    show_std=False,
    derivative_order=1,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=30,
    legend_loc="outside",
    use_inline_labels=False,
    normalize_method="l2",
    show_std=False,
    derivative_order=2,
)

# %% [markdown]
# # TEST: Percentile Clipping
#
# Test the new `apply_percentile_clipping()` function to remove extreme spikes before smoothing.

# %%
# Helper function to visualize histograms per band
def test_plot_band_histograms(cube, sample_every_n_bands=10, figsize=(20, 12)):
    """
    Plot histograms for sampled wavelength bands to see distribution of values.
    This helps you identify which bands have extreme outliers (spikes).
    """
    n_bands = cube.data_corrected.shape[2]
    band_indices = list(range(0, n_bands, sample_every_n_bands))

    n_plots = len(band_indices)
    n_cols = 5
    n_rows = (n_plots + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_rows, n_cols, figsize=figsize)
    axes = axes.flatten()

    for idx, band_idx in enumerate(band_indices):
        if band_idx >= n_bands:
            break

        # Get all values for this band
        band_data = cube.data_corrected[:, :, band_idx].flatten()

        # Plot histogram
        axes[idx].hist(band_data, bins=50, alpha=0.7, edgecolor="black")
        axes[idx].set_title(
            f"Band {band_idx}\n{cube.wavelengths[band_idx]:.1f} nm", fontsize=10
        )
        axes[idx].set_xlabel("Intensity", fontsize=8)
        axes[idx].set_ylabel("Count", fontsize=8)
        axes[idx].grid(alpha=0.3)

        # Mark percentiles
        p5 = np.percentile(band_data, 5)
        p95 = np.percentile(band_data, 95)
        axes[idx].axvline(
            p5, color="red", linestyle="--", linewidth=1, alpha=0.7, label="5th %ile"
        )
        axes[idx].axvline(
            p95, color="red", linestyle="--", linewidth=1, alpha=0.7, label="95th %ile"
        )
        axes[idx].legend(fontsize=6)

    # Hide unused subplots
    for idx in range(len(band_indices), len(axes)):
        axes[idx].axis("off")

    plt.suptitle("Histogram per Band (sampled)", fontsize=14, fontweight="bold")
    plt.tight_layout()
    plt.show()


print("✅ test_plot_band_histograms() defined")
# Out:
# ✅ test_plot_band_histograms() defined

# %%
# Step 1: Look at histograms BEFORE clipping
print("📊 Histograms BEFORE percentile clipping:")
test_plot_band_histograms(cube, sample_every_n_bands=20)
# Out:
# 📊 Histograms BEFORE percentile clipping:

# %%
# Step 2: Save one example spectrum BEFORE clipping (for comparison)
# Pick a pixel from the middle of the cube (safer than using ROI which might be out of bounds)
T, S, B = cube.data_corrected.shape
example_t = T // 2
example_s = S // 2
example_spectrum_before = cube.data_corrected[example_t, example_s, :].copy()
print(
    f"✅ Saved example spectrum from cube center at track={example_t}, slit={example_s}"
)
# Out:
# ✅ Saved example spectrum from cube center at track=5013, slit=484

# %%
# Step 3: Apply percentile clipping
# TRY DIFFERENT VALUES: 5-95, 10-90, 2-98, etc.
cube.apply_percentile_clipping(lower_percentile=5, upper_percentile=95)
# Out:
# ============================================================
# ✂️ PERCENTILE CLIPPING (Per-Spectrum)
# ============================================================
# 📊 Datacube shape: (10027, 968, 210)
# 📉 Clipping range: 5th - 95th percentile
#
# 📈 Value range before clipping: [0.0000, 10878979.0000]
# 📉 Value range after clipping:  [0.0000, 13.3188]
# ✅ Clipping complete!
# ============================================================
# array([[[0.00000000e+00, 8.00363868e-02, 3.36138916e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          9.79862548e-03, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 6.24412894e-01, 0.00000000e+00, ...,
#          2.43312144e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          3.24271822e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 1.18552887e+00, ...,
#          2.34972164e-01, 0.00000000e+00, 0.00000000e+00],
#         [9.47257459e-01, 0.00000000e+00, 0.00000000e+00, ...,
#          3.01917344e-01, 0.00000000e+00, 0.00000000e+00]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          6.05699968e+00, 6.05699968e+00, 3.45664215e-03],
#         [0.00000000e+00, 1.00000000e+00, 9.11504328e-01, ...,
#          2.32659373e-02, 2.43540382e+00, 3.36993074e+00],
#         [0.00000000e+00, 2.92477322e+00, 0.00000000e+00, ...,
#          2.92477322e+00, 1.90113354e-02, 8.68073642e-01],
#         ...,
#         [1.75438598e-02, 0.00000000e+00, 1.00000000e+00, ...,
#          3.72378802e+00, 1.33838160e-02, 2.99430227e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          1.98360729e+00, 4.46460485e+00, 4.46460485e+00],
#         [0.00000000e+00, 1.98199582e+00, 0.00000000e+00, ...,
#          3.54448652e+00, 3.09236441e-03, 1.81136024e+00]],
#
#        [[0.00000000e+00, 4.21987295e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 4.62434626e+00, 1.53628865e-03],
#         [0.00000000e+00, 3.37125516e+00, 2.54227202e-02, ...,
#          0.00000000e+00, 3.37125516e+00, 1.27472639e+00],
#         [0.00000000e+00, 2.95954704e+00, 2.95954704e+00, ...,
#          3.63057196e-01, 1.52854491e-02, 2.05932403e+00],
#         ...,
#         [0.00000000e+00, 3.99544978e+00, 0.00000000e+00, ...,
#          4.70339119e-01, 0.00000000e+00, 1.28490031e+00],
#         [0.00000000e+00, 3.92014837e+00, 1.46382201e+00, ...,
#          2.85792470e+00, 4.19724464e+00, 3.82714182e-01],
#         [0.00000000e+00, 3.72013187e+00, 0.00000000e+00, ...,
#          4.00783730e+00, 1.39315668e-02, 1.81136024e+00]],
#
#        ...,
#
#        [[3.63110518e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 3.63110518e+00, 1.16181439e-02],
#         [5.75209093e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 4.66794825e+00, 5.75209093e+00],
#         [3.79534054e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 3.79534054e+00, 6.50349081e-01],
#         ...,
#         [1.40816319e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          4.53750181e+00, 1.27653405e-02, 3.60336947e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          4.16623211e+00, 4.16623211e+00, 4.16623211e+00],
#         [2.40280390e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 4.87507391e+00, 0.00000000e+00]],
#
#        [[0.00000000e+00, 6.32014573e-01, 5.48770189e+00, ...,
#          2.06427407e-02, 5.19848061e+00, 9.21770278e-03],
#         [2.65016556e+00, 3.81691527e+00, 4.00114107e+00, ...,
#          1.02630155e-02, 2.93049908e+00, 4.00114107e+00],
#         [1.87591171e+00, 0.00000000e+00, 4.79432869e+00, ...,
#          4.79432869e+00, 4.79432869e+00, 4.61305952e+00],
#         ...,
#         [1.32653058e+00, 1.39577746e+00, 5.77251148e+00, ...,
#          5.77251148e+00, 5.34362486e-03, 5.77251148e+00],
#         [0.00000000e+00, 0.00000000e+00, 5.40984488e+00, ...,
#          5.40984488e+00, 5.40984488e+00, 5.40984488e+00],
#         [2.50300431e+00, 9.10873473e-01, 3.11982632e+00, ...,
#          2.55792458e-02, 3.11982632e+00, 3.11982632e+00]],
#
#        [[0.00000000e+00, 3.01844072e+00, 3.01844072e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [6.69966877e-01, 3.93482018e+00, 3.93482018e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 1.27472639e+00],
#         [0.00000000e+00, 2.26482272e+00, 3.38142586e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 2.31925821e+00, 3.40770054e+00, ...,
#          4.45186234e+00, 0.00000000e+00, 3.90964794e+00],
#         [0.00000000e+00, 1.67911899e+00, 3.42214584e+00, ...,
#          3.71844983e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 1.17311001e+00, 3.81481481e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]], dtype=float32)

# %%
# Step 4: Look at histograms AFTER clipping
print("📊 Histograms AFTER percentile clipping:")
test_plot_band_histograms(cube, sample_every_n_bands=20)
# Out:
# 📊 Histograms AFTER percentile clipping:

# %%
# Step 5: Compare BEFORE vs AFTER for one example spectrum
# Use the same pixel we saved earlier
example_spectrum_after = cube.data_corrected[example_t, example_s, :]

fig, axes = plt.subplots(2, 1, figsize=(16, 10))

# Plot BEFORE    
axes[0].plot(cube.wavelengths, example_spectrum_before, linewidth=1.5, color='red', label='BEFORE clipping')
axes[0].set_title('Spectrum BEFORE Percentile Clipping', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Wavelength (nm)', fontsize=12)
axes[0].set_ylabel('Intensity', fontsize=12)
axes[0].grid(
    alpha=0.3,
    example_spectrum_before,
    color="red",
    label="",
)
axes[0].set_title("size=11)""bold")
axes[0].set_xlabel(".wavelengths[0]" 450, alpha=0.2, color='gray', label='Bad range')
axes[0].axvspan(700" cube.wav"lengths[-1], alpha=0.2, color='gray')

# Plot AFTER
axes[1].plot(cube.wavelengths, example_spectrum_after, line"idth", label="r='blue',"label='AFTER clipping')
axes[1].set_title('Spectrum AFTER Percentile Clipping', font"ize="4, fontweight='bold')
axes[1].set_xlabel('Wavelength (nm)', fontsize=12)
axes[1].set_ylabel('Intensity', fontsize=12)
axes[1].grid(
    alpha=0.3)
    example_spectrum_after,
   
    color="blue",
    label="",
)
axes[1].set_title("size=11)""bold")
axes[1].set_xlabel(".wavelengths[0]" 450, alpha=0.2, color='gray', label='Bad range')
axes[1].axvspan(700" cube.wav"lengths[-1], alpha=0.2, color='gray')

plt.tight_layout()
plt.show()"", label=""
""
print(f"\n📉 BEFORE - Value range: [{example_spectrum_before.min():.4f}, {example_spectrum_before.max():.4f}]")
print(f"📉 AFTER  - Value range: [{example_spectrum_after.min():.4f}, {example_spectrum_after.max():.4f}]")
print(f"\n✅ Notice how the spikes at <450nm and >700nm are now clipped!")
# Out:
#   Cell In[11], line 33
#     )
#     ^
# SyntaxError: unmatched ')'

# %%
# Step 6: Now test with smoothing on the FULL spectrum (no wavelength filter yet!)
# This tests if clipping was enough to allow smoothing across bad bands
cube.plot_spectrum(
    roi_names=["sediment"],
    use_corrected=True,
    wavelength_range=None,  # FULL spectrum (no cropping)
    wavelength_smoothing=20,  # Large window
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    figsize=(20, 8),
)
print(
    "\n✅ If the edges (<450nm, >700nm) now look smooth (not spiky), clipping worked!"
)

# %% [markdown]
# # TEST: Advanced Smoothing Methods
#
# Test the new smoothing methods: Gaussian, Median, Whittaker, and Bilateral filters.

# %% [markdown]
# ## Gaussian Smoothing
#
# Test Gaussian filter with different sigma values.

# %%
# Gaussian smoothing with sigma=1.0 (light smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=1.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Gaussian smoothing with sigma=2.0 (default, moderate smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=2.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=3.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    track_index=300,
    slit_index=50,
    # roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=3.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)
# Out:
# c:\Users\Erik Liu\OneDrive - NTNU\PhD\Courses\UHI post processing\havard_repo\from_Leo_usb\gref4hsi\gref4hsi\final_act\utils\gref_pipeline\georef.py:6835: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   label_y = plot_avg[-10:].mean()

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    track_index=300,
    slit_index=50,
    # roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=3.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    # track_index=300,
    # slit_index=50,
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=3.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=3.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=5.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
    # normalize_method="l2",
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
# %matplotlib qt

cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=5.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
    normalize_method="l2",
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=3,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
    normalize_method="l2",
    derivative_order=1,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
# %matplotlib inline
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=5.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
    normalize_method="l2",
    derivative_order=1,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=3,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
    normalize_method="l2",
    derivative_order=2,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=5.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
    normalize_method="l2",
    derivative_order=2,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=5.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=5.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
)

# %%
# Gaussian smoothing with sigma=3.0 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    gaussian_sigma=5.0,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    normalize_method="l2",
)

# %% [markdown]
# ## Median Smoothing
#
# Test Median filter with different kernel sizes.

# %%
# Median smoothing with kernel_size=3 (light smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="median",
    median_kernel_size=3,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Median smoothing with kernel_size=5 (default, moderate smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="median",
    median_kernel_size=5,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Median smoothing with kernel_size=7 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="median",
    median_kernel_size=7,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %% [markdown]
# ## Whittaker Smoothing
#
# Test Whittaker smoother with different lambda values.

# %%
# Whittaker smoothing with lambda=1e3 (light smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="whittaker",
    whittaker_lambda=1e3,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Whittaker smoothing with lambda=1e3 (light smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="whittaker",
    whittaker_lambda=1e3,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    # smooth_before_filter=True,
)

# %%
# Whittaker smoothing with lambda=1e3 (light smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="whittaker",
    whittaker_lambda=1e3,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    normalize_method="l2",
    # smooth_before_filter=True,
)

# %%
# Whittaker smoothing with lambda=1e3 (light smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    # wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="whittaker",
    whittaker_lambda=1e3,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    smooth_before_filter=True,
)

# %%
# Whittaker smoothing with lambda=1e4 (default, moderate smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="whittaker",
    whittaker_lambda=1e4,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Whittaker smoothing with lambda=1e5 (heavy smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="whittaker",
    whittaker_lambda=1e5,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %% [markdown]
# ## Bilateral Smoothing
#
# Test Bilateral filter with different spatial and intensity sigma values.

# %%
# Bilateral smoothing with default parameters (moderate edge preservation)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="bilateral",
    bilateral_sigma_spatial=2.0,
    bilateral_sigma_intensity=0.1,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Bilateral smoothing with larger spatial sigma (more smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="bilateral",
    bilateral_sigma_spatial=3.0,
    bilateral_sigma_intensity=0.1,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Bilateral smoothing with smaller intensity sigma (stronger edge preservation)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="bilateral",
    bilateral_sigma_spatial=2.0,
    bilateral_sigma_intensity=0.05,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %%
# Bilateral smoothing with larger intensity sigma (less edge preservation, more smoothing)
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    wavelength_smoothing=10,
    smoothing_method="bilateral",
    bilateral_sigma_spatial=2.0,
    bilateral_sigma_intensity=0.2,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %% [markdown]
# ## Summary of Smoothing Methods
#
# **Gaussian Smoothing** (`smoothing_method="gaussian"`):
# - Good for general noise reduction
# - `gaussian_sigma`: Larger = smoother (typical range: 1.0-3.0)
# - Smooth, continuous results
#
# **Median Smoothing** (`smoothing_method="median"`):
# - Robust to outliers and spikes
# - `median_kernel_size`: Larger = smoother (must be odd, typical: 3, 5, 7)
# - Good for preserving edges while removing noise
#
# **Whittaker Smoothing** (`smoothing_method="whittaker"`):
# - Excellent feature preservation with penalized least squares
# - `whittaker_lambda`: Larger = smoother (typical range: 1e3-1e5)
# - Best for spectral contours and subtle features
#
# **Bilateral Smoothing** (`smoothing_method="bilateral"`):
# - Edge-preserving, intensity-aware smoothing
# - `bilateral_sigma_spatial`: Controls spatial extent (typical: 2.0-3.0)
# - `bilateral_sigma_intensity`: Controls edge preservation (smaller = stronger, typical: 0.05-0.2)
# - Best for maintaining sharp transitions between features
#
# **Recommendation**: Start with Whittaker for spectral analysis (excellent feature preservation), or Gaussian for quick noise reduction.

# %% [markdown]
# ## How to use in your real workflow:
#
# Once you find good percentile values (e.g., 5-95 or 10-90), add this AFTER illumination correction:
#
# ```python
# # Your normal workflow:
# cube.apply_illumination_correction_v2()
#
# # NEW: Clip extreme spikes
# cube.apply_percentile_clipping(lower_percentile=5, upper_percentile=95)
#
# # Then continue as normal:
# cube.apply_spectral_smoothing(wavelength_smoothing=20)
# cube.apply_wavelength_filter(wavelength_range=(450, 700))
# cube.apply_spectral_normalization(method="l2")
# ```
#
# **To test different percentile values:**
# - More aggressive (removes more outliers): `lower_percentile=10, upper_percentile=90`
# - Less aggressive (keeps more data): `lower_percentile=2, upper_percentile=98`
# - Check the histograms to see which bands have the worst outliers!

# %% [markdown]
# # TEST: apply_spectral_smoothing() with Gaussian
#
# Test the new Gaussian smoothing in the pipeline function that modifies the entire datacube.

# %%
# Test: Apply Gaussian smoothing to the entire datacube
# WARNING: This modifies cube.data_corrected permanently (until you reload)
# Make a backup first if needed

# Apply Gaussian smoothing with default sigma=2.0
cube.apply_spectral_smoothing(method="gaussian", gaussian_sigma=2.0)

# %%
# After smoothing, plot the spectra to see the effect
cube.plot_spectrum(
    roi_names=roi_028,
    use_corrected=True,
    wavelength_range=(450, 700),
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)

# %% [markdown]
# **Note:** If you need to reload the cube to test different smoothing parameters:
# ```python
# # Reload the cube from scratch
# cube = transect.select_files([
#     "rad_uhi_20241029_125028_1",
#     "rad_uhi_20241029_125028_2",
#     "rad_uhi_20241029_125028_3",
#     "rad_uhi_20241029_125028_4",
#     "rad_uhi_20241029_125028_5",
# ])
# cube.apply_illumination_correction_v2()
# # Then apply different smoothing settings
# ```

# %% [markdown]
# # check wavelenghts from 057

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt

sys.path.append(os.path.abspath("../"))
from utils.gref_pipeline.georef import *

sys.path.append(os.path.abspath("../../"))
from gref_pipeline import config

# %%
# Load transect
transect = load_transect(config.OUTPUT_FOLDER)
transect.list_files()

# Select file
cube = transect.select_files(["rad_uhi_20241029_115057_5"])
cube.describe()
# Out:
# 📋 Files in output (corrected=False):
#  1. rad_uhi_20241029_115057_1  | shape=(1333, 968, 210)  | has_georef=True
#  2. rad_uhi_20241029_115057_2  | shape=(1946, 968, 210)  | has_georef=True
#  3. rad_uhi_20241029_115057_3  | shape=(2227, 968, 210)  | has_georef=True
#  4. rad_uhi_20241029_115057_4  | shape=(2463, 968, 210)  | has_georef=True
#  5. rad_uhi_20241029_115057_5  | shape=(2462, 968, 210)  | has_georef=True
#  6. rad_uhi_20241029_115057_6  | shape=(155, 968, 210)  | has_georef=True
# 🔄 Rebuilding grids from georef hits for selected files...
#    • rad_uhi_20241029_115057_5
#   rad_uhi_20241029_115057_5: Using GRIDDED format (T=2462, S=968)
# ✅ Combined shapes: X/Y/Z (2462, 968), RGB (2462, 968)
# 🔄 Loading full hyperspectral cube...
#    • Loading rad_uhi_20241029_115057_5...
# ✅ Loaded full cube: (2462, 968, 210) (T × S × B)
#
# === Combined_output ===
# Tracks × Slits: 2462 × 968
# RGB coverage: R/G/B finite ratios 1.00/1.00/1.00
#
# 📋 File boundaries:
#   rad_uhi_20241029_115057_5: tracks 0–2461 (2462)

# %%
# Apply illumination correction
cube.apply_illumination_correction_v2()
# Out:
# 🔄 Using V2 algorithm (pandas rolling median)
# ✅ Illumination correction already applied with window=500, strength=1.0
#    Loading from disk...
# 📂 Loading saved illumination correction from 1 files...
#    rad_uhi_20241029_115057_5: window=500, strength=1.0
# ✅ Loaded illumination correction from disk
# array([[[2.2304249e+00, 1.6764377e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 7.0077596e+00, 0.0000000e+00],
#         [7.4757171e+00, 8.5974735e-01, 0.0000000e+00, ...,
#          0.0000000e+00, 3.0958059e+00, 0.0000000e+00],
#         [1.8294926e+00, 2.3438740e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 7.1090145e+00, 0.0000000e+00],
#         ...,
#         [1.7213115e+00, 1.4317783e+00, 0.0000000e+00, ...,
#          1.0000000e+00, 2.3279436e-02, 3.7040919e-01],
#         [5.8812752e+00, 2.0123754e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 1.4956644e+00, 0.0000000e+00],
#         [2.3867478e+00, 1.0000000e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 1.5736811e+01, 4.5105180e-01]],
#
#        [[2.2304249e+00, 7.7452070e-01, 3.9940205e+00, ...,
#          0.0000000e+00, 0.0000000e+00, 9.6023534e-05],
#         [1.7471981e+00, 0.0000000e+00, 1.2654871e+00, ...,
#          0.0000000e+00, 8.5029960e-01, 6.3767982e-01],
#         [1.9216584e+00, 0.0000000e+00, 3.0771544e+00, ...,
#          0.0000000e+00, 0.0000000e+00, 2.1357527e-01],
#         ...,
#         [2.0491803e+00, 7.4093300e-01, 3.1371305e+00, ...,
#          0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 5.5005544e-01, 1.9202455e+00, ...,
#          0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [1.5392909e+00, 9.0162331e-01, 3.0465119e+00, ...,
#          0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#
#        [[2.3422816e+00, 0.0000000e+00, 0.0000000e+00, ...,
#          1.8859167e+01, 5.8449674e+00, 0.0000000e+00],
#         [6.2640095e-01, 2.9873672e-01, 0.0000000e+00, ...,
#          0.0000000e+00, 3.9191585e+00, 0.0000000e+00],
#         [2.1059902e+00, 0.0000000e+00, 0.0000000e+00, ...,
#          3.2293000e+00, 3.1616514e+00, 0.0000000e+00],
#         ...,
#         [3.9508197e+00, 0.0000000e+00, 0.0000000e+00, ...,
#          3.2160661e+00, 1.2146864e-02, 0.0000000e+00],
#         [8.6807364e-01, 1.5624306e+00, 0.0000000e+00, ...,
#          5.5901666e+00, 5.7088113e+00, 0.0000000e+00],
#         [6.1479235e-01, 1.1967534e+00, 0.0000000e+00, ...,
#          1.1547997e+00, 1.1877170e+01, 0.0000000e+00]],
#
#        ...,
#
#        [[0.0000000e+00, 7.9466099e-01, 4.9080677e+00, ...,
#          6.6571338e-03, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 5.8426270e+00, 3.6507815e-01, ...,
#          1.7363773e+01, 0.0000000e+00, 0.0000000e+00],
#         [2.0389593e+00, 3.4413159e+00, 3.4064233e+00, ...,
#          2.5625014e+00, 0.0000000e+00, 0.0000000e+00],
#         ...,
#         [5.1219511e-01, 3.5835798e+00, 3.5794657e-01, ...,
#          0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 5.1131272e+00, 0.0000000e+00, ...,
#          1.8588965e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 3.5389473e+00, 0.0000000e+00, ...,
#          4.6380416e-01, 0.0000000e+00, 1.8863976e-01]],
#
#        [[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ...,
#          5.9670443e-04, 2.6423416e+00, 7.2973492e-03],
#         [6.0102441e+02, 0.0000000e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 3.8708076e+00, 1.1975717e+01],
#         [3.8571382e+00, 0.0000000e+00, 0.0000000e+00, ...,
#          1.5062513e+01, 0.0000000e+00, 2.0917063e+00],
#         ...,
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 7.1990537e-03, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 1.0661943e+01, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 1.8470470e+01, 0.0000000e+00]],
#
#        [[0.0000000e+00, 1.3936358e+01, 0.0000000e+00, ...,
#          0.0000000e+00, 9.4821796e+00, 0.0000000e+00],
#         [0.0000000e+00, 1.3590830e+01, 0.0000000e+00, ...,
#          0.0000000e+00, 4.2296591e+00, 1.0000000e+00],
#         [0.0000000e+00, 4.9485002e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 7.0439320e+00, 0.0000000e+00],
#         ...,
#         [0.0000000e+00, 6.9270358e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 3.4881963e-03, 2.9908118e+00],
#         [0.0000000e+00, 1.4624733e+01, 0.0000000e+00, ...,
#          0.0000000e+00, 2.4492915e+00, 4.8961077e+00],
#         [0.0000000e+00, 4.2313876e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 6.2803654e-03, 4.4482813e+00]]], dtype=float32)

# %%
# Import ROIs
cube.import_rois("./ROIs/057_5_combined.json")
cube.list_rois()
# Out:
# 📂 Imported 6 ROIs from ./ROIs/057_5_combined.json
#
# 📂 ROI Collection (6 ROIs):
# ==================================================
#  1. 'validation_dark': 358 pixels
#      Slit range:  174 - 740
#      Track range: 729 - 1416
#  2. 'validation_bombs': 454 pixels
#      Slit range:  244 - 880
#      Track range: 593 - 1547
#  3. 'validation_sediment': 273 pixels
#      Slit range:   14 - 870
#      Track range: 577 - 1580
#  4. 'training_dark': 364 pixels
#      Slit range:   24 - 962
#      Track range:  23 - 2420
#  5. 'training_sediment': 398 pixels
#      Slit range:   31 - 924
#      Track range:  51 - 2417
#  6. 'training_bombs': 201 pixels
#      Slit range:  513 - 794
#      Track range: 2136 - 2416

# %%
# Define ROI collections
training_rois = [
    "training_dark",
    "training_sediment",
    "training_bombs",
]

validation_rois = [
    "validation_dark",
    "validation_sediment",
    "validation_bombs",
]

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=training_rois,
    use_corrected=True,
    wavelength_range=(440, 750),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=training_rois,
    use_corrected=True,
    wavelength_range=(440, 700),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=training_rois,
    use_corrected=True,
    wavelength_range=(490, 700),
    # wavelength_smoothing=10,
    # smoothing_method="gaussian",
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=training_rois,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
    smooth_before_filter=True,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=validation_rois,
    use_corrected=True,
    wavelength_range=(490, 700),
    # wavelength_smoothing=10,
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
)

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=validation_rois,
    use_corrected=True,
    wavelength_range=(490, 700),
    wavelength_smoothing=10,
    smoothing_method="gaussian",
    legend_loc="outside",
    use_inline_labels=False,
    # normalize_method="l2",
    show_std=False,
    smooth_before_filter=True,
)
