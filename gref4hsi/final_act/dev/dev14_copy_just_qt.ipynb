# %%
import importlib
import sys
import os

sys.path.append(os.path.abspath("../"))

from utils.gref_pipeline import georef
from gref_pipeline import config

importlib.reload(georef)
from utils.gref_pipeline.georef import *

# %%
# %matplotlib qt

# %%
# Load a transect folder
# transect = load_transect(r"E:\mjosa_new\use_gref4hsi\221\Input\H5")
transect = load_transect(r"E:\mjosa_new\uhi_rad")
transect.list_files()
# Out:
# ⚠️  rad_uhi_20241029_104221_1.h5: radiance found but no georef dataset – loaded anyway
# ⚠️  rad_uhi_20241029_104221_2.h5: radiance found but no georef dataset – loaded anyway
# ⚠️  rad_uhi_20241029_104221_3.h5: radiance found but no georef dataset – loaded anyway
# ⚠️  rad_uhi_20241029_104221_4.h5: radiance found but no georef dataset – loaded anyway
# ⚠️  rad_uhi_20241029_104221_5.h5: radiance found but no georef dataset – loaded anyway
# ⚠️  rad_uhi_20241029_115057_1.h5: radiance found but no georef dataset – loaded anyway
# ⚠️  rad_uhi_20241029_115057_2.h5: radiance found but no georef dataset – loaded anyway
# ⚠️  rad_uhi_20241029_115057_3.h5: radiance found but no georef dataset – loaded anyway
# ⚠️  rad_uhi_20241029_115057_4.h5: radiance found but no georef dataset – loaded anyway
# ⚠️  rad_uhi_20241029_115057_5.h5: radiance found but no georef dataset – loaded anyway
# ⚠️  rad_uhi_20241029_115057_6.h5: radiance found but no georef dataset – loaded anyway
# ...

# %%
cube = transect.select_files(
    [
        "rad_uhi_20241029_115057_1",
        "rad_uhi_20241029_115057_2",
        "rad_uhi_20241029_115057_3",
        "rad_uhi_20241029_115057_4",
        "rad_uhi_20241029_115057_6",
        "rad_uhi_20241029_115057_5",
    ]
)
cube.describe()

cube.apply_illumination_correction_v2()
# cube.plot_rgb(
#     red_wl=620.0,
#     green_wl=565.0,
#     blue_wl=490.0,
#     normalize=True,
# )

cube.plot_rgb(
    red_wl=620.0,
    green_wl=565.0,
    blue_wl=490.0,
    normalize=True,
    use_corrected=True,  # ← Use this!,
)
# Out:
# ⚠️  Files have no georef data - skipping spatial grid building
# ✅ Spectral analysis functions available (plot_spectrum, illumination correction, etc.)
# 🔄 Loading full hyperspectral cube...
#    • Loading rad_uhi_20241029_115057_1...
#    • Loading rad_uhi_20241029_115057_2...
#    • Loading rad_uhi_20241029_115057_3...
#    • Loading rad_uhi_20241029_115057_4...
#    • Loading rad_uhi_20241029_115057_6...
#    • Loading rad_uhi_20241029_115057_5...
# ✅ Loaded full cube: (10586, 968, 210) (T × S × B)
#
# === Combined_uhi_rad ===
# Datacube shape: 10586 tracks × 968 slits × 210 bands
# Wavelength range: 380.9 - 748.6 nm
#
# ⚠️  No georef data available
# ✅ Spectral analysis functions available: plot_spectrum, illumination correction, etc.
# 🔄 Using V2 algorithm (pandas rolling median)
# ✅ Illumination correction already applied with window=500, strength=1.0
#    Loading from disk...
# 📂 Loading saved illumination correction from 6 files...
# ...

# %%
cube.plot_rgb(
    red_wl=620.0,
    green_wl=565.0,
    blue_wl=490.0,
    normalize=True,
    use_corrected=True,  # ← Use this!,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cube.plot_rgb(
#       2     red_wl=620.0,
#       3     green_wl=565.0,
#       4     blue_wl=490.0,
#       5     normalize=True,
#       6     use_corrected=True,  # ← Use this!,
#       7 )
#
# NameError: name 'cube' is not defined

# %%
cube = transect.select_files(
    [
        "rad_uhi_20241029_104221_1",
        "rad_uhi_20241029_104221_2",
        "rad_uhi_20241029_104221_3",
        "rad_uhi_20241029_104221_4",
        "rad_uhi_20241029_104221_5",
    ]
)
cube.describe()


cube.apply_illumination_correction_v2()
# cube.plot_rgb(
#     red_wl=620.0,
#     green_wl=565.0,
#     blue_wl=490.0,
#     normalize=True,
# )

cube.plot_rgb(
    red_wl=620.0,
    green_wl=565.0,
    blue_wl=490.0,
    normalize=True,
    use_corrected=True,  # ← Use this!,
    spacing=8,
)
# Out:
# ⚠️  Files have no georef data - skipping spatial grid building
# ✅ Spectral analysis functions available (plot_spectrum, illumination correction, etc.)
# 🔄 Loading full hyperspectral cube...
#    • Loading rad_uhi_20241029_104221_1...
#    • Loading rad_uhi_20241029_104221_2...
#    • Loading rad_uhi_20241029_104221_3...
#    • Loading rad_uhi_20241029_104221_4...
#    • Loading rad_uhi_20241029_104221_5...
# ✅ Loaded full cube: (9898, 968, 210) (T × S × B)
#
# === Combined_uhi_rad ===
# Datacube shape: 9898 tracks × 968 slits × 210 bands
# Wavelength range: 380.9 - 748.6 nm
#
# ⚠️  No georef data available
# ✅ Spectral analysis functions available: plot_spectrum, illumination correction, etc.
# 🔄 Using V2 algorithm (pandas rolling median)
# ✅ Illumination correction already applied with window=500, strength=1.0
#    Loading from disk...
# 📂 Loading saved illumination correction from 5 files...
#    rad_uhi_20241029_104221_1: window=500, strength=1.0
# ...

# %%
cube = transect.select_files(
    [
        "rad_uhi_20241029_125028_1",
        "rad_uhi_20241029_125028_2",
        "rad_uhi_20241029_125028_3",
        "rad_uhi_20241029_125028_4",
        "rad_uhi_20241029_125028_5",
    ]
)
cube.describe()


cube.apply_illumination_correction_v2()
# cube.plot_rgb(
#     red_wl=620.0,
#     green_wl=565.0,
#     blue_wl=490.0,
#     normalize=True,
# )

cube.plot_rgb(
    red_wl=620.0,
    green_wl=565.0,
    blue_wl=490.0,
    normalize=True,
    use_corrected=True,  # ← Use this!,
    spacing=8,
)
# Out:
# ⚠️  Files have no georef data - skipping spatial grid building
# ✅ Spectral analysis functions available (plot_spectrum, illumination correction, etc.)
# 🔄 Loading full hyperspectral cube...
#    • Loading rad_uhi_20241029_125028_1...
#    • Loading rad_uhi_20241029_125028_2...
#    • Loading rad_uhi_20241029_125028_3...
#    • Loading rad_uhi_20241029_125028_4...
#    • Loading rad_uhi_20241029_125028_5...
# ✅ Loaded full cube: (10027, 968, 210) (T × S × B)
#
# === Combined_uhi_rad ===
# Datacube shape: 10027 tracks × 968 slits × 210 bands
# Wavelength range: 380.9 - 748.6 nm
#
# ⚠️  No georef data available
# ✅ Spectral analysis functions available: plot_spectrum, illumination correction, etc.
# 🔄 Using V2 algorithm (pandas rolling median)
# ✅ Illumination correction already applied with window=500, strength=1.0
#    Loading from disk...
# 📂 Loading saved illumination correction from 5 files...
#    rad_uhi_20241029_125028_1: window=500, strength=1.0
# ...

# %%
cube = transect.select_files(
    [
        "rad_uhi_20241029_130135_1",
        "rad_uhi_20241029_130135_2",
    ]
)
cube.describe()

cube.apply_illumination_correction_v2()
# cube.plot_rgb(
#     red_wl=620.0,
#     green_wl=565.0,
#     blue_wl=490.0,
#     normalize=True,
# )

cube.plot_rgb(
    red_wl=620.0,
    green_wl=565.0,
    blue_wl=490.0,
    normalize=True,
    use_corrected=True,  # ← Use this!,
)
# Out:
# ⚠️  Files have no georef data - skipping spatial grid building
# ✅ Spectral analysis functions available (plot_spectrum, illumination correction, etc.)
# 🔄 Loading full hyperspectral cube...
#    • Loading rad_uhi_20241029_130135_1...
#    • Loading rad_uhi_20241029_130135_2...
# ✅ Loaded full cube: (3944, 968, 210) (T × S × B)
#
# === Combined_uhi_rad ===
# Datacube shape: 3944 tracks × 968 slits × 210 bands
# Wavelength range: 380.9 - 748.6 nm
#
# ⚠️  No georef data available
# ✅ Spectral analysis functions available: plot_spectrum, illumination correction, etc.
# 🔄 Using V2 algorithm (pandas rolling median)
# ✅ Illumination correction already applied with window=500, strength=1.0
#    Loading from disk...
# 📂 Loading saved illumination correction from 2 files...
#    rad_uhi_20241029_130135_1: window=500, strength=1.0
#    rad_uhi_20241029_130135_2: window=500, strength=1.0
# ✅ Loaded illumination correction from disk

# %%
# Load a transect folder
# transect = load_transect(r"E:\mjosa_new\use_gref4hsi\221\Input\H5")
transect = load_transect(r"E:\mjosa\29\uhi_rad")
transect.list_files()
# Out:
# ⚠️  rad_uhi_20241029_104221_1.h5: radiance found but no georef dataset – loaded anyway
# ⚠️  rad_uhi_20241029_104221_2.h5: radiance found but no georef dataset – loaded anyway
# ⚠️  rad_uhi_20241029_104221_3.h5: radiance found but no georef dataset – loaded anyway
# ⚠️  rad_uhi_20241029_104221_4.h5: radiance found but no georef dataset – loaded anyway
# ⚠️  rad_uhi_20241029_104221_5.h5: radiance found but no georef dataset – loaded anyway
# ⚠️  rad_uhi_20241029_111520_from1_1.h5: radiance found but no georef dataset – loaded anyway
# ⚠️  rad_uhi_20241029_111520_from3_1.h5: radiance found but no georef dataset – loaded anyway
# ⚠️  rad_uhi_20241029_111520_from3_2.h5: radiance found but no georef dataset – loaded anyway
# ⚠️  rad_uhi_20241029_111520_from3_3.h5: radiance found but no georef dataset – loaded anyway
# ⚠️  rad_uhi_20241029_115057_1.h5: radiance found but no georef dataset – loaded anyway
# ...

# %%
cube = transect.select_files(
    [
        "rad_uhi_20241029_111520_from1_1",
        "rad_uhi_20241029_111520_from3_1",
        "rad_uhi_20241029_111520_from3_2",
        "rad_uhi_20241029_111520_from3_3",
    ]
)
cube.describe()

cube.apply_illumination_correction_v2()
# cube.plot_rgb(
#     red_wl=620.0,
#     green_wl=565.0,
#     blue_wl=490.0,
#     normalize=True,
# )

cube.plot_rgb(
    red_wl=620.0,
    green_wl=565.0,
    blue_wl=490.0,
    normalize=True,
    use_corrected=True,  # ← Use this!,
)
# Out:
# ⚠️  Files have no georef data - skipping spatial grid building
# ✅ Spectral analysis functions available (plot_spectrum, illumination correction, etc.)
# 🔄 Loading full hyperspectral cube...
#    • Loading rad_uhi_20241029_111520_from1_1...
#    • Loading rad_uhi_20241029_111520_from3_1...
#    • Loading rad_uhi_20241029_111520_from3_2...
#    • Loading rad_uhi_20241029_111520_from3_3...
# ✅ Loaded full cube: (7543, 968, 210) (T × S × B)
#
# === Combined_uhi_rad ===
# Datacube shape: 7543 tracks × 968 slits × 210 bands
# Wavelength range: 380.9 - 748.6 nm
#
# ⚠️  No georef data available
# ✅ Spectral analysis functions available: plot_spectrum, illumination correction, etc.
# 🔄 Using V2 algorithm (pandas rolling median)
# ✅ Illumination correction already applied with window=500, strength=1.0
#    Loading from disk...
# 📂 Loading saved illumination correction from 4 files...
#    rad_uhi_20241029_111520_from1_1: window=500, strength=1.0
# ...

# %%
cube = transect.select_files(
    [
        "rad_uhi_20241029_121639_1",
        "rad_uhi_20241029_121639_2",
        "rad_uhi_20241029_121639_3",
        "rad_uhi_20241029_121639_4",
        "rad_uhi_20241029_121639_5",
    ]
)
cube.describe()

cube.apply_illumination_correction_v2()
# cube.plot_rgb(
#     red_wl=620.0,
#     green_wl=565.0,
#     blue_wl=490.0,
#     normalize=True,
# )


cube.plot_rgb(
    red_wl=620.0,
    green_wl=565.0,
    blue_wl=490.0,
    normalize=True,
    use_corrected=True,  # ← Use this!,
)
# Out:
# ⚠️  Files have no georef data - skipping spatial grid building
# ✅ Spectral analysis functions available (plot_spectrum, illumination correction, etc.)
# 🔄 Loading full hyperspectral cube...
#    • Loading rad_uhi_20241029_121639_1...
#    • Loading rad_uhi_20241029_121639_2...
#    • Loading rad_uhi_20241029_121639_3...
#    • Loading rad_uhi_20241029_121639_4...
#    • Loading rad_uhi_20241029_121639_5...
# ✅ Loaded full cube: (10075, 968, 210) (T × S × B)
#
# === Combined_uhi_rad ===
# Datacube shape: 10075 tracks × 968 slits × 210 bands
# Wavelength range: 380.9 - 748.6 nm
#
# ⚠️  No georef data available
# ✅ Spectral analysis functions available: plot_spectrum, illumination correction, etc.
# 🔄 Using V2 algorithm (pandas rolling median)
# ✅ Illumination correction already applied with window=500, strength=1.0
#    Loading from disk...
# 📂 Loading saved illumination correction from 5 files...
#    rad_uhi_20241029_121639_1: window=500, strength=1.0
# ...
