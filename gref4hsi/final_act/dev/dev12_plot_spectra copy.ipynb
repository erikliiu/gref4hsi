# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt

sys.path.append(os.path.abspath("../"))
from utils.gref_pipeline.georef import *

sys.path.append(os.path.abspath("../../"))
from gref_pipeline import config

# %%
transect = load_transect(config.OUTPUT_FOLDER)
transect.list_files()
# Out:
# 📋 Files in output (corrected=False):
#  1. rad_uhi_20241029_115057_1  | shape=(1333, 968, 210)  | has_georef=True
#  2. rad_uhi_20241029_115057_2  | shape=(1946, 968, 210)  | has_georef=True
#  3. rad_uhi_20241029_115057_3  | shape=(2227, 968, 210)  | has_georef=True
#  4. rad_uhi_20241029_115057_4  | shape=(2463, 968, 210)  | has_georef=True
#  5. rad_uhi_20241029_115057_5  | shape=(2462, 968, 210)  | has_georef=True
#  6. rad_uhi_20241029_115057_6  | shape=(155, 968, 210)  | has_georef=True

# %%
cube = transect.select_files(
    [
        # "rad_uhi_20241029_115057_4",
        "rad_uhi_20241029_115057_5",
    ]
)
cube.describe()
# Out:
# 🔄 Rebuilding grids from georef hits for selected files...
#    • rad_uhi_20241029_115057_5
#   rad_uhi_20241029_115057_5: Using GRIDDED format (T=2462, S=968)
# ✅ Combined shapes: X/Y/Z (2462, 968), RGB (2462, 968)
# 🔄 Loading full hyperspectral cube...
#    • Loading rad_uhi_20241029_115057_5...
# ✅ Loaded full cube: (2462, 968, 210) (T × S × B)
#
# === Combined_output ===
# Tracks × Slits: 2462 × 968
# RGB coverage: R/G/B finite ratios 1.00/1.00/1.00
#
# 📋 File boundaries:
#   rad_uhi_20241029_115057_5: tracks 0–2461 (2462)

# %%
cube.list_saved_corrections()
# Out:
# 📋 Cached illumination corrections:
# ================================================================================
#
# 📁 File: rad_uhi_20241029_115057_5
#    ✓ window=1000, strength=1.0
#      Dataset: dataCube_illum_corrected_w1000_s1p00
#      Shape: (2462, 968, 210), Size: 1909.2 MB
#    ✓ window=500, strength=1.0
#      Dataset: dataCube_illum_corrected_w500_s1p00
#      Shape: (2462, 968, 210), Size: 1909.2 MB
#    ✓ window=750, strength=1.0
#      Dataset: dataCube_illum_corrected_w750_s1p00
#      Shape: (2462, 968, 210), Size: 1909.2 MB
# ================================================================================

# %%
# Apply illumination correction with rolling window (window_size=1000 tracks)
# NOTE: Using V2 version (pandas rolling median, no scipy bugs)
# This will be cached to disk - next time it will load instantly!
# Use force_recompute=True to force recalculation
cube.apply_illumination_correction_v2(window_size=750, force_recompute=False)
# Out:
# 🔄 Using V2 algorithm (pandas rolling median)
# ✅ Illumination correction already applied with window=750, strength=1.0
#    Loading from disk...
# 📂 Loading saved illumination correction from 1 files...
#    rad_uhi_20241029_115057_5: window=750, strength=1.0
# ✅ Loaded illumination correction from disk
# array([[[2.2304249e+00, 1.6764377e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 7.4917216e+00, 0.0000000e+00],
#         [7.4757171e+00, 8.5974735e-01, 0.0000000e+00, ...,
#          0.0000000e+00, 3.0958059e+00, 0.0000000e+00],
#         [1.8294926e+00, 2.3438740e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 7.8464627e+00, 0.0000000e+00],
#         ...,
#         [1.7213115e+00, 1.4317783e+00, 0.0000000e+00, ...,
#          1.0000000e+00, 2.3279436e-02, 3.9091909e-01],
#         [5.1958108e+00, 2.2674298e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 1.9884717e+00, 0.0000000e+00],
#         [2.3867478e+00, 1.0517330e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 2.4243166e+01, 5.2279919e-01]],
#
#        [[2.2304249e+00, 7.7452070e-01, 3.9940205e+00, ...,
#          0.0000000e+00, 0.0000000e+00, 9.6023534e-05],
#         [1.7471981e+00, 0.0000000e+00, 1.2654871e+00, ...,
#          0.0000000e+00, 8.5029960e-01, 7.2527355e-01],
#         [1.9216584e+00, 0.0000000e+00, 3.0771544e+00, ...,
#          0.0000000e+00, 0.0000000e+00, 2.2279701e-01],
#         ...,
#         [2.0491803e+00, 7.4093300e-01, 3.1371305e+00, ...,
#          0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 6.1977112e-01, 1.9202455e+00, ...,
#          0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [1.5392909e+00, 9.4826698e-01, 3.3589745e+00, ...,
#          0.0000000e+00, 0.0000000e+00, 0.0000000e+00]],
#
#        [[2.4810421e+00, 0.0000000e+00, 0.0000000e+00, ...,
#          1.8859167e+01, 6.2486258e+00, 0.0000000e+00],
#         [6.2640095e-01, 2.9873672e-01, 0.0000000e+00, ...,
#          0.0000000e+00, 3.9191585e+00, 0.0000000e+00],
#         [2.2077286e+00, 0.0000000e+00, 0.0000000e+00, ...,
#          3.2293000e+00, 3.8935139e+00, 0.0000000e+00],
#         ...,
#         [3.9508197e+00, 0.0000000e+00, 0.0000000e+00, ...,
#          3.2160661e+00, 1.2146864e-02, 0.0000000e+00],
#         [7.6689941e-01, 1.7604578e+00, 0.0000000e+00, ...,
#          5.5901666e+00, 7.5898108e+00, 0.0000000e+00],
#         [6.1479235e-01, 1.2586651e+00, 0.0000000e+00, ...,
#          1.0000000e+00, 1.8297239e+01, 0.0000000e+00]],
#
#        ...,
#
#        [[0.0000000e+00, 6.5928417e-01, 6.3731732e+00, ...,
#          6.6571338e-03, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 5.8426270e+00, 2.7710739e-01, ...,
#          3.8203479e+02, 0.0000000e+00, 0.0000000e+00],
#         [1.6185559e+00, 3.4413159e+00, 3.4064233e+00, ...,
#          2.5625014e+00, 0.0000000e+00, 0.0000000e+00],
#         ...,
#         [4.2857143e-01, 3.5835798e+00, 3.0843812e-01, ...,
#          0.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 5.1131272e+00, 0.0000000e+00, ...,
#          2.1188822e+00, 0.0000000e+00, 0.0000000e+00],
#         [0.0000000e+00, 3.7556615e+00, 0.0000000e+00, ...,
#          5.3560090e-01, 0.0000000e+00, 1.8863976e-01]],
#
#        [[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ...,
#          5.9670443e-04, 3.2321525e+00, 7.2973492e-03],
#         [1.7504873e+01, 0.0000000e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 3.8708076e+00, 3.0688236e+01],
#         [3.0618532e+00, 0.0000000e+00, 0.0000000e+00, ...,
#          1.5062513e+01, 0.0000000e+00, 2.6759839e+00],
#         ...,
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 7.1990537e-03, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 1.0661943e+01, 0.0000000e+00],
#         [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 5.0051650e-03, 0.0000000e+00]],
#
#        [[0.0000000e+00, 1.1562189e+01, 0.0000000e+00, ...,
#          0.0000000e+00, 9.4821796e+00, 0.0000000e+00],
#         [0.0000000e+00, 1.3590830e+01, 0.0000000e+00, ...,
#          0.0000000e+00, 4.2296591e+00, 1.4386026e+00],
#         [0.0000000e+00, 5.6798058e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 7.0439320e+00, 0.0000000e+00],
#         ...,
#         [0.0000000e+00, 6.9270358e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 3.4881963e-03, 3.5316463e+00],
#         [0.0000000e+00, 1.4624733e+01, 0.0000000e+00, ...,
#          0.0000000e+00, 2.4492915e+00, 6.2486258e+00],
#         [0.0000000e+00, 4.4905047e+00, 0.0000000e+00, ...,
#          0.0000000e+00, 6.2803654e-03, 4.4482813e+00]]], dtype=float32)

# %%
cube.adjust_uhi_alignment(dx=-0.05, dy=-3.0)
# Out:
# ✅ UHI alignment adjusted:
#    dx (East):  -0.050 m
#    dy (North): -3.000 m
#
# 💡 This will be applied in plot_georef() with coordinate_system='NED'

# %%
# Import ROIs from file
cube.import_rois("my_rois_6.json")
# Out:
# 📂 Imported 18 ROIs from my_rois_6.json

# %%
# List all ROIs
cube.list_rois()
# Out:
# 📂 ROI Collection (18 ROIs):
# ==================================================
#  1. 'yellow leaf': 19 pixels
#      Slit range:  756 - 779
#      Track range: 2100 - 2103
#  2. 'brown leaf': 33 pixels
#      Slit range:  756 - 782
#      Track range: 1770 - 1776
#  3. 'dark sediment': 120 pixels
#      Slit range:  254 - 325
#      Track range: 931 - 1416
#  4. 'dark1': 98 pixels
#      Slit range:  606 - 740
#      Track range: 729 - 765
#  5. 'dark2': 140 pixels
#      Slit range:  174 - 356
#      Track range: 1094 - 1148
#  6. 'sediment': 273 pixels
#      Slit range:   14 - 870
#      Track range: 577 - 1580
#  7. 'dark bomb': 238 pixels
#      Slit range:  174 - 740
#      Track range: 729 - 1148
#  8. 'tripple bomb 1': 71 pixels
#      Slit range:  662 - 701
#      Track range: 593 - 598
#  9. 'tripple bomb 2': 42 pixels
#      Slit range:  639 - 654
#      Track range: 700 - 705
# 10. 'tripple bomb 3': 84 pixels
#      Slit range:  632 - 678
#      Track range: 757 - 765
# 11. 'single bomb ring': 62 pixels
#      Slit range:  224 - 404
#      Track range: 1124 - 1168
# 12. 'single bomb inside': 82 pixels
#      Slit range:  244 - 291
#      Track range: 1126 - 1135
# 13. 'double bomb 1': 114 pixels
#      Slit range:  809 - 880
#      Track range: 1500 - 1516
# 14. 'double bomb 2': 61 pixels
#      Slit range:  659 - 690
#      Track range: 1540 - 1547
# 15. 'tripple bomb': 197 pixels
#      Slit range:  632 - 701
#      Track range: 593 - 765
# 16. 'double bomb': 175 pixels
#      Slit range:  659 - 880
#      Track range: 1500 - 1547
# 17. 'dark spots': 358 pixels
#      Slit range:  174 - 740
#      Track range: 729 - 1416
# 18. 'all bombs': 454 pixels
#      Slit range:  244 - 880
#      Track range: 593 - 1547

# %%
# cube.export_rois("my_rois_6.json")

# %%
# # Example: Combine multiple ROIs
# cube.combine_rois(
#     roi_names_to_combine=[
#         "single bomb inside",
#         "double bomb 1",
#         "double bomb 2",
#         "tripple bomb 1",
#         "tripple bomb 2",
#         "tripple bomb 3",
#     ],
#     new_roi_name="all bombs",
# )

# %%
# cube.rename_roi(old_roi_name="sed1", new_roi_name="Sediment")

# %%
cube.plot_georef(
    apply_alignment_shift=True,
    use_corrected=True,
    coordinate_system="NED",
    track_start=config.UHI_TRACK_RANGE_5[0],
    track_end=config.UHI_TRACK_RANGE_5[1],
    figsize=(30, 10),
    roi_collection="all",
    roi_marker_size=2,
    roi_legend_loc="outside",
    roi_marker_edgewidth=0,
    roi_legend_markersize=50,
)
# Out:
# 💡 Interactive mode: Click on the plot to display coordinates

# %%
roi_extra = [
    "sediment",
    "dark spots",
    "all bombs",
    "brown leaf",
    "yellow leaf",
]

# %%
roi_totals = [
    "sediment",
    "dark spots",
    "all bombs",
]

# %%
roi_names = [
    "double bomb 2",
    "double bomb 1",
    "tripple bomb 1",
    "tripple bomb 2",
    "tripple bomb 3",
    "single bomb ring",
    "single bomb inside",
    "dark sediment",
    "dark bomb",
    "sediment",
]


cube.plot_georef(
    apply_alignment_shift=True,
    use_corrected=True,
    coordinate_system="NED",
    track_start=config.UHI_TRACK_RANGE_5[0],
    track_end=config.UHI_TRACK_RANGE_5[1],
    figsize=(30, 10),
    roi_collection=roi_names,
    roi_marker_size=2,
    roi_legend_loc="outside",
    roi_marker_edgewidth=0,
    roi_legend_markersize=50,
)
# Out:
# 💡 Interactive mode: Click on the plot to display coordinates

# %%
cube.plot_georef(
    apply_alignment_shift=True,
    use_corrected=True,
    coordinate_system="NED",
    track_start=config.UHI_TRACK_RANGE_5[0],
    track_end=config.UHI_TRACK_RANGE_5[1],
    figsize=(30, 10),
    roi_collection=roi_totals,
    roi_marker_size=2,
    roi_legend_loc="outside",
    roi_marker_edgewidth=0,
    roi_legend_markersize=50,
)
# Out:
# 💡 Interactive mode: Click on the plot to display coordinates

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_names,
    use_corrected=True,
    # wavelength_range=(475, 675),
    wavelength_smoothing=0,
    interpolate_wavelengths=[64, 107, 138],
    legend_loc="outside",
    use_inline_labels=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
# Test: No normalization (raw data with offset visible)
cube.plot_spectrum(
    roi_names=roi_names,
    use_corrected=True,
    wavelength_range=(500, 650),
    wavelength_smoothing=1,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method=None,  # No normalization
    legend_loc="outside",
    use_inline_labels=False,
    show_std=True,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
cube.plot_spectrum(
    roi_names=roi_totals,
    use_corrected=True,
    wavelength_range=(500, 650),
    wavelength_smoothing=1,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method=None,  # No normalization
    legend_loc="outside",
    use_inline_labels=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %% [markdown]
# ## 📊 All Normalization Methods - roi_names (individual bombs + sediment)

# %%
# roi_names: No normalization
cube.plot_spectrum(
    roi_names=roi_names,
    use_corrected=True,
    wavelength_range=(500, 650),
    wavelength_smoothing=1,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method=None,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
# roi_names: Mean centering ⭐
cube.plot_spectrum(
    roi_names=roi_names,
    use_corrected=True,
    wavelength_range=(500, 650),
    wavelength_smoothing=10,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method="mean_center",
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
# roi_names: SNV ⭐
cube.plot_spectrum(
    roi_names=roi_names,
    use_corrected=True,
    wavelength_range=(500, 650),
    wavelength_smoothing=10,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method="snv",
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
# roi_names: MSC
cube.plot_spectrum(
    roi_names=roi_names,
    use_corrected=True,
    wavelength_range=(500, 650),
    wavelength_smoothing=10,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method="msc",
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm
#
# 📊 Computing reference spectrum for MSC normalization...
#    ✓ Reference computed from 1147 spectra

# %%
# roi_names: Mean
cube.plot_spectrum(
    roi_names=roi_names,
    use_corrected=True,
    wavelength_range=(500, 650),
    wavelength_smoothing=10,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method="mean",
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
# roi_names: Min-max
cube.plot_spectrum(
    roi_names=roi_names,
    use_corrected=True,
    wavelength_range=(500, 650),
    wavelength_smoothing=10,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method="minmax",
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
# roi_names: L2
cube.plot_spectrum(
    roi_names=roi_names,
    use_corrected=True,
    wavelength_range=(500, 650),
    wavelength_smoothing=10,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method="l2",
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %% [markdown]
# ## 📊 All Normalization Methods - roi_totals (grouped: sediment, dark spots, all bombs)

# %%
# roi_totals: L2
cube.plot_spectrum(
    roi_names=roi_totals,
    use_corrected=True,
    wavelength_range=(500, 650),
    wavelength_smoothing=10,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method="l2",
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    ylim=0.01,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
# roi_totals: Min-max
cube.plot_spectrum(
    roi_names=roi_totals,
    use_corrected=True,
    wavelength_range=(500, 650),
    wavelength_smoothing=1,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method="minmax",
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
# roi_totals: Mean
cube.plot_spectrum(
    roi_names=roi_totals,
    use_corrected=True,
    wavelength_range=(500, 650),
    wavelength_smoothing=1,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method="mean",
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
# roi_totals: MSC
cube.plot_spectrum(
    roi_names=roi_totals,
    use_corrected=True,
    wavelength_range=(500, 650),
    wavelength_smoothing=1,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method="msc",
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm
#
# 📊 Computing reference spectrum for MSC normalization...
#    ✓ Reference computed from 1085 spectra

# %%
# roi_totals: SNV ⭐
cube.plot_spectrum(
    roi_names=roi_totals,
    use_corrected=True,
    wavelength_range=(500, 650),
    wavelength_smoothing=1,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method="snv",
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
# roi_totals: Mean centering ⭐
cube.plot_spectrum(
    roi_names=roi_totals,
    use_corrected=True,
    wavelength_range=(500, 650),
    wavelength_smoothing=1,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method="mean_center",
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
# roi_totals: No normalization
cube.plot_spectrum(
    roi_names=roi_totals,
    use_corrected=True,
    wavelength_range=(500, 650),
    wavelength_smoothing=1,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method=None,
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %% [markdown]
# # radiance

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_names,
    use_corrected=False,
    # wavelength_range=(475, 675),
    wavelength_smoothing=0,
    interpolate_wavelengths=[64, 107, 138],
    legend_loc="outside",
    use_inline_labels=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
# Test: No normalization (raw data with offset visible)
cube.plot_spectrum(
    roi_names=roi_names,
    use_corrected=False,
    wavelength_range=(500, 650),
    wavelength_smoothing=1,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method=None,  # No normalization
    legend_loc="outside",
    use_inline_labels=False,
    show_std=True,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
cube.plot_spectrum(
    roi_names=roi_totals,
    use_corrected=False,
    # wavelength_range=(500, 650),
    wavelength_smoothing=1,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method=None,  # No normalization
    legend_loc="outside",
    use_inline_labels=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
cube.plot_spectrum(
    roi_names=roi_totals,
    use_corrected=False,
    wavelength_range=(500, 650),
    wavelength_smoothing=1,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method=None,  # No normalization
    legend_loc="outside",
    use_inline_labels=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
# All ROI spectra with std bands
# Note: ROI colors are now hardcoded in the class!
cube.plot_spectrum(
    roi_names=roi_names,
    use_corrected=False,
    # wavelength_range=(475, 675),
    wavelength_smoothing=0,
    interpolate_wavelengths=[64, 107, 138],
    legend_loc="outside",
    use_inline_labels=False,
    normalize_method="mean",
    show_std=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
# Test: No normalization (raw data with offset visible)
cube.plot_spectrum(
    roi_names=roi_names,
    use_corrected=False,
    wavelength_range=(500, 650),
    wavelength_smoothing=1,
    interpolate_wavelengths=[64, 107, 138],
    legend_loc="outside",
    use_inline_labels=False,
    show_std=False,
    normalize_method="mean",
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
cube.plot_spectrum(
    roi_names=roi_totals,
    use_corrected=False,
    # wavelength_range=(500, 650),
    wavelength_smoothing=1,
    interpolate_wavelengths=[64, 107, 138],
    legend_loc="outside",
    use_inline_labels=False,
    normalize_method="mean",
    show_std=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
cube.plot_spectrum(
    roi_names=roi_totals,
    use_corrected=False,
    # wavelength_range=(500, 650),
    wavelength_smoothing=1,
    interpolate_wavelengths=[64, 107, 138],
    legend_loc="outside",
    use_inline_labels=False,
    normalize_method="msc",
    show_std=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm
#
# 📊 Computing reference spectrum for MSC normalization...
#    ✓ Reference computed from 1085 spectra

# %%
cube.plot_spectrum(
    roi_names=roi_totals,
    use_corrected=False,
    wavelength_range=(580, 650),
    wavelength_smoothing=1,
    interpolate_wavelengths=[64, 107, 138],
    legend_loc="outside",
    use_inline_labels=False,
    normalize_method="minmax",
    show_std=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %%
cube.plot_spectrum(
    roi_names=roi_totals,
    use_corrected=False,
    # wavelength_range=(500, 650),
    wavelength_smoothing=1,
    interpolate_wavelengths=[64, 107, 138],
    legend_loc="outside",
    use_inline_labels=False,
    normalize_method="mean_center",
    show_std=False,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm

# %% [markdown]
# # extra

# %%
# Test: No normalization (raw data with offset visible)
cube.plot_spectrum(
    roi_names=roi_extra,
    use_corrected=True,
    wavelength_range=(500, 650),
    wavelength_smoothing=1,
    interpolate_wavelengths=[64, 107, 138],
    normalize_method=None,  # No normalization
    legend_loc="outside",
    use_inline_labels=False,
    show_std=True,
)
# Out:
# 🔧 Interpolating 3 wavelength(s):
#    • Index 64: 490.18 nm
#    • Index 107: 565.25 nm
#    • Index 138: 620.19 nm
