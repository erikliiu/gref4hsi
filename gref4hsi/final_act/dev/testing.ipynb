# %%
print("Starting testing notebook...")
print("=" * 50)

# %%
import numpy as np
import sys

print("System information:")
print(f"Python version: {sys.version}")
print(f"NumPy version: {np.__version__}")
print("-" * 50)

# %%
# Test data creation
test_data = np.random.rand(5, 5)
print("Created test data:")
print(f"Shape: {test_data.shape}")
print(f"Data type: {test_data.dtype}")
print(f"Min value: {test_data.min():.4f}")
print(f"Max value: {test_data.max():.4f}")
print(f"Mean value: {test_data.mean():.4f}")

# %%
print("\nTesting complete!")
print("All checks passed ✓")
print("=" * 50)
